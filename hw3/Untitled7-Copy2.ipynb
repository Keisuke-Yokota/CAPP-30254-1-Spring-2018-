# %%
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
import pandas as pd
#import Analysis_hw3
df = pd.read_csv('data.csv', header=0)
df = df.drop(["Unnamed: 0"],axis=1)

# %%
df = df.drop(['projectid', 'date_posted'],axis=1)
X = df.iloc[:, 1:]

# %%
Y = df.iloc[:, 0]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.5, random_state=0)

# %%
scores = ['accuracy', 'precision', 'recall']

# %%
LR = LogisticRegression()
KNN = KNeighborsClassifier()
DT = DecisionTreeClassifier()
RF = RandomForestClassifier()
BAG = BaggingClassifier()
AB = AdaBoostClassifier()
SVM = SVC()
clfs = [DT]

# %%
large_grid = { 
    RF:{'n_estimators': [1,10,100,1000,10000], 'max_depth': [1,5,10,20,50,100], 'max_features': ['sqrt','log2'],'min_samples_split': [2,5,10]},
    LR: { 'penalty': ['l1','l2'], 'C': [0.00001,0.0001,0.001,0.01,0.1,1,10]},
    AB: { 'algorithm': ['SAMME', 'SAMME.R'], 'n_estimators': [1,10,100,1000,10000]},
    DT: {'criterion': ['gini', 'entropy'], 'max_depth': [1,5,10,20,50,100], 'max_features': [None, 'sqrt','log2'],'min_samples_split': [2,5,10]},
    SVM :{'C' :[0.00001,0.0001,0.001,0.01,0.1,1,10],'kernel':['linear', 'rbf']},
    KNN :{'n_neighbors': [1,5,10,25,50,100],'weights': ['uniform','distance'],'algorithm': ['auto','ball_tree','kd_tree']},
    BAG :{'n_neighbors': [1,5,10,25,50,100],'max_features': [1,2,5,10]}     
           }

# %%
small_grid = { 
    RF:{'n_estimators': [100, 10000], 'max_depth': [5,50], 'max_features': ['sqrt','log2'],'min_samples_split': [2,10]},
    LR: { 'penalty': ['l1','l2'], 'C': [0.00001,0.001,0.1,1,10]},
    AB: { 'algorithm': ['SAMME', 'SAMME.R'], 'n_estimators': [1,10,100,1000,10000]},
    DT: {'criterion': ['gini', 'entropy'], 'max_depth': [1,5,10,20,50,100], 'max_features': [None,'sqrt','log2'],'min_samples_split': [2,5,10]},
    SVM :{'C' :[0.00001,0.0001,0.001,0.01,0.1,1,10],'kernel':['linear', 'rbf']},
    KNN :{'n_neighbors': [1,5,10,25,50,100],'weights': ['uniform','distance'],'algorithm': ['auto','ball_tree','kd_tree']},
    BAG :{'n_neighbors': [1,5,10,25,50,100],'max_features': [2,10]}     
           }

# %%
score = 'recall'

# %%
for clf in clfs:
    grid_clf = GridSearchCV(clf, large_grid[clf], cv=5, scoring=score, n_jobs=-1)
    grid_clf.fit(x_train, y_train)

    print(grid_clf.best_estimator_)

    for params, mean_score, all_scores in grid_clf.grid_scores_:
        print("{:.3f} (+/- {:.3f}) for {}".format(
            mean_score, all_scores.std() / 2, params))
        y_true, y_pred = y_test, grid_clf.predict(x_test)
        print(classification_report(y_true, y_pred))
        print(confusion_matrix(y_true, y_pred))
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')
# 0.000 (+/- 0.000) for {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'gini', 'max_depth': 1, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'gini', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'gini', 'max_depth': 1, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.734 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.734 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.734 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.461 (+/- 0.042) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.406 (+/- 0.049) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.530 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.302 (+/- 0.076) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.458 (+/- 0.107) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.412 (+/- 0.051) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.801 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.801 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.801 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 10, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.638 (+/- 0.033) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.596 (+/- 0.035) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.551 (+/- 0.031) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.561 (+/- 0.026) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.615 (+/- 0.045) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.602 (+/- 0.024) for {'criterion': 'gini', 'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.786 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 20, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.782 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 20, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.786 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 20, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.739 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.734 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.740 (+/- 0.003) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.715 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.704 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.710 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 20, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.788 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.780 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.784 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.721 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.727 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.729 (+/- 0.011) for {'criterion': 'gini', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.715 (+/- 0.011) for {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.698 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.699 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.788 (+/- 0.001) for {'criterion': 'gini', 'max_depth': 100, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.782 (+/- 0.001) for {'criterion': 'gini', 'max_depth': 100, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.785 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 100, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.734 (+/- 0.006) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.726 (+/- 0.006) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.712 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.724 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.694 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.715 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'entropy', 'max_depth': 1, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'entropy', 'max_depth': 1, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'entropy', 'max_depth': 1, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'entropy', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'entropy', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'entropy', 'max_depth': 1, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'entropy', 'max_depth': 1, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'entropy', 'max_depth': 1, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.000 (+/- 0.000) for {'criterion': 'entropy', 'max_depth': 1, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.740 (+/- 0.003) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.740 (+/- 0.003) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.740 (+/- 0.003) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.311 (+/- 0.058) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.424 (+/- 0.100) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.308 (+/- 0.086) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.596 (+/- 0.148) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.470 (+/- 0.079) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.247 (+/- 0.032) for {'criterion': 'entropy', 'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.802 (+/- 0.002) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.802 (+/- 0.003) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.803 (+/- 0.003) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.623 (+/- 0.038) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.646 (+/- 0.024) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.538 (+/- 0.067) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.619 (+/- 0.046) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.646 (+/- 0.034) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.638 (+/- 0.039) for {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.788 (+/- 0.002) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.784 (+/- 0.002) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.784 (+/- 0.002) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.734 (+/- 0.014) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.722 (+/- 0.009) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.700 (+/- 0.007) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.699 (+/- 0.025) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.717 (+/- 0.004) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.710 (+/- 0.015) for {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.793 (+/- 0.003) for {'criterion': 'entropy', 'max_depth': 50, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.786 (+/- 0.002) for {'criterion': 'entropy', 'max_depth': 50, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.788 (+/- 0.002) for {'criterion': 'entropy', 'max_depth': 50, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.758 (+/- 0.010) for {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.737 (+/- 0.007) for {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.735 (+/- 0.011) for {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.725 (+/- 0.011) for {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.711 (+/- 0.009) for {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.719 (+/- 0.013) for {'criterion': 'entropy', 'max_depth': 50, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.792 (+/- 0.003) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.785 (+/- 0.003) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.788 (+/- 0.002) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': None, 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.748 (+/- 0.005) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.748 (+/- 0.007) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.731 (+/- 0.003) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'sqrt', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.733 (+/- 0.005) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 2}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.695 (+/- 0.003) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 5}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
# 0.719 (+/- 0.016) for {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'log2', 'min_samples_split': 10}
#              precision    recall  f1-score   support
#
#           0       0.96      0.98      0.97    121355
#           1       0.90      0.81      0.85     27025
#
# avg / total       0.95      0.95      0.95    148380
#
# [[119024   2331]
#  [  5120  21905]]
