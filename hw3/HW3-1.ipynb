# %%
import pandas as pd
df = pd.read_csv('hw3.csv', header=0)
df = df.drop(["Unnamed: 0"],axis=1) 
df.shape
# Out:
# (353151, 46)

# %%
df.head(1)
# Out:
#                           projectid                    teacher_acctid  \
# 0  62526d85d2a1818432d03d600969e99c  ebc7c90b6c92a069432e0714b8d93dfd
#
#                            schoolid  school_ncesid  school_latitude  \
# 0  5aca9711ff0e4b37db48701f46f73036   1.713710e+11        41.972419
#
#    school_longitude school_city school_state  school_zip school_metro  \
# 0        -88.174597    Bartlett           IL     60103.0     suburban
#
#              ...             at_least_1_teacher_referred_donor fully_funded  \
# 0            ...                                             f            t
#
#   at_least_1_green_donation great_chat  \
# 0                         f          t
#
#   three_or_more_non_teacher_referred_donors  \
# 0                                         t
#
#   one_non_teacher_referred_donor_giving_100_plus  \
# 0                                              t
#
#   donation_from_thoughtful_donor great_messages_proportion  \
# ...

# %%
df.index = df.index -1

# %%
df.index
# Out:
# RangeIndex(start=0, stop=353151, step=1)

# %%
df.iat[0,0]
# Out:
# '62526d85d2a1818432d03d600969e99c'

# %%
df.loc[:, ["projectid", "schoolid"]]
# Out:
#                                projectid                          schoolid
# 0       62526d85d2a1818432d03d600969e99c  5aca9711ff0e4b37db48701f46f73036
# 1       33d59ac771b80222ad63ef0f4ac47ade  d91a805b213bf74ae77b94e0de2b73ad
# 2       1a3aaeffc56dd2a421e37d8298024c0a  9310d3eb447a4e46bc5fc31ed007ceac
# 3       33aa19ee4da4c5adf47d0dfb84fab5ef  9ac70da58322783f82152eecc140a812
# 4       e31c0ea8b68f404699dfb0d39e9bc99b  cb9f688cf59e3ee22a087d616ca8f5d7
# 5       c685c844476d7ed75bf87699eeafd682  34c650f9f6d5c3e42b8e2169c280ecb7
# 6       a4b234feb2b72921ed59850d5c873d62  da1985df161ba5c3842fc99579b6e4b1
# 7       0ff5dec32bf793243a8b0b2c023a81f0  72e2b0cb2eecfdc37e67e0eaf10da07b
# 8       8cdbc04c8ee2ae6afed4951727488579  5ad205c4692c53cd0f5fcdfca2322a86
# 9       72d58b8e22adbe6e6aab65d8b2ab4973  a180e99ef60be5a9c5f96e21f9868f13
# 10      1f405ea5b8ae8935a4169bdb56006b18  42d6a0b12a85feabc1eaabce06f7b777
# ...
