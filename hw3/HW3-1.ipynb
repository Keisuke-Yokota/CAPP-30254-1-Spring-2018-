# %%
import Analysis_hw3
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
import pandas as pd
df = pd.read_csv('hw3.csv', header=0)
df = df.drop(["Unnamed: 0"],axis=1) 
df.shape
# Out:
# (353151, 46)

# %%
df[df.date_posted =='2012-12-01'].index[-1]
# Out:
# 140518

# %%
df['year']=0
df['month']=0
df[day]=0
for i in df.shape[0]:
    lst = df.date_posted[i].split('-')
    df.iat[i, 46] = lst[0]
    df.iat[i, 46] = lst[1]
    df.iat[i, 46] = lst[2]
# Out:
# ['2013', '12', '31']

# %%
from datetime import date, datetime, timedelta

# %%
df.date_posted[2]
# Out:
# '62526d85d2a1818432d03d600969e99c'

# %%
df.loc[:, ["projectid", "schoolid"]]
# Out:
#                                 projectid                          schoolid
# -1       62526d85d2a1818432d03d600969e99c  5aca9711ff0e4b37db48701f46f73036
#  0       33d59ac771b80222ad63ef0f4ac47ade  d91a805b213bf74ae77b94e0de2b73ad
#  1       1a3aaeffc56dd2a421e37d8298024c0a  9310d3eb447a4e46bc5fc31ed007ceac
#  2       33aa19ee4da4c5adf47d0dfb84fab5ef  9ac70da58322783f82152eecc140a812
#  3       e31c0ea8b68f404699dfb0d39e9bc99b  cb9f688cf59e3ee22a087d616ca8f5d7
#  4       c685c844476d7ed75bf87699eeafd682  34c650f9f6d5c3e42b8e2169c280ecb7
#  5       a4b234feb2b72921ed59850d5c873d62  da1985df161ba5c3842fc99579b6e4b1
#  6       0ff5dec32bf793243a8b0b2c023a81f0  72e2b0cb2eecfdc37e67e0eaf10da07b
#  7       8cdbc04c8ee2ae6afed4951727488579  5ad205c4692c53cd0f5fcdfca2322a86
#  8       72d58b8e22adbe6e6aab65d8b2ab4973  a180e99ef60be5a9c5f96e21f9868f13
#  9       1f405ea5b8ae8935a4169bdb56006b18  42d6a0b12a85feabc1eaabce06f7b777
# ...

# %%
df[df.fully_funded == 'f']
# Out:
#                                projectid                    teacher_acctid  \
# 0       33d59ac771b80222ad63ef0f4ac47ade  de83b4c1f6428a15032c207c1d5e572a
# 1       1a3aaeffc56dd2a421e37d8298024c0a  f4c9ed095b85458dcf858e25f203af00
# 2       33aa19ee4da4c5adf47d0dfb84fab5ef  17768031eb40de8d4497dbb54df48742
# 4       c685c844476d7ed75bf87699eeafd682  4b19500fb087a635c98061505f1e6c6f
# 5       a4b234feb2b72921ed59850d5c873d62  620982375045fa11d872702f26ab98bb
# 10      c83d0794e67ec95f680cbb058c4523ff  535ab721f66316cf26a1d5ce1d9184f5
# 13      301b1da14667351b130f88bfc2928825  9b8f56e9a0a7116e129760d21a252038
# 14      9470f32d62e450ce072fed930cda104f  d0dc57f1fc72b86b0d40f7be65a442f3
# 19      f0174f30cd56d0641aeed0092d596b55  41a94b89c96e6dbbe02e74e392afc2bc
# 20      5d206ace88a5078409c17f9cf186c0ec  4378196ad1d5ba1f96ea64390a2f4c53
# 23      8bc3a18664ea03fe9161dc37385ed7d9  9c2872b67c63eb3dfbc9505eb4cd50a4
# ...

# %%
df.iloc[:,:15]
# Out:
#                                 projectid                    teacher_acctid  \
# -1       62526d85d2a1818432d03d600969e99c  ebc7c90b6c92a069432e0714b8d93dfd
#  0       33d59ac771b80222ad63ef0f4ac47ade  de83b4c1f6428a15032c207c1d5e572a
#  1       1a3aaeffc56dd2a421e37d8298024c0a  f4c9ed095b85458dcf858e25f203af00
#  2       33aa19ee4da4c5adf47d0dfb84fab5ef  17768031eb40de8d4497dbb54df48742
#  3       e31c0ea8b68f404699dfb0d39e9bc99b  0f1bc5b4700fd33383be104442660178
#  4       c685c844476d7ed75bf87699eeafd682  4b19500fb087a635c98061505f1e6c6f
#  5       a4b234feb2b72921ed59850d5c873d62  620982375045fa11d872702f26ab98bb
#  6       0ff5dec32bf793243a8b0b2c023a81f0  ec5b110df87bd511b508961676d08b6c
#  7       8cdbc04c8ee2ae6afed4951727488579  697e3ea37463219c27f9652b2287c844
#  8       72d58b8e22adbe6e6aab65d8b2ab4973  0793851e2f40ecc28e40513622aea670
#  9       1f405ea5b8ae8935a4169bdb56006b18  d2b8b908c4a88c48d07439b6d903372e
# ...

# %%
df.iloc[:,15:30]
# Out:
#         school_nlns school_kipp school_charter_ready_promise teacher_prefix  \
# -1                f           f                            f           Mrs.
#  0                f           f                            f           Mrs.
#  1                f           f                            f           Mrs.
#  2                f           f                            f            Ms.
#  3                f           f                            f            Mr.
#  4                f           f                            f           Mrs.
#  5                f           f                            f           Mrs.
#  6                f           f                            f            Ms.
#  7                f           f                            f           Mrs.
#  8                f           f                            f           Mrs.
#  9                f           f                            f            Ms.
# ...

# %%
df.iloc[:,30:]
# Out:
#          total_price_including_optional_support  students_reached  \
# -1                                       522.78               7.0
#  0                                       274.40              30.0
#  1                                       335.40             230.0
#  2                                       274.05              18.0
#  3                                       604.01              70.0
#  4                                       809.54              22.0
#  5                                      1100.19              25.0
#  6                                       952.14              17.0
#  7                                       370.60              20.0
#  8                                       350.41              21.0
#  9                                       235.98              25.0
#  10                                      317.53              36.0
#  11                                      610.62             160.0
# ...

# %%
def make_labels(x):
    if x == 'f':
        return 1
    elif x == 't':
        return 0
    else:
        return -1

df['label'] = df['fully_funded'].apply(make_labels)

# %%
df.label.mean()
# Out:
# 0.29860597874563571

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
df.sort_values(by=["teacher_referred_count"], ascending=True)

# %%
len(df)
# Out:
# 353151
