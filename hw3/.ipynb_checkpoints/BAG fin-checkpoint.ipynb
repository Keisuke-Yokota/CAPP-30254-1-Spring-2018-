# %%
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier,GradientBoostingClassifier ,AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
import pandas as pd
#import Analysis_hw3
df = pd.read_csv('data.csv', header=0)
df = df.drop(["Unnamed: 0"],axis=1)

# %%
df = df.drop(['projectid', 'date_posted'],axis=1)
X = df.iloc[:, 1:]

# %%
Y = df.iloc[:, 0]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.5, random_state=0)

# %%
scores = ['accuracy', 'precision', 'recall']

# %%
LR = LogisticRegression()
KNN = KNeighborsClassifier()
DT = DecisionTreeClassifier()
RF = RandomForestClassifier()
BAG = BaggingClassifier()
AB = AdaBoostClassifier()
GB = GradientBoostingClassifier()
SVM = SVC()
clfs = [BAG]

# %%
large_grid = { 
    RF:{'n_estimators': [1,10,100,1000,10000], 'max_depth': [1,5,10,20,50,100], 'max_features': ['sqrt','log2'],'min_samples_split': [2,5,10]},
    LR: { 'penalty': ['l1','l2'], 'C': [0.00001,0.0001,0.001,0.01,0.1,1,10]},
    AB: { 'algorithm': ['SAMME', 'SAMME.R'], 'n_estimators': [1,10,100,1000,10000]},
    DT: {'criterion': ['gini', 'entropy'], 'max_depth': [1,5,10,20,50,100], 'max_features': [None, 'sqrt','log2'],'min_samples_split': [2,5,10]},
    SVM :{'C' :[0.00001,0.0001,0.001,0.01,0.1,1,10],'kernel':['linear', 'rbf']},
    KNN :{'n_neighbors': [1,5,10,25,50,100],'weights': ['uniform','distance'],'algorithm': ['auto','ball_tree','kd_tree']},
    BAG :{'n_estimators': [1,5,10,25,50,100],'max_features': [1,2,5,10]}     
           }

# %%
small_grid = { 
    RF:{'n_estimators': [100, 10000], 'max_depth': [5,50], 'max_features': ['sqrt','log2'],'min_samples_split': [2,10]},
    LR: { 'penalty': ['l1','l2'], 'C': [0.00001,0.001,0.1,1,10]},
    AB: { 'algorithm': ['SAMME', 'SAMME.R'], 'n_estimators': [1,10,100,1000,10000]},
    DT: {'criterion': ['gini', 'entropy'], 'max_depth': [1,5,10,20,50,100], 'max_features': [None,'sqrt','log2'],'min_samples_split': [2,5,10]},
    SVM :{'C' :[0.00001,0.0001,0.001,0.01,0.1,1,10],'kernel':['linear', 'rbf']},
    KNN :{'n_neighbors': [1,5,10,25,50,100],'weights': ['uniform','distance'],'algorithm': ['auto','ball_tree','kd_tree']},
    BAG :{'n_estimators': [1,5,10,25,50,100],'max_features': [2,10]}     
           }

# %%
score = 'recall'

# %%
for clf in clfs:
    grid_clf = GridSearchCV(clf, large_grid[clf], cv=5, scoring=score, n_jobs=-1)
    grid_clf.fit(x_train, y_train)

    print(grid_clf.best_estimator_)

    for params, mean_score, all_scores in grid_clf.grid_scores_:
        print("{:.3f} (+/- {:.3f}) for {}".format(
            mean_score, all_scores.std() / 2, params))
        y_true, y_pred = y_test, grid_clf.predict(x_test)
        print(classification_report(y_true, y_pred))
        print(confusion_matrix(y_true, y_pred))
# Out:
# BaggingClassifier(base_estimator=None, bootstrap=True,
#          bootstrap_features=False, max_features=10, max_samples=1.0,
#          n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#          verbose=0, warm_start=False)
# 0.000 (+/- 0.000) for {'max_features': 1, 'n_estimators': 1}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 1, 'n_estimators': 5}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 1, 'n_estimators': 10}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 1, 'n_estimators': 25}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 1, 'n_estimators': 50}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 1, 'n_estimators': 100}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 2, 'n_estimators': 1}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 2, 'n_estimators': 5}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 2, 'n_estimators': 10}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 2, 'n_estimators': 25}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 2, 'n_estimators': 50}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 2, 'n_estimators': 100}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.182 (+/- 0.115) for {'max_features': 5, 'n_estimators': 1}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.021 (+/- 0.013) for {'max_features': 5, 'n_estimators': 5}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.002 (+/- 0.002) for {'max_features': 5, 'n_estimators': 10}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.003 (+/- 0.001) for {'max_features': 5, 'n_estimators': 25}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 5, 'n_estimators': 50}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.000 (+/- 0.000) for {'max_features': 5, 'n_estimators': 100}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.210 (+/- 0.096) for {'max_features': 10, 'n_estimators': 1}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.199 (+/- 0.052) for {'max_features': 10, 'n_estimators': 5}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.212 (+/- 0.041) for {'max_features': 10, 'n_estimators': 10}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.111 (+/- 0.025) for {'max_features': 10, 'n_estimators': 25}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.021 (+/- 0.004) for {'max_features': 10, 'n_estimators': 50}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
# 0.038 (+/- 0.002) for {'max_features': 10, 'n_estimators': 100}
#              precision    recall  f1-score   support
#
#           0       0.85      1.00      0.92    121355
#           1       0.94      0.20      0.33     27025
#
# avg / total       0.87      0.85      0.81    148380
#
# [[121025    330]
#  [ 21539   5486]]
