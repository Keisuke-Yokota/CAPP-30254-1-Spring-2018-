# %%
import Analysis_hw3
import pandas as pd
# %matplotlib inline
xy = pd.read_csv('xy.csv', header=0)
xy = xy.drop(["Unnamed: 0"],axis=1)
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
xy.columns
# Out:
# Index(['fully_funded', 'Health & Sports', 'History & Civics',
#        'Literacy & Language', 'Math & Science', 'Music & The Arts',
#        'Special Needs', 'Health & Sports.1', 'History & Civics.1',
#        'Literacy & Language.1', 'Math & Science.1', 'Music & The Arts.1',
#        'Special Needs.1', 'projectid', 'school_metro', 'school_charter',
#        'school_magnet', 'school_year_round', 'school_nlns', 'school_kipp',
#        'school_charter_ready_promise', 'teacher_prefix',
#        'teacher_teach_for_america', 'teacher_ny_teaching_fellow',
#        'poverty_level', 'grade_level', 'fulfillment_labor_materials',
#        'total_price_excluding_optional_support',
#        'total_price_including_optional_support', 'students_reached',
#        'eligible_double_your_impact_match', 'eligible_almost_home_match',
#        'date_posted', 'is_exciting', 'at_least_1_teacher_referred_donor',
#        'at_least_1_green_donation', 'great_chat',
# ...

# %%
Analysis_hw3.show_dist(xy.iloc[:, [0,32]], 'fully_funded')

# %%
Analysis_hw3.show_dist(xy.iloc[:, [0,33]], 'fully_funded')

# %%
Analysis_hw3.show_dist(xy.iloc[:, [0,34]], 'fully_funded')

# %%
Analysis_hw3.show_dist(xy.iloc[:, [0,37]], 'fully_funded')

# %%
Analysis_hw3.show_dist(xy.iloc[:, [0,39]], 'fully_funded')

# %%
Analysis_hw3.show_dist(xy.iloc[:, [0,41]], 'fully_funded')
