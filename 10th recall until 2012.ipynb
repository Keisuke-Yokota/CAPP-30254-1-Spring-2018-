# %%
import pandas as pd
import numpy as np
from sklearn.grid_search import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %%
df=pd.read_csv('/Users/Keisuke/Desktop/bigtable.csv')

# %%
df=df.drop(['Unnamed: 0','t-1yr_unemp_rate','t-1school_yr_unemp_rate'], axis=1)

# %%
l = []
for val in df.columns.tolist():
    if '0.0' in val:
        l.append(val)
        df = df.drop(val, axis=1)
len(l)
# Out:
# 28

# %%
l
# Out:
# ['third_read_pl_0.0',
#  'third_math_pl_0.0',
#  'fourth_read_pl_0.0',
#  'fourth_math_pl_0.0',
#  'fourth_write_pl_0.0',
#  'fourth_ctz_pl_0.0',
#  'fourth_science_pl_0.0',
#  'fifth_read_pl_0.0',
#  'fifth_math_pl_0.0',
#  'fifth_socstudies_pl_0.0',
#  'fifth_science_pl_0.0',
#  'sixth_read_pl_0.0',
#  'sixth_math_pl_0.0',
#  'sixth_write_pl_0.0',
#  'sixth_ctz_pl_0.0',
#  'sixth_science_pl_0.0',
#  'seventh_read_pl_0.0',
#  'seventh_math_pl_0.0',
#  'seventh_write_pl_0.0',
#  'eighth_read_pl_0.0',
#  'eighth_math_pl_0.0',
#  'eighth_science_pl_0.0',
#  'eighth_socstudies_pl_0.0',
#  'ogt_read_pl_0.0',
#  'ogt_math_pl_0.0',
#  'ogt_write_pl_0.0',
#  'ogt_science_pl_0.0',
#  'ogt_socstudies_pl_0.0']

# %%
len(df.columns.tolist())
# Out:
# 219

# %%
def split_train_test(dataset, ith_grade, test_year):
    """
    transform dataset into suitable one for specific grade students
    
    input
        dataset: dataframe
        ith_grade: the target current (or base) grade for analysis (integer)
        test_year: testing data's year (integer)      
    output
        dataframe
    """
        
    final_grade = 12
    duration = final_grade - ith_grade + 1

    if test_year <= 2009:
        print("""We have no enough training data.
              Please set school year from 2010.""")
        return None, None, None, None

    max_year = dataset['school_year'].max()
    
    if test_year + duration  > max_year:
        print("""We have no enough school year for testing data.
              Please set school year before {}.""".format(max_year - duration + 2))
        return None, None, None, None
    
    ### create keep_col
    
    all_cols = dataset.columns.values.tolist()
    district_cols = [col for col in all_cols if 'district' in col]
    disability_cols = [col for col in all_cols if 'disability' in col]
    zip_cols = [col for col in all_cols if 'zip' in col]
    disadv_cols = [col for col in all_cols if 'disadvantagement' in col]
    change_cols = ['school_year', 'grade','age', 'discipline_incidents','retained',
               'log_median', 'log_mean', 'log_pop','log_median_miss', 'log_mean_miss', 'log_pop_miss',
                 'limited_english_Miss',
                 'limited_english_f', 'limited_english_t', 'gifted_Miss',
                 'gifted_f','gifted_t','total_length_of_absence',
                 'length_of_unexcused_absence', 'absence_ratio',
                 'unexcused_absence_ratio', 'diff_total_length_of_absence',
                 'diff_length_of_unexcused_absence', 'diff_absence_ratio',
                 'diff_unexcused_absence_ratio', 'absence_consec_count',
                 'diff_absence_consec_count', 'absence_medical',
                 'diff_absence_medical', 'absence_suspension',
                 'diff_absence_suspension','days_tardy',
                 'diff_days_tardy', 'unexcused tardy', 'diff_unexcused tardy',
                 'tardy_consec_count', 'diff_tardy_consec_count',
                 'unemp_rate', 't-1yr_unemp_rate', 'school_yr_unemp_rate',
                 't-1school_yr_unemp_rate', 'dropout_prevention',
                 'special_education', 'extra_program', 'advanced_program',
                 'other_program', 'family_school_career_program', 'missing_intervention',
                 'gpa_est','gpa_miss']
    change_cols = change_cols + district_cols + disability_cols + zip_cols + disadv_cols
    keep_cols = [x for x in all_cols if x not in change_cols]
    
    x_train = train_x_transform(dataset, ith_grade, test_year, keep_cols=keep_cols)
    y_train = train_y_transform(dataset, ith_grade, test_year)
        
    x_test = test_x_transform(dataset, ith_grade, test_year, keep_cols=keep_cols)
    y_test = test_y_transform(dataset, ith_grade, test_year)

    return  x_train, x_test, y_train, y_test



def train_x_transform(dataset, ith_grade, test_year, keep_cols=['student_lookup']):
    """
    transform dataset into suitable one for specific grade students
    
    input
        dataset: dataframe
        ith_grade: the target grade for analysis (integer)
        test_year: testing data's year (integer)              
        keep_cols: list of columns' names that you don't want to create by grade (default 'student_lookup')
                   <CAUTION> Do not include either 'dropout', 'school_year' or 'grade'
                             and you should include something plus 'student_lookup'      
    output
        dataframe
    """
    dataset = dataset.drop('dropout', axis =1)
    cols = dataset.columns.values.tolist()
    if 'grade' in cols:
        cols.remove('grade')
    if 'dropout' in keep_cols:
        keep_cols.remove('dropout')
    if 'grade' in keep_cols:
        keep_cols.remove('grade')    
    for col in keep_cols:
        cols.remove(col)
    
    final_grade = 12
    duration = final_grade - ith_grade + 1
    
    sid_df = dataset[(dataset.grade == ith_grade)&(dataset.school_year <= test_year - duration)][['student_lookup']]
    df_ith = dataset[dataset.student_lookup.isin(sid_df.student_lookup)]
    new_dataset = df_ith[(dataset.grade <= ith_grade)&(dataset.grade >= ith_grade - 3)]
    new_dataset = new_dataset.reset_index()  
    pivot_df = pd.pivot_table(new_dataset, 
                              values=cols, 
                              index=keep_cols,
                              columns=['grade'])
    pivot_df.columns = [s1 +'_'+ str(s2)+'th' for (s1,s2) in pivot_df.columns.tolist()]
    pivot_df.reset_index(inplace=True)
    
    for col in pivot_df.columns.values:
        if 'miss' in col or 'Miss' in col or 'zip_0' in col:
            pivot_df[col].fillna(1, inplace=True)
        else:
            pivot_df[col].fillna(0, inplace=True)
            
    ### avoid duplication with x_data
    for col in pivot_df.columns.tolist():
        if 'school_year' in col:
            pivot_df = pivot_df.drop(col, axis=1)
        
    pivot_df = pivot_df.drop('student_lookup', axis=1)
    return pivot_df



def train_y_transform(dataset, ith_grade, test_year):
    """
    transform dataset into suitable one for specific grade students
    
    input
        dataset: dataframe
        ith_grade: the target grade for analysis (integer)
        test_year: testing data's year (integer)      
        
    output
        dataframe
    """
    dataset = dataset[['student_lookup', 'grade', 'school_year', 'dropout']]
    cols = ['school_year', 'dropout']
 
    
    final_grade = 12
    duration = final_grade - ith_grade + 1

    sid_df = dataset[(dataset.grade == ith_grade)&(dataset.school_year <= test_year - duration)][['student_lookup']]
    df_ith = dataset[dataset.student_lookup.isin(sid_df.student_lookup)]
    new_dataset = df_ith[dataset.grade >= ith_grade]
    new_dataset = new_dataset.reset_index()  
    pivot_df = pd.pivot_table(new_dataset, 
                              values=cols, 
                              index=['student_lookup'],
                              columns=['grade'])
    pivot_df.columns = [s1 +'_'+ str(s2)+'th' for (s1,s2) in pivot_df.columns.tolist()]
    pivot_df.reset_index(inplace=True)
    
    ### avoid duplication with x_data
    for col in pivot_df.columns.tolist():
        if 'school_year' in col:
            pivot_df = pivot_df.drop(col, axis=1)
            
    ### fill nan in the dropout column with the previous year information by student             
    for i in range(pivot_df.shape[0]):
        for j in range(2, pivot_df.shape[1]):
            cell = pivot_df.iat[i, j]
            cell = cell.astype(str)
            if cell == 'nan':
                pivot_df.iat[i, j] = pivot_df.iat[i, j-1]
                
    ### fix label value error cuased by duplication                            
    for i in range(pivot_df.shape[0]):
        for j in range(pivot_df.shape[1]):
            cell = pivot_df.iat[i, j] 
            if cell > 0 and cell < 1:
                pivot_df.iat[i, j] = 1
                
    pivot_df = pivot_df[['student_lookup','dropout_12.0th']]

    pivot_df = pivot_df.drop('student_lookup', axis=1)
    return pivot_df.as_matrix().reshape(-1,)


def test_x_transform(dataset, ith_grade, test_year, keep_cols=['student_lookup']):
    """
    transform dataset into suitable one for specific grade students
    
    input
        dataset: dataframe
        ith_grade: the target grade for analysis (integer)
        keep_cols: list of columns' names that you don't want to create by grade (default 'student_lookup')
                   <CAUTION> Do not include either 'dropout', 'school_year' or 'grade'
                             and you should include something plus 'student_lookup'      
    output
        dataframe
    """
    dataset = dataset.drop('dropout', axis =1)
    cols = dataset.columns.values.tolist()
    if 'grade' in cols:
        cols.remove('grade')
    if 'dropout' in keep_cols:
        keep_cols.remove('dropout')
    if 'grade' in keep_cols:
        keep_cols.remove('grade')    
    for col in keep_cols:
        cols.remove(col)
    
    final_grade = 12
    duration = final_grade - ith_grade + 1

    sid_df = dataset[(dataset.grade == ith_grade)&(dataset.school_year <= test_year - duration)][['student_lookup']]
    df_ith = dataset[dataset.student_lookup.isin(sid_df.student_lookup)]
    new_dataset = df_ith[(dataset.grade <= ith_grade)&(dataset.grade >= ith_grade - 3)]
    new_dataset = new_dataset.reset_index()  
    pivot_df = pd.pivot_table(new_dataset, 
                              values=cols, 
                              index=keep_cols,
                              columns=['grade'])
    pivot_df.columns = [s1 +'_'+ str(s2)+'th' for (s1,s2) in pivot_df.columns.tolist()]
    pivot_df.reset_index(inplace=True)
    
    for col in pivot_df.columns.values:
        if 'miss' in col or 'Miss' in col or 'zip_0' in col:
            pivot_df[col].fillna(1, inplace=True)
        else:
            pivot_df[col].fillna(0, inplace=True)
            
    ### avoid duplication with x_data
    for col in pivot_df.columns.tolist():
        if 'school_year' in col:
            pivot_df = pivot_df.drop(col, axis=1)
        
    pivot_df = pivot_df.drop('student_lookup', axis=1)
    return pivot_df



def test_y_transform(dataset, ith_grade, test_year):
    """
    transform dataset into suitable one for specific grade students
    
    input
        dataset: dataframe
        ith_grade: the target grade for analysis (integer)
          
    output
        dataframe
    """
    dataset = dataset[['student_lookup', 'grade', 'school_year', 'dropout']]
    cols = ['school_year', 'dropout']
    
    final_grade = 12
    duration = final_grade - ith_grade + 1

    sid_df = dataset[(dataset.grade == ith_grade)&(dataset.school_year <= test_year - duration)][['student_lookup']]
    df_ith = dataset[dataset.student_lookup.isin(sid_df.student_lookup)]
    new_dataset = df_ith[dataset.grade >= ith_grade]
    new_dataset = new_dataset.reset_index()  
    pivot_df = pd.pivot_table(new_dataset, 
                              values=cols, 
                              index=['student_lookup'],
                              columns=['grade'])
    pivot_df.columns = [s1 +'_'+ str(s2)+'th' for (s1,s2) in pivot_df.columns.tolist()]
    pivot_df.reset_index(inplace=True)
    
    ### avoid duplication with x_data
    for col in pivot_df.columns.tolist():
        if 'school_year' in col:
            pivot_df = pivot_df.drop(col, axis=1)
            
    ### fill nan in the dropout column with the previous year information by student             
    for i in range(pivot_df.shape[0]):
        for j in range(2, pivot_df.shape[1]):
            cell = pivot_df.iat[i, j]
            cell = cell.astype(str)
            if cell == 'nan':
                pivot_df.iat[i, j] = pivot_df.iat[i, j-1]
                
    ### fix label value error cuased by duplication                            
    for i in range(pivot_df.shape[0]):
        for j in range(pivot_df.shape[1]):
            cell = pivot_df.iat[i, j] 
            if cell > 0 and cell < 1:
                pivot_df.iat[i, j] = 1
    pivot_df = pivot_df[['student_lookup','dropout_12.0th']]
    
    pivot_df = pivot_df.drop('student_lookup', axis=1)
    return pivot_df.as_matrix().reshape(-1,)

# %%
from sklearn.metrics import recall_score
def recall_get_feature_importance(train_x_data, train_y_data, test_x_data, test_y_data, model):
    """
    Borrowed from here
    http://www.dskomei.com/entry/2018/03/20/003752
    """
    from sklearn.ensemble import RandomForestClassifier

    col_names = train_x_data.columns.values

    ### model = SVC(kernel='rbf', C=1, gamma=0.1)

    selected_col_names = []
    scores = []
    selected_k = 0
    max_score = 0

    rf = RandomForestClassifier(random_state=0)
    rf.fit(train_x_data, train_y_data)

    # sort by feature importance provided by RF
    col_names_ = col_names[np.argsort(rf.feature_importances_)[::-1]]

    for n_variable in range(1, len(col_names)+1):

        # select variables from top important one
        train_x_data_ = train_x_data.loc[:, col_names_[:n_variable]]
        test_x_data_ = test_x_data.loc[:, col_names_[:n_variable]]

        model.fit(train_x_data_, train_y_data)
        #score = model.score(test_x_data_, test_y_data)
        score = recall_score(test_y_data, model.predict(test_x_data_))

        if score > max_score:
            max_score = score
            selected_k = n_variable

        selected_col_names.append(','.join(col_names_[:n_variable]))
        scores.append(score)

        print('k {:3} : score {:5.2f}%'.format(n_variable, max_score * 100))

    print('')
    print('[MAX SCORE] : k {} : score {}%'.format(selected_k, max_score))
    print(selected_col_names[int(np.argmax(scores))])

# %%
x_train, x_test, y_train, y_test = split_train_test(df, 10, 2012)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:99: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:145: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:209: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:253: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
y_train.shape
# Out:
# (5095,)

# %%
x_train.shape
# Out:
# (5095, 662)

# %%
y_test.shape
# Out:
# (5095,)

# %%
x_test.shape
# Out:
# (5095, 662)

# %%
LR = LogisticRegression()
KNN = KNeighborsClassifier()
DT = DecisionTreeClassifier()
RF = RandomForestClassifier()
BAG = BaggingClassifier()
AB = AdaBoostClassifier()
SVM = SVC(kernel='rbf')

# %%
recall_get_feature_importance(x_train, y_train, x_test, y_test, LR)
# Out:
# k   1 : score  1.19%
# k   2 : score  1.19%
# k   3 : score  2.38%
# k   4 : score  2.38%
# k   5 : score  2.38%
# k   6 : score  3.57%
# k   7 : score  3.57%
# k   8 : score  3.57%
# k   9 : score  3.57%
# k  10 : score  4.76%
# k  11 : score  4.76%
# k  12 : score  4.76%
# k  13 : score  4.76%
# k  14 : score  4.76%
# k  15 : score  5.95%
# k  16 : score  5.95%
# k  17 : score  5.95%
# k  18 : score  5.95%
# k  19 : score  5.95%
# k  20 : score  5.95%
# k  21 : score  5.95%
# k  22 : score  5.95%
# k  23 : score  8.33%
# k  24 : score  8.33%
# k  25 : score  8.33%
# k  26 : score  8.33%
# k  27 : score  8.33%
# k  28 : score  8.33%
# k  29 : score  8.33%
# k  30 : score  8.33%
# k  31 : score  8.33%
# k  32 : score  8.33%
# k  33 : score  8.33%
# k  34 : score  8.33%
# k  35 : score  8.33%
# k  36 : score  8.33%
# k  37 : score  8.33%
# k  38 : score  8.33%
# k  39 : score  8.33%
# k  40 : score  8.33%
# k  41 : score  8.33%
# k  42 : score  8.33%
# k  43 : score  8.33%
# k  44 : score  8.33%
# k  45 : score  8.33%
# k  46 : score  8.33%
# k  47 : score  8.33%
# k  48 : score  8.33%
# k  49 : score  8.33%
# k  50 : score  8.33%
# k  51 : score  8.33%
# k  52 : score  8.33%
# k  53 : score  8.33%
# k  54 : score  8.33%
# k  55 : score  8.33%
# k  56 : score  8.33%
# k  57 : score  8.33%
# k  58 : score  8.33%
# k  59 : score  9.52%
# k  60 : score  9.52%
# k  61 : score  9.52%
# k  62 : score  9.52%
# k  63 : score  9.52%
# k  64 : score  9.52%
# k  65 : score  9.52%
# k  66 : score 10.71%
# k  67 : score 10.71%
# k  68 : score 10.71%
# k  69 : score 10.71%
# k  70 : score 10.71%
# k  71 : score 10.71%
# k  72 : score 10.71%
# k  73 : score 10.71%
# k  74 : score 10.71%
# k  75 : score 10.71%
# k  76 : score 10.71%
# k  77 : score 10.71%
# k  78 : score 10.71%
# k  79 : score 10.71%
# k  80 : score 10.71%
# k  81 : score 10.71%
# k  82 : score 10.71%
# k  83 : score 10.71%
# k  84 : score 11.90%
# k  85 : score 11.90%
# k  86 : score 11.90%
# k  87 : score 11.90%
# k  88 : score 11.90%
# k  89 : score 11.90%
# k  90 : score 11.90%
# k  91 : score 13.10%
# k  92 : score 14.29%
# k  93 : score 14.29%
# k  94 : score 14.29%
# k  95 : score 14.29%
# k  96 : score 14.29%
# k  97 : score 14.29%
# k  98 : score 14.29%
# k  99 : score 14.29%
# k 100 : score 14.29%
# k 101 : score 14.29%
# k 102 : score 14.29%
# k 103 : score 14.29%
# k 104 : score 14.29%
# k 105 : score 14.29%
# k 106 : score 14.29%
# k 107 : score 14.29%
# k 108 : score 15.48%
# k 109 : score 15.48%
# k 110 : score 15.48%
# k 111 : score 15.48%
# k 112 : score 15.48%
# k 113 : score 15.48%
# k 114 : score 15.48%
# k 115 : score 15.48%
# k 116 : score 15.48%
# k 117 : score 15.48%
# k 118 : score 15.48%
# k 119 : score 15.48%
# k 120 : score 15.48%
# k 121 : score 15.48%
# k 122 : score 15.48%
# k 123 : score 15.48%
# k 124 : score 15.48%
# k 125 : score 15.48%
# k 126 : score 15.48%
# k 127 : score 15.48%
# k 128 : score 15.48%
# k 129 : score 15.48%
# k 130 : score 15.48%
# k 131 : score 15.48%
# k 132 : score 15.48%
# k 133 : score 15.48%
# k 134 : score 15.48%
# k 135 : score 15.48%
# k 136 : score 15.48%
# k 137 : score 15.48%
# k 138 : score 15.48%
# k 139 : score 15.48%
# k 140 : score 15.48%
# k 141 : score 15.48%
# k 142 : score 15.48%
# k 143 : score 15.48%
# k 144 : score 15.48%
# k 145 : score 15.48%
# k 146 : score 16.67%
# k 147 : score 16.67%
# k 148 : score 16.67%
# k 149 : score 16.67%
# k 150 : score 16.67%
# k 151 : score 16.67%
# k 152 : score 17.86%
# k 153 : score 17.86%
# k 154 : score 17.86%
# k 155 : score 17.86%
# k 156 : score 17.86%
# k 157 : score 17.86%
# k 158 : score 17.86%
# k 159 : score 17.86%
# k 160 : score 17.86%
# k 161 : score 17.86%
# k 162 : score 17.86%
# k 163 : score 17.86%
# k 164 : score 17.86%
# k 165 : score 17.86%
# k 166 : score 17.86%
# k 167 : score 17.86%
# k 168 : score 17.86%
# k 169 : score 17.86%
# k 170 : score 17.86%
# k 171 : score 17.86%
# k 172 : score 17.86%
# k 173 : score 17.86%
# k 174 : score 17.86%
# k 175 : score 17.86%
# k 176 : score 17.86%
# k 177 : score 17.86%
# k 178 : score 17.86%
# k 179 : score 17.86%
# k 180 : score 17.86%
# k 181 : score 17.86%
# k 182 : score 17.86%
# k 183 : score 17.86%
# k 184 : score 17.86%
# k 185 : score 17.86%
# k 186 : score 17.86%
# k 187 : score 17.86%
# k 188 : score 17.86%
# k 189 : score 17.86%
# k 190 : score 17.86%
# k 191 : score 17.86%
# k 192 : score 17.86%
# k 193 : score 17.86%
# k 194 : score 17.86%
# k 195 : score 17.86%
# k 196 : score 19.05%
# k 197 : score 19.05%
# k 198 : score 19.05%
# k 199 : score 19.05%
# k 200 : score 19.05%
# k 201 : score 19.05%
# k 202 : score 19.05%
# k 203 : score 19.05%
# k 204 : score 19.05%
# k 205 : score 19.05%
# k 206 : score 19.05%
# k 207 : score 19.05%
# k 208 : score 19.05%
# k 209 : score 19.05%
# k 210 : score 19.05%
# k 211 : score 19.05%
# k 212 : score 19.05%
# k 213 : score 19.05%
# k 214 : score 19.05%
# k 215 : score 19.05%
# k 216 : score 19.05%
# k 217 : score 19.05%
# k 218 : score 19.05%
# k 219 : score 19.05%
# k 220 : score 19.05%
# k 221 : score 19.05%
# k 222 : score 19.05%
# k 223 : score 19.05%
# k 224 : score 19.05%
# k 225 : score 19.05%
# k 226 : score 19.05%
# k 227 : score 19.05%
# k 228 : score 19.05%
# k 229 : score 19.05%
# k 230 : score 19.05%
# k 231 : score 19.05%
# k 232 : score 19.05%
# k 233 : score 19.05%
# k 234 : score 19.05%
# k 235 : score 19.05%
# k 236 : score 19.05%
# k 237 : score 19.05%
# k 238 : score 19.05%
# k 239 : score 19.05%
# k 240 : score 19.05%
# k 241 : score 19.05%
# k 242 : score 19.05%
# k 243 : score 19.05%
# k 244 : score 19.05%
# k 245 : score 19.05%
# k 246 : score 19.05%
# k 247 : score 19.05%
# k 248 : score 19.05%
# k 249 : score 19.05%
# k 250 : score 19.05%
# k 251 : score 19.05%
# k 252 : score 19.05%
# k 253 : score 19.05%
# k 254 : score 19.05%
# k 255 : score 19.05%
# k 256 : score 19.05%
# k 257 : score 19.05%
# k 258 : score 19.05%
# k 259 : score 19.05%
# k 260 : score 19.05%
# k 261 : score 19.05%
# k 262 : score 19.05%
# k 263 : score 19.05%
# k 264 : score 19.05%
# k 265 : score 19.05%
# k 266 : score 19.05%
# k 267 : score 19.05%
# k 268 : score 19.05%
# k 269 : score 19.05%
# k 270 : score 19.05%
# k 271 : score 19.05%
# k 272 : score 19.05%
# k 273 : score 19.05%
# k 274 : score 19.05%
# k 275 : score 19.05%
# k 276 : score 19.05%
# k 277 : score 19.05%
# k 278 : score 19.05%
# k 279 : score 19.05%
# k 280 : score 19.05%
# k 281 : score 19.05%
# k 282 : score 19.05%
# k 283 : score 19.05%
# k 284 : score 19.05%
# k 285 : score 19.05%
# k 286 : score 19.05%
# k 287 : score 19.05%
# k 288 : score 19.05%
# k 289 : score 19.05%
# k 290 : score 19.05%
# k 291 : score 19.05%
# k 292 : score 19.05%
# k 293 : score 19.05%
# k 294 : score 19.05%
# k 295 : score 19.05%
# k 296 : score 19.05%
# k 297 : score 19.05%
# k 298 : score 19.05%
# k 299 : score 19.05%
# k 300 : score 19.05%
# k 301 : score 19.05%
# k 302 : score 19.05%
# k 303 : score 19.05%
# k 304 : score 19.05%
# k 305 : score 19.05%
# k 306 : score 19.05%
# k 307 : score 19.05%
# k 308 : score 19.05%
# k 309 : score 19.05%
# k 310 : score 19.05%
# k 311 : score 19.05%
# k 312 : score 19.05%
# k 313 : score 19.05%
# k 314 : score 19.05%
# k 315 : score 19.05%
# k 316 : score 19.05%
# k 317 : score 19.05%
# k 318 : score 19.05%
# k 319 : score 19.05%
# k 320 : score 19.05%
# k 321 : score 19.05%
# k 322 : score 19.05%
# k 323 : score 19.05%
# k 324 : score 19.05%
# k 325 : score 19.05%
# k 326 : score 19.05%
# k 327 : score 19.05%
# k 328 : score 19.05%
# k 329 : score 19.05%
# k 330 : score 19.05%
# k 331 : score 19.05%
# k 332 : score 19.05%
# k 333 : score 19.05%
# k 334 : score 19.05%
# k 335 : score 19.05%
# k 336 : score 19.05%
# k 337 : score 19.05%
# k 338 : score 19.05%
# k 339 : score 19.05%
# k 340 : score 19.05%
# k 341 : score 19.05%
# k 342 : score 19.05%
# k 343 : score 19.05%
# k 344 : score 19.05%
# k 345 : score 19.05%
# k 346 : score 19.05%
# k 347 : score 19.05%
# k 348 : score 19.05%
# k 349 : score 19.05%
# k 350 : score 19.05%
# k 351 : score 19.05%
# k 352 : score 19.05%
# k 353 : score 19.05%
# k 354 : score 19.05%
# k 355 : score 19.05%
# k 356 : score 19.05%
# k 357 : score 19.05%
# k 358 : score 19.05%
# k 359 : score 19.05%
# k 360 : score 19.05%
# k 361 : score 19.05%
# k 362 : score 19.05%
# k 363 : score 19.05%
# k 364 : score 19.05%
# k 365 : score 19.05%
# k 366 : score 19.05%
# k 367 : score 19.05%
# k 368 : score 19.05%
# k 369 : score 19.05%
# k 370 : score 19.05%
# k 371 : score 19.05%
# k 372 : score 19.05%
# k 373 : score 19.05%
# k 374 : score 19.05%
# k 375 : score 19.05%
# k 376 : score 19.05%
# k 377 : score 19.05%
# k 378 : score 19.05%
# k 379 : score 19.05%
# k 380 : score 19.05%
# k 381 : score 19.05%
# k 382 : score 19.05%
# k 383 : score 19.05%
# k 384 : score 19.05%
# k 385 : score 19.05%
# k 386 : score 19.05%
# k 387 : score 19.05%
# k 388 : score 19.05%
# k 389 : score 19.05%
# k 390 : score 19.05%
# k 391 : score 19.05%
# k 392 : score 19.05%
# k 393 : score 19.05%
# k 394 : score 19.05%
# k 395 : score 19.05%
# k 396 : score 19.05%
# k 397 : score 19.05%
# k 398 : score 19.05%
# k 399 : score 19.05%
# k 400 : score 19.05%
# k 401 : score 19.05%
# k 402 : score 19.05%
# k 403 : score 19.05%
# k 404 : score 19.05%
# k 405 : score 19.05%
# k 406 : score 19.05%
# k 407 : score 19.05%
# k 408 : score 19.05%
# k 409 : score 19.05%
# k 410 : score 19.05%
# k 411 : score 19.05%
# k 412 : score 19.05%
# k 413 : score 19.05%
# k 414 : score 19.05%
# k 415 : score 19.05%
# k 416 : score 19.05%
# k 417 : score 19.05%
# k 418 : score 19.05%
# k 419 : score 19.05%
# k 420 : score 19.05%
# k 421 : score 19.05%
# k 422 : score 19.05%
# k 423 : score 19.05%
# k 424 : score 19.05%
# k 425 : score 19.05%
# k 426 : score 19.05%
# k 427 : score 19.05%
# k 428 : score 19.05%
# k 429 : score 19.05%
# k 430 : score 19.05%
# k 431 : score 19.05%
# k 432 : score 19.05%
# k 433 : score 19.05%
# k 434 : score 19.05%
# k 435 : score 19.05%
# k 436 : score 19.05%
# k 437 : score 19.05%
# k 438 : score 19.05%
# k 439 : score 19.05%
# k 440 : score 19.05%
# k 441 : score 19.05%
# k 442 : score 19.05%
# k 443 : score 19.05%
# k 444 : score 19.05%
# k 445 : score 19.05%
# k 446 : score 19.05%
# k 447 : score 19.05%
# k 448 : score 19.05%
# k 449 : score 19.05%
# k 450 : score 19.05%
# k 451 : score 19.05%
# k 452 : score 19.05%
# k 453 : score 19.05%
# k 454 : score 19.05%
# k 455 : score 19.05%
# k 456 : score 19.05%
# k 457 : score 19.05%
# k 458 : score 19.05%
# k 459 : score 19.05%
# k 460 : score 19.05%
# k 461 : score 19.05%
# k 462 : score 19.05%
# k 463 : score 19.05%
# k 464 : score 19.05%
# k 465 : score 19.05%
# k 466 : score 19.05%
# k 467 : score 19.05%
# k 468 : score 19.05%
# k 469 : score 19.05%
# k 470 : score 19.05%
# k 471 : score 19.05%
# k 472 : score 19.05%
# k 473 : score 19.05%
# k 474 : score 19.05%
# k 475 : score 19.05%
# k 476 : score 20.24%
# k 477 : score 20.24%
# k 478 : score 20.24%
# k 479 : score 20.24%
# k 480 : score 20.24%
# k 481 : score 20.24%
# k 482 : score 20.24%
# k 483 : score 20.24%
# k 484 : score 20.24%
# k 485 : score 20.24%
# k 486 : score 20.24%
# k 487 : score 20.24%
# k 488 : score 20.24%
# k 489 : score 20.24%
# k 490 : score 20.24%
# k 491 : score 20.24%
# k 492 : score 20.24%
# k 493 : score 20.24%
# k 494 : score 20.24%
# k 495 : score 20.24%
# k 496 : score 21.43%
# k 497 : score 21.43%
# k 498 : score 21.43%
# k 499 : score 21.43%
# k 500 : score 21.43%
# k 501 : score 21.43%
# k 502 : score 21.43%
# k 503 : score 21.43%
# k 504 : score 21.43%
# k 505 : score 21.43%
# k 506 : score 21.43%
# k 507 : score 21.43%
# k 508 : score 21.43%
# k 509 : score 21.43%
# k 510 : score 21.43%
# k 511 : score 21.43%
# k 512 : score 21.43%
# k 513 : score 21.43%
# k 514 : score 21.43%
# k 515 : score 21.43%
# k 516 : score 21.43%
# k 517 : score 21.43%
# k 518 : score 21.43%
# k 519 : score 21.43%
# k 520 : score 21.43%
# k 521 : score 21.43%
# k 522 : score 21.43%
# k 523 : score 21.43%
# k 524 : score 21.43%
# k 525 : score 21.43%
# k 526 : score 21.43%
# k 527 : score 21.43%
# k 528 : score 21.43%
# k 529 : score 21.43%
# k 530 : score 21.43%
# k 531 : score 21.43%
# k 532 : score 21.43%
# k 533 : score 21.43%
# k 534 : score 21.43%
# k 535 : score 21.43%
# k 536 : score 21.43%
# k 537 : score 21.43%
# k 538 : score 21.43%
# k 539 : score 21.43%
# k 540 : score 21.43%
# k 541 : score 21.43%
# k 542 : score 21.43%
# k 543 : score 21.43%
# k 544 : score 21.43%
# k 545 : score 21.43%
# k 546 : score 21.43%
# k 547 : score 21.43%
# k 548 : score 21.43%
# k 549 : score 21.43%
# k 550 : score 21.43%
# k 551 : score 21.43%
# k 552 : score 21.43%
# k 553 : score 21.43%
# k 554 : score 21.43%
# k 555 : score 22.62%
# k 556 : score 22.62%
# k 557 : score 22.62%
# k 558 : score 22.62%
# k 559 : score 22.62%
# k 560 : score 22.62%
# k 561 : score 22.62%
# k 562 : score 22.62%
# k 563 : score 22.62%
# k 564 : score 22.62%
# k 565 : score 22.62%
# k 566 : score 22.62%
# k 567 : score 22.62%
# k 568 : score 22.62%
# k 569 : score 22.62%
# k 570 : score 22.62%
# k 571 : score 22.62%
# k 572 : score 22.62%
# k 573 : score 22.62%
# k 574 : score 22.62%
# k 575 : score 22.62%
# k 576 : score 22.62%
# k 577 : score 22.62%
# k 578 : score 22.62%
# k 579 : score 22.62%
# k 580 : score 22.62%
# k 581 : score 22.62%
# k 582 : score 22.62%
# k 583 : score 22.62%
# k 584 : score 22.62%
# k 585 : score 22.62%
# k 586 : score 22.62%
# k 587 : score 22.62%
# k 588 : score 22.62%
# k 589 : score 22.62%
# k 590 : score 22.62%
# k 591 : score 22.62%
# k 592 : score 22.62%
# k 593 : score 22.62%
# k 594 : score 22.62%
# k 595 : score 22.62%
# k 596 : score 22.62%
# k 597 : score 22.62%
# k 598 : score 22.62%
# k 599 : score 22.62%
# k 600 : score 22.62%
# k 601 : score 22.62%
# k 602 : score 22.62%
# k 603 : score 22.62%
# k 604 : score 22.62%
# k 605 : score 22.62%
# k 606 : score 22.62%
# k 607 : score 22.62%
# k 608 : score 22.62%
# k 609 : score 22.62%
# k 610 : score 22.62%
# k 611 : score 22.62%
# k 612 : score 22.62%
# k 613 : score 22.62%
# k 614 : score 22.62%
# k 615 : score 22.62%
# k 616 : score 22.62%
# k 617 : score 22.62%
# k 618 : score 22.62%
# k 619 : score 22.62%
# k 620 : score 22.62%
# k 621 : score 22.62%
# k 622 : score 22.62%
# k 623 : score 22.62%
# k 624 : score 22.62%
# k 625 : score 22.62%
# k 626 : score 22.62%
# k 627 : score 22.62%
# k 628 : score 22.62%
# k 629 : score 22.62%
# k 630 : score 22.62%
# k 631 : score 22.62%
# k 632 : score 22.62%
# k 633 : score 22.62%
# k 634 : score 22.62%
# k 635 : score 22.62%
# k 636 : score 22.62%
# k 637 : score 22.62%
# k 638 : score 22.62%
# k 639 : score 22.62%
# k 640 : score 22.62%
# k 641 : score 22.62%
# k 642 : score 22.62%
# k 643 : score 22.62%
# k 644 : score 22.62%
# k 645 : score 22.62%
# k 646 : score 22.62%
# k 647 : score 22.62%
# k 648 : score 22.62%
# k 649 : score 22.62%
# k 650 : score 22.62%
# k 651 : score 22.62%
# k 652 : score 22.62%
# k 653 : score 22.62%
# k 654 : score 22.62%
# k 655 : score 22.62%
# k 656 : score 22.62%
# k 657 : score 22.62%
# k 658 : score 22.62%
# k 659 : score 22.62%
# k 660 : score 22.62%
# k 661 : score 22.62%
# k 662 : score 22.62%
#
# [MAX SCORE] : k 555 : score 0.2261904761904762%
# total_length_of_absence_10.0th,absence_ratio_10.0th,discipline_incidents_10.0th,gpa_est_10.0th,age_10.0th,log_median_10.0th,diff_total_length_of_absence_10.0th,total_length_of_absence_9.0th,diff_total_length_of_absence_8.0th,length_of_unexcused_absence_10.0th,diff_absence_ratio_10.0th,unexcused_absence_ratio_10.0th,absence_ratio_9.0th,gender_M,log_pop_10.0th,unemp_rate_10.0th,discipline_incidents_9.0th,total_length_of_absence_8.0th,other_program_10.0th,missing_intervention_10.0th,age_8.0th,absence_ratio_8.0th,gpa_miss_10.0th,gpa_est_9.0th,eighth_read_pl_Miss,extra_program_10.0th,ogt_math_pl_1.0,school_yr_unemp_rate_10.0th,district_TriValley_10.0th,total_length_of_absence_7.0th,log_mean_10.0th,disability_none_10.0th,gender_F,sixth_science_pl_1.0,age_9.0th,log_pop_8.0th,district_Coshocton_10.0th,absence_consec_count_10.0th,log_median_8.0th,zip_43720_10.0th,special_education_10.0th,fourth_math_pl_1.0,unexcused_absence_ratio_9.0th,sixth_write_pl_1.0,missing_intervention_9.0th,gpa_est_8.0th,gpa_est_7.0th,diff_unexcused_absence_ratio_10.0th,disability_learning disability_9.0th,retained_8.0th,ogt_socstudies_pl_Miss,diff_length_of_unexcused_absence_10.0th,disability_learning disability_10.0th,fourth_ctz_pl_1.0,log_pop_9.0th,disadvantagement_economic_10.0th,log_mean_9.0th,advanced_program_9.0th,zip_43821_10.0th,disadvantagement_Miss_9.0th,district_Franklin_10.0th,unemp_rate_9.0th,school_yr_unemp_rate_9.0th,district_Maysville_10.0th,disability_cognitive disability_9.0th,zip_43822_10.0th,sixth_ctz_pl_1.0,sixth_science_pl_Miss,zip_43842_10.0th,school_yr_unemp_rate_7.0th,other_program_9.0th,log_median_9.0th,ogt_read_pl_Miss,fourth_read_pl_1.0,length_of_unexcused_absence_9.0th,gpa_miss_8.0th,diff_absence_ratio_9.0th,diff_total_length_of_absence_7.0th,disadvantagement_Miss_10.0th,zip_43844_9.0th,ogt_write_pl_Miss,zip_43812_10.0th,advanced_program_10.0th,eighth_science_pl_Miss,sixth_read_pl_Miss,ogt_science_pl_Miss,sixth_write_pl_Miss,fourth_science_pl_Miss,zip_43735_9.0th,seventh_math_pl_Miss,extra_program_8.0th,retained_10.0th,zip_43821_9.0th,zip_43845_10.0th,fourth_write_pl_1.0,zip_43739_10.0th,district_Coshocton_8.0th,absence_suspension_10.0th,eighth_science_pl_1.0,missing_intervention_7.0th,fourth_science_pl_1.0,disability_Miss_10.0th,special_education_9.0th,seventh_read_pl_Miss,missing_intervention_8.0th,disadvantagement_economic_9.0th,log_mean_7.0th,district_Riverview_10.0th,disability_other minor_10.0th,sixth_read_pl_1.0,family_school_career_program_10.0th,sixth_ctz_pl_Miss,district_Coshocton_9.0th,zip_43843_10.0th,zip_43812_9.0th,discipline_incidents_8.0th,zip_43701_9.0th,extra_program_9.0th,age_7.0th,absence_suspension_9.0th,zip_43844_10.0th,limited_english_f_9.0th,disability_cognitive disability_8.0th,district_TriValley_9.0th,fourth_write_pl_Miss,district_Maysville_9.0th,limited_english_f_10.0th,district_Ridgewood_10.0th,fourth_math_pl_Miss,zip_43845_9.0th,log_pop_miss_7.0th,disability_none_9.0th,zip_43821_8.0th,zip_43830_10.0th,zip_0_8.0th,disability_cognitive disability_10.0th,zip_43701_10.0th,district_Ridgewood_9.0th,absence_consec_count_9.0th,tardy_consec_count_9.0th,fourth_ctz_pl_Miss,disability_emotional disturbance_10.0th,disadvantagement_Miss_8.0th,ogt_science_pl_1.0,ogt_write_pl_1.0,gpa_miss_9.0th,log_median_miss_7.0th,log_pop_miss_8.0th,district_TriValley_7.0th,diff_absence_ratio_8.0th,ogt_math_pl_Miss,disability_Miss_9.0th,seventh_read_pl_1.0,district_Riverview_9.0th,disability_none_8.0th,disability_multiple_8.0th,special_education_8.0th,eighth_math_pl_Miss,ethnicity_B,log_mean_8.0th,eighth_read_pl_1.0,gpa_miss_7.0th,diff_total_length_of_absence_9.0th,ogt_socstudies_pl_1.0,limited_english_Miss_10.0th,eighth_math_pl_1.0,district_Maysville_8.0th,retained_9.0th,log_mean_miss_9.0th,log_pop_miss_9.0th,zip_43822_8.0th,seventh_write_pl_Miss,days_tardy_10.0th,zip_0_9.0th,limited_english_Miss_9.0th,zip_43055_10.0th,seventh_math_pl_1.0,zip_43701_8.0th,zip_43777_10.0th,sixth_math_pl_1.0,ethnicity_W,zip_43056_8.0th,district_Franklin ...

# %%
recall_get_feature_importance(x_train, y_train, x_test, y_test, DT)
# Out:
# k   1 : score 10.71%
# k   2 : score 30.95%
# k   3 : score 57.14%
# k   4 : score 83.33%
# k   5 : score 85.71%
# k   6 : score 89.29%
# k   7 : score 96.43%
# k   8 : score 97.62%
# k   9 : score 98.81%
# k  10 : score 98.81%
# k  11 : score 98.81%
# k  12 : score 98.81%
# k  13 : score 98.81%
# k  14 : score 98.81%
# k  15 : score 98.81%
# k  16 : score 98.81%
# k  17 : score 98.81%
# k  18 : score 98.81%
# k  19 : score 98.81%
# k  20 : score 98.81%
# k  21 : score 98.81%
# k  22 : score 98.81%
# k  23 : score 98.81%
# k  24 : score 98.81%
# k  25 : score 100.00%
# k  26 : score 100.00%
# k  27 : score 100.00%
# k  28 : score 100.00%
# k  29 : score 100.00%
# k  30 : score 100.00%
# k  31 : score 100.00%
# k  32 : score 100.00%
# k  33 : score 100.00%
# k  34 : score 100.00%
# k  35 : score 100.00%
# k  36 : score 100.00%
# k  37 : score 100.00%
# k  38 : score 100.00%
# k  39 : score 100.00%
# k  40 : score 100.00%
# k  41 : score 100.00%
# k  42 : score 100.00%
# k  43 : score 100.00%
# k  44 : score 100.00%
# k  45 : score 100.00%
# k  46 : score 100.00%
# k  47 : score 100.00%
# k  48 : score 100.00%
# k  49 : score 100.00%
# k  50 : score 100.00%
# k  51 : score 100.00%
# k  52 : score 100.00%
# k  53 : score 100.00%
# k  54 : score 100.00%
# k  55 : score 100.00%
# k  56 : score 100.00%
# k  57 : score 100.00%
# k  58 : score 100.00%
# k  59 : score 100.00%
# k  60 : score 100.00%
# k  61 : score 100.00%
# k  62 : score 100.00%
# k  63 : score 100.00%
# k  64 : score 100.00%
# k  65 : score 100.00%
# k  66 : score 100.00%
# k  67 : score 100.00%
# k  68 : score 100.00%
# k  69 : score 100.00%
# k  70 : score 100.00%
# k  71 : score 100.00%
# k  72 : score 100.00%
# k  73 : score 100.00%
# k  74 : score 100.00%
# k  75 : score 100.00%
# k  76 : score 100.00%
# k  77 : score 100.00%
# k  78 : score 100.00%
# k  79 : score 100.00%
# k  80 : score 100.00%
# k  81 : score 100.00%
# k  82 : score 100.00%
# k  83 : score 100.00%
# k  84 : score 100.00%
# k  85 : score 100.00%
# k  86 : score 100.00%
# k  87 : score 100.00%
# k  88 : score 100.00%
# k  89 : score 100.00%
# k  90 : score 100.00%
# k  91 : score 100.00%
# k  92 : score 100.00%
# k  93 : score 100.00%
# k  94 : score 100.00%
# k  95 : score 100.00%
# k  96 : score 100.00%
# k  97 : score 100.00%
# k  98 : score 100.00%
# k  99 : score 100.00%
# k 100 : score 100.00%
# k 101 : score 100.00%
# k 102 : score 100.00%
# k 103 : score 100.00%
# k 104 : score 100.00%
# k 105 : score 100.00%
# k 106 : score 100.00%
# k 107 : score 100.00%
# k 108 : score 100.00%
# k 109 : score 100.00%
# k 110 : score 100.00%
# k 111 : score 100.00%
# k 112 : score 100.00%
# k 113 : score 100.00%
# k 114 : score 100.00%
# k 115 : score 100.00%
# k 116 : score 100.00%
# k 117 : score 100.00%
# k 118 : score 100.00%
# k 119 : score 100.00%
# k 120 : score 100.00%
# k 121 : score 100.00%
# k 122 : score 100.00%
# k 123 : score 100.00%
# k 124 : score 100.00%
# k 125 : score 100.00%
# k 126 : score 100.00%
# k 127 : score 100.00%
# k 128 : score 100.00%
# k 129 : score 100.00%
# k 130 : score 100.00%
# k 131 : score 100.00%
# k 132 : score 100.00%
# k 133 : score 100.00%
# k 134 : score 100.00%
# k 135 : score 100.00%
# k 136 : score 100.00%
# k 137 : score 100.00%
# k 138 : score 100.00%
# k 139 : score 100.00%
# k 140 : score 100.00%
# k 141 : score 100.00%
# k 142 : score 100.00%
# k 143 : score 100.00%
# k 144 : score 100.00%
# k 145 : score 100.00%
# k 146 : score 100.00%
# k 147 : score 100.00%
# k 148 : score 100.00%
# k 149 : score 100.00%
# k 150 : score 100.00%
# k 151 : score 100.00%
# k 152 : score 100.00%
# k 153 : score 100.00%
# k 154 : score 100.00%
# k 155 : score 100.00%
# k 156 : score 100.00%
# k 157 : score 100.00%
# k 158 : score 100.00%
# k 159 : score 100.00%
# k 160 : score 100.00%
# k 161 : score 100.00%
# k 162 : score 100.00%
# k 163 : score 100.00%
# k 164 : score 100.00%
# k 165 : score 100.00%
# k 166 : score 100.00%
# k 167 : score 100.00%
# k 168 : score 100.00%
# k 169 : score 100.00%
# k 170 : score 100.00%
# k 171 : score 100.00%
# k 172 : score 100.00%
# k 173 : score 100.00%
# k 174 : score 100.00%
# k 175 : score 100.00%
# k 176 : score 100.00%
# k 177 : score 100.00%
# k 178 : score 100.00%
# k 179 : score 100.00%
# k 180 : score 100.00%
# k 181 : score 100.00%
# k 182 : score 100.00%
# k 183 : score 100.00%
# k 184 : score 100.00%
# k 185 : score 100.00%
# k 186 : score 100.00%
# k 187 : score 100.00%
# k 188 : score 100.00%
# k 189 : score 100.00%
# k 190 : score 100.00%
# k 191 : score 100.00%
# k 192 : score 100.00%
# k 193 : score 100.00%
# k 194 : score 100.00%
# k 195 : score 100.00%
# k 196 : score 100.00%
# k 197 : score 100.00%
# k 198 : score 100.00%
# k 199 : score 100.00%
# k 200 : score 100.00%
# k 201 : score 100.00%
# k 202 : score 100.00%
# k 203 : score 100.00%
# k 204 : score 100.00%
# k 205 : score 100.00%
# k 206 : score 100.00%
# k 207 : score 100.00%
# k 208 : score 100.00%
# k 209 : score 100.00%
# k 210 : score 100.00%
# k 211 : score 100.00%
# k 212 : score 100.00%
# k 213 : score 100.00%
# k 214 : score 100.00%
# k 215 : score 100.00%
# k 216 : score 100.00%
# k 217 : score 100.00%
# k 218 : score 100.00%
# k 219 : score 100.00%
# k 220 : score 100.00%
# k 221 : score 100.00%
# k 222 : score 100.00%
# k 223 : score 100.00%
# k 224 : score 100.00%
# k 225 : score 100.00%
# k 226 : score 100.00%
# k 227 : score 100.00%
# k 228 : score 100.00%
# k 229 : score 100.00%
# k 230 : score 100.00%
# k 231 : score 100.00%
# k 232 : score 100.00%
# k 233 : score 100.00%
# k 234 : score 100.00%
# k 235 : score 100.00%
# k 236 : score 100.00%
# k 237 : score 100.00%
# k 238 : score 100.00%
# k 239 : score 100.00%
# k 240 : score 100.00%
# k 241 : score 100.00%
# k 242 : score 100.00%
# k 243 : score 100.00%
# k 244 : score 100.00%
# k 245 : score 100.00%
# k 246 : score 100.00%
# k 247 : score 100.00%
# k 248 : score 100.00%
# k 249 : score 100.00%
# k 250 : score 100.00%
# k 251 : score 100.00%
# k 252 : score 100.00%
# k 253 : score 100.00%
# k 254 : score 100.00%
# k 255 : score 100.00%
# k 256 : score 100.00%
# k 257 : score 100.00%
# k 258 : score 100.00%
# k 259 : score 100.00%
# k 260 : score 100.00%
# k 261 : score 100.00%
# k 262 : score 100.00%
# k 263 : score 100.00%
# k 264 : score 100.00%
# k 265 : score 100.00%
# k 266 : score 100.00%
# k 267 : score 100.00%
# k 268 : score 100.00%
# k 269 : score 100.00%
# k 270 : score 100.00%
# k 271 : score 100.00%
# k 272 : score 100.00%
# k 273 : score 100.00%
# k 274 : score 100.00%
# k 275 : score 100.00%
# k 276 : score 100.00%
# k 277 : score 100.00%
# k 278 : score 100.00%
# k 279 : score 100.00%
# k 280 : score 100.00%
# k 281 : score 100.00%
# k 282 : score 100.00%
# k 283 : score 100.00%
# k 284 : score 100.00%
# k 285 : score 100.00%
# k 286 : score 100.00%
# k 287 : score 100.00%
# k 288 : score 100.00%
# k 289 : score 100.00%
# k 290 : score 100.00%
# k 291 : score 100.00%
# k 292 : score 100.00%
# k 293 : score 100.00%
# k 294 : score 100.00%
# k 295 : score 100.00%
# k 296 : score 100.00%
# k 297 : score 100.00%
# k 298 : score 100.00%
# k 299 : score 100.00%
# k 300 : score 100.00%
# k 301 : score 100.00%
# k 302 : score 100.00%
# k 303 : score 100.00%
# k 304 : score 100.00%
# k 305 : score 100.00%
# k 306 : score 100.00%
# k 307 : score 100.00%
# k 308 : score 100.00%
# k 309 : score 100.00%
# k 310 : score 100.00%
# k 311 : score 100.00%
# k 312 : score 100.00%
# k 313 : score 100.00%
# k 314 : score 100.00%
# k 315 : score 100.00%
# k 316 : score 100.00%
# k 317 : score 100.00%
# k 318 : score 100.00%
# k 319 : score 100.00%
# k 320 : score 100.00%
# k 321 : score 100.00%
# k 322 : score 100.00%
# k 323 : score 100.00%
# k 324 : score 100.00%
# k 325 : score 100.00%
# k 326 : score 100.00%
# k 327 : score 100.00%
# k 328 : score 100.00%
# k 329 : score 100.00%
# k 330 : score 100.00%
# k 331 : score 100.00%
# k 332 : score 100.00%
# k 333 : score 100.00%
# k 334 : score 100.00%
# k 335 : score 100.00%
# k 336 : score 100.00%
# k 337 : score 100.00%
# k 338 : score 100.00%
# k 339 : score 100.00%
# k 340 : score 100.00%
# k 341 : score 100.00%
# k 342 : score 100.00%
# k 343 : score 100.00%
# k 344 : score 100.00%
# k 345 : score 100.00%
# k 346 : score 100.00%
# k 347 : score 100.00%
# k 348 : score 100.00%
# k 349 : score 100.00%
# k 350 : score 100.00%
# k 351 : score 100.00%
# k 352 : score 100.00%
# k 353 : score 100.00%
# k 354 : score 100.00%
# k 355 : score 100.00%
# k 356 : score 100.00%
# k 357 : score 100.00%
# k 358 : score 100.00%
# k 359 : score 100.00%
# k 360 : score 100.00%
# k 361 : score 100.00%
# k 362 : score 100.00%
# k 363 : score 100.00%
# k 364 : score 100.00%
# k 365 : score 100.00%
# k 366 : score 100.00%
# k 367 : score 100.00%
# k 368 : score 100.00%
# k 369 : score 100.00%
# k 370 : score 100.00%
# k 371 : score 100.00%
# k 372 : score 100.00%
# k 373 : score 100.00%
# k 374 : score 100.00%
# k 375 : score 100.00%
# k 376 : score 100.00%
# k 377 : score 100.00%
# k 378 : score 100.00%
# k 379 : score 100.00%
# k 380 : score 100.00%
# k 381 : score 100.00%
# k 382 : score 100.00%
# k 383 : score 100.00%
# k 384 : score 100.00%
# k 385 : score 100.00%
# k 386 : score 100.00%
# k 387 : score 100.00%
# k 388 : score 100.00%
# k 389 : score 100.00%
# k 390 : score 100.00%
# k 391 : score 100.00%
# k 392 : score 100.00%
# k 393 : score 100.00%
# k 394 : score 100.00%
# k 395 : score 100.00%
# k 396 : score 100.00%
# k 397 : score 100.00%
# k 398 : score 100.00%
# k 399 : score 100.00%
# k 400 : score 100.00%
# k 401 : score 100.00%
# k 402 : score 100.00%
# k 403 : score 100.00%
# k 404 : score 100.00%
# k 405 : score 100.00%
# k 406 : score 100.00%
# k 407 : score 100.00%
# k 408 : score 100.00%
# k 409 : score 100.00%
# k 410 : score 100.00%
# k 411 : score 100.00%
# k 412 : score 100.00%
# k 413 : score 100.00%
# k 414 : score 100.00%
# k 415 : score 100.00%
# k 416 : score 100.00%
# k 417 : score 100.00%
# k 418 : score 100.00%
# k 419 : score 100.00%
# k 420 : score 100.00%
# k 421 : score 100.00%
# k 422 : score 100.00%
# k 423 : score 100.00%
# k 424 : score 100.00%
# k 425 : score 100.00%
# k 426 : score 100.00%
# k 427 : score 100.00%
# k 428 : score 100.00%
# k 429 : score 100.00%
# k 430 : score 100.00%
# k 431 : score 100.00%
# k 432 : score 100.00%
# k 433 : score 100.00%
# k 434 : score 100.00%
# k 435 : score 100.00%
# k 436 : score 100.00%
# k 437 : score 100.00%
# k 438 : score 100.00%
# k 439 : score 100.00%
# k 440 : score 100.00%
# k 441 : score 100.00%
# k 442 : score 100.00%
# k 443 : score 100.00%
# k 444 : score 100.00%
# k 445 : score 100.00%
# k 446 : score 100.00%
# k 447 : score 100.00%
# k 448 : score 100.00%
# k 449 : score 100.00%
# k 450 : score 100.00%
# k 451 : score 100.00%
# k 452 : score 100.00%
# k 453 : score 100.00%
# k 454 : score 100.00%
# k 455 : score 100.00%
# k 456 : score 100.00%
# k 457 : score 100.00%
# k 458 : score 100.00%
# k 459 : score 100.00%
# k 460 : score 100.00%
# k 461 : score 100.00%
# k 462 : score 100.00%
# k 463 : score 100.00%
# k 464 : score 100.00%
# k 465 : score 100.00%
# k 466 : score 100.00%
# k 467 : score 100.00%
# k 468 : score 100.00%
# k 469 : score 100.00%
# k 470 : score 100.00%
# k 471 : score 100.00%
# k 472 : score 100.00%
# k 473 : score 100.00%
# k 474 : score 100.00%
# k 475 : score 100.00%
# k 476 : score 100.00%
# k 477 : score 100.00%
# k 478 : score 100.00%
# k 479 : score 100.00%
# k 480 : score 100.00%
# k 481 : score 100.00%
# k 482 : score 100.00%
# k 483 : score 100.00%
# k 484 : score 100.00%
# k 485 : score 100.00%
# k 486 : score 100.00%
# k 487 : score 100.00%
# k 488 : score 100.00%
# k 489 : score 100.00%
# k 490 : score 100.00%
# k 491 : score 100.00%
# k 492 : score 100.00%
# k 493 : score 100.00%
# k 494 : score 100.00%
# k 495 : score 100.00%
# k 496 : score 100.00%
# k 497 : score 100.00%
# k 498 : score 100.00%
# k 499 : score 100.00%
# k 500 : score 100.00%
# k 501 : score 100.00%
# k 502 : score 100.00%
# k 503 : score 100.00%
# k 504 : score 100.00%
# k 505 : score 100.00%
# k 506 : score 100.00%
# k 507 : score 100.00%
# k 508 : score 100.00%
# k 509 : score 100.00%
# k 510 : score 100.00%
# k 511 : score 100.00%
# k 512 : score 100.00%
# k 513 : score 100.00%
# k 514 : score 100.00%
# k 515 : score 100.00%
# k 516 : score 100.00%
# k 517 : score 100.00%
# k 518 : score 100.00%
# k 519 : score 100.00%
# k 520 : score 100.00%
# k 521 : score 100.00%
# k 522 : score 100.00%
# k 523 : score 100.00%
# k 524 : score 100.00%
# k 525 : score 100.00%
# k 526 : score 100.00%
# k 527 : score 100.00%
# k 528 : score 100.00%
# k 529 : score 100.00%
# k 530 : score 100.00%
# k 531 : score 100.00%
# k 532 : score 100.00%
# k 533 : score 100.00%
# k 534 : score 100.00%
# k 535 : score 100.00%
# k 536 : score 100.00%
# k 537 : score 100.00%
# k 538 : score 100.00%
# k 539 : score 100.00%
# k 540 : score 100.00%
# k 541 : score 100.00%
# k 542 : score 100.00%
# k 543 : score 100.00%
# k 544 : score 100.00%
# k 545 : score 100.00%
# k 546 : score 100.00%
# k 547 : score 100.00%
# k 548 : score 100.00%
# k 549 : score 100.00%
# k 550 : score 100.00%
# k 551 : score 100.00%
# k 552 : score 100.00%
# k 553 : score 100.00%
# k 554 : score 100.00%
# k 555 : score 100.00%
# k 556 : score 100.00%
# k 557 : score 100.00%
# k 558 : score 100.00%
# k 559 : score 100.00%
# k 560 : score 100.00%
# k 561 : score 100.00%
# k 562 : score 100.00%
# k 563 : score 100.00%
# k 564 : score 100.00%
# k 565 : score 100.00%
# k 566 : score 100.00%
# k 567 : score 100.00%
# k 568 : score 100.00%
# k 569 : score 100.00%
# k 570 : score 100.00%
# k 571 : score 100.00%
# k 572 : score 100.00%
# k 573 : score 100.00%
# k 574 : score 100.00%
# k 575 : score 100.00%
# k 576 : score 100.00%
# k 577 : score 100.00%
# k 578 : score 100.00%
# k 579 : score 100.00%
# k 580 : score 100.00%
# k 581 : score 100.00%
# k 582 : score 100.00%
# k 583 : score 100.00%
# k 584 : score 100.00%
# k 585 : score 100.00%
# k 586 : score 100.00%
# k 587 : score 100.00%
# k 588 : score 100.00%
# k 589 : score 100.00%
# k 590 : score 100.00%
# k 591 : score 100.00%
# k 592 : score 100.00%
# k 593 : score 100.00%
# k 594 : score 100.00%
# k 595 : score 100.00%
# k 596 : score 100.00%
# k 597 : score 100.00%
# k 598 : score 100.00%
# k 599 : score 100.00%
# k 600 : score 100.00%
# k 601 : score 100.00%
# k 602 : score 100.00%
# k 603 : score 100.00%
# k 604 : score 100.00%
# k 605 : score 100.00%
# k 606 : score 100.00%
# k 607 : score 100.00%
# k 608 : score 100.00%
# k 609 : score 100.00%
# k 610 : score 100.00%
# k 611 : score 100.00%
# k 612 : score 100.00%
# k 613 : score 100.00%
# k 614 : score 100.00%
# k 615 : score 100.00%
# k 616 : score 100.00%
# k 617 : score 100.00%
# k 618 : score 100.00%
# k 619 : score 100.00%
# k 620 : score 100.00%
# k 621 : score 100.00%
# k 622 : score 100.00%
# k 623 : score 100.00%
# k 624 : score 100.00%
# k 625 : score 100.00%
# k 626 : score 100.00%
# k 627 : score 100.00%
# k 628 : score 100.00%
# k 629 : score 100.00%
# k 630 : score 100.00%
# k 631 : score 100.00%
# k 632 : score 100.00%
# k 633 : score 100.00%
# k 634 : score 100.00%
# k 635 : score 100.00%
# k 636 : score 100.00%
# k 637 : score 100.00%
# k 638 : score 100.00%
# k 639 : score 100.00%
# k 640 : score 100.00%
# k 641 : score 100.00%
# k 642 : score 100.00%
# k 643 : score 100.00%
# k 644 : score 100.00%
# k 645 : score 100.00%
# k 646 : score 100.00%
# k 647 : score 100.00%
# k 648 : score 100.00%
# k 649 : score 100.00%
# k 650 : score 100.00%
# k 651 : score 100.00%
# k 652 : score 100.00%
# k 653 : score 100.00%
# k 654 : score 100.00%
# k 655 : score 100.00%
# k 656 : score 100.00%
# k 657 : score 100.00%
# k 658 : score 100.00%
# k 659 : score 100.00%
# k 660 : score 100.00%
# k 661 : score 100.00%
# k 662 : score 100.00%
#
# [MAX SCORE] : k 25 : score 1.0%
# total_length_of_absence_10.0th,absence_ratio_10.0th,discipline_incidents_10.0th,gpa_est_10.0th,age_10.0th,log_median_10.0th,diff_total_length_of_absence_10.0th,total_length_of_absence_9.0th,diff_total_length_of_absence_8.0th,length_of_unexcused_absence_10.0th,diff_absence_ratio_10.0th,unexcused_absence_ratio_10.0th,absence_ratio_9.0th,gender_M,log_pop_10.0th,unemp_rate_10.0th,discipline_incidents_9.0th,total_length_of_absence_8.0th,other_program_10.0th,missing_intervention_10.0th,age_8.0th,absence_ratio_8.0th,gpa_miss_10.0th,gpa_est_9.0th,eighth_read_pl_Miss

# %%
recall_get_feature_importance(x_train, y_train, x_test, y_test, AB)
# Out:
# k   1 : score  1.19%
# k   2 : score  2.38%
# k   3 : score  7.14%
# k   4 : score  7.14%
# k   5 : score 10.71%
# k   6 : score 10.71%
# k   7 : score 10.71%
# k   8 : score 11.90%
# k   9 : score 11.90%
# k  10 : score 11.90%
# k  11 : score 11.90%
# k  12 : score 11.90%
# k  13 : score 11.90%
# k  14 : score 11.90%
# k  15 : score 11.90%
# k  16 : score 11.90%
# k  17 : score 11.90%
# k  18 : score 11.90%
# k  19 : score 14.29%
# k  20 : score 14.29%
# k  21 : score 14.29%
# k  22 : score 14.29%
# k  23 : score 14.29%
# k  24 : score 14.29%
# k  25 : score 14.29%
# k  26 : score 14.29%
# k  27 : score 14.29%
# k  28 : score 14.29%
# k  29 : score 14.29%
# k  30 : score 14.29%
# k  31 : score 15.48%
# k  32 : score 15.48%
# k  33 : score 15.48%
# k  34 : score 15.48%
# k  35 : score 15.48%
# k  36 : score 15.48%
# k  37 : score 15.48%
# k  38 : score 15.48%
# k  39 : score 15.48%
# k  40 : score 15.48%
# k  41 : score 15.48%
# k  42 : score 15.48%
# k  43 : score 15.48%
# k  44 : score 15.48%
# k  45 : score 15.48%
# k  46 : score 15.48%
# k  47 : score 15.48%
# k  48 : score 16.67%
# k  49 : score 16.67%
# k  50 : score 16.67%
# k  51 : score 16.67%
# k  52 : score 16.67%
# k  53 : score 16.67%
# k  54 : score 17.86%
# k  55 : score 17.86%
# k  56 : score 19.05%
# k  57 : score 19.05%
# k  58 : score 19.05%
# k  59 : score 19.05%
# k  60 : score 19.05%
# k  61 : score 19.05%
# k  62 : score 19.05%
# k  63 : score 19.05%
# k  64 : score 19.05%
# k  65 : score 19.05%
# k  66 : score 19.05%
# k  67 : score 19.05%
# k  68 : score 19.05%
# k  69 : score 19.05%
# k  70 : score 19.05%
# k  71 : score 19.05%
# k  72 : score 19.05%
# k  73 : score 19.05%
# k  74 : score 19.05%
# k  75 : score 19.05%
# k  76 : score 19.05%
# k  77 : score 19.05%
# k  78 : score 19.05%
# k  79 : score 22.62%
# k  80 : score 22.62%
# k  81 : score 22.62%
# k  82 : score 22.62%
# k  83 : score 22.62%
# k  84 : score 22.62%
# k  85 : score 22.62%
# k  86 : score 22.62%
# k  87 : score 22.62%
# k  88 : score 22.62%
# k  89 : score 22.62%
# k  90 : score 22.62%
# k  91 : score 22.62%
# k  92 : score 22.62%
# k  93 : score 22.62%
# k  94 : score 22.62%
# k  95 : score 22.62%
# k  96 : score 22.62%
# k  97 : score 22.62%
# k  98 : score 22.62%
# k  99 : score 22.62%
# k 100 : score 22.62%
# k 101 : score 22.62%
# k 102 : score 22.62%
# k 103 : score 22.62%
# k 104 : score 22.62%
# k 105 : score 22.62%
# k 106 : score 22.62%
# k 107 : score 22.62%
# k 108 : score 22.62%
# k 109 : score 22.62%
# k 110 : score 22.62%
# k 111 : score 22.62%
# k 112 : score 22.62%
# k 113 : score 22.62%
# k 114 : score 22.62%
# k 115 : score 22.62%
# k 116 : score 22.62%
# k 117 : score 22.62%
# k 118 : score 22.62%
# k 119 : score 23.81%
# k 120 : score 23.81%
# k 121 : score 23.81%
# k 122 : score 23.81%
# k 123 : score 23.81%
# k 124 : score 23.81%
# k 125 : score 23.81%
# k 126 : score 23.81%
# k 127 : score 23.81%
# k 128 : score 23.81%
# k 129 : score 23.81%
# k 130 : score 23.81%
# k 131 : score 23.81%
# k 132 : score 23.81%
# k 133 : score 23.81%
# k 134 : score 23.81%
# k 135 : score 23.81%
# k 136 : score 23.81%
# k 137 : score 23.81%
# k 138 : score 23.81%
# k 139 : score 23.81%
# k 140 : score 23.81%
# k 141 : score 23.81%
# k 142 : score 23.81%
# k 143 : score 23.81%
# k 144 : score 23.81%
# k 145 : score 23.81%
# k 146 : score 23.81%
# k 147 : score 23.81%
# k 148 : score 23.81%
# k 149 : score 23.81%
# k 150 : score 23.81%
# k 151 : score 23.81%
# k 152 : score 23.81%
# k 153 : score 23.81%
# k 154 : score 23.81%
# k 155 : score 23.81%
# k 156 : score 23.81%
# k 157 : score 23.81%
# k 158 : score 23.81%
# k 159 : score 23.81%
# k 160 : score 23.81%
# k 161 : score 23.81%
# k 162 : score 23.81%
# k 163 : score 23.81%
# k 164 : score 23.81%
# k 165 : score 23.81%
# k 166 : score 23.81%
# k 167 : score 23.81%
# k 168 : score 23.81%
# k 169 : score 23.81%
# k 170 : score 23.81%
# k 171 : score 23.81%
# k 172 : score 23.81%
# k 173 : score 23.81%
# k 174 : score 23.81%
# k 175 : score 23.81%
# k 176 : score 23.81%
# k 177 : score 23.81%
# k 178 : score 23.81%
# k 179 : score 23.81%
# k 180 : score 23.81%
# k 181 : score 23.81%
# k 182 : score 23.81%
# k 183 : score 23.81%
# k 184 : score 23.81%
# k 185 : score 23.81%
# k 186 : score 23.81%
# k 187 : score 23.81%
# k 188 : score 23.81%
# k 189 : score 23.81%
# k 190 : score 23.81%
# k 191 : score 23.81%
# k 192 : score 23.81%
# k 193 : score 23.81%
# k 194 : score 23.81%
# k 195 : score 23.81%
# k 196 : score 23.81%
# k 197 : score 23.81%
# k 198 : score 23.81%
# k 199 : score 23.81%
# k 200 : score 23.81%
# k 201 : score 23.81%
# k 202 : score 23.81%
# k 203 : score 23.81%
# k 204 : score 23.81%
# k 205 : score 23.81%
# k 206 : score 23.81%
# k 207 : score 23.81%
# k 208 : score 23.81%
# k 209 : score 23.81%
# k 210 : score 23.81%
# k 211 : score 23.81%
# k 212 : score 23.81%
# k 213 : score 23.81%
# k 214 : score 23.81%
# k 215 : score 23.81%
# k 216 : score 23.81%
# k 217 : score 23.81%
# k 218 : score 23.81%
# k 219 : score 23.81%
# k 220 : score 23.81%
# k 221 : score 23.81%
# k 222 : score 23.81%
# k 223 : score 23.81%
# k 224 : score 23.81%
# k 225 : score 23.81%
# k 226 : score 23.81%
# k 227 : score 23.81%
# k 228 : score 23.81%
# k 229 : score 23.81%
# k 230 : score 23.81%
# k 231 : score 23.81%
# k 232 : score 23.81%
# k 233 : score 23.81%
# k 234 : score 23.81%
# k 235 : score 23.81%
# k 236 : score 23.81%
# k 237 : score 23.81%
# k 238 : score 23.81%
# k 239 : score 23.81%
# k 240 : score 23.81%
# k 241 : score 23.81%
# k 242 : score 23.81%
# k 243 : score 23.81%
# k 244 : score 23.81%
# k 245 : score 23.81%
# k 246 : score 23.81%
# k 247 : score 23.81%
# k 248 : score 23.81%
# k 249 : score 23.81%
# k 250 : score 23.81%
# k 251 : score 23.81%
# k 252 : score 23.81%
# k 253 : score 23.81%
# k 254 : score 23.81%
# k 255 : score 23.81%
# k 256 : score 23.81%
# k 257 : score 23.81%
# k 258 : score 23.81%
# k 259 : score 23.81%
# k 260 : score 23.81%
# k 261 : score 23.81%
# k 262 : score 23.81%
# k 263 : score 23.81%
# k 264 : score 23.81%
# k 265 : score 23.81%
# k 266 : score 23.81%
# k 267 : score 23.81%
# k 268 : score 23.81%
# k 269 : score 23.81%
# k 270 : score 23.81%
# k 271 : score 23.81%
# k 272 : score 23.81%
# k 273 : score 23.81%
# k 274 : score 23.81%
# k 275 : score 23.81%
# k 276 : score 23.81%
# k 277 : score 23.81%
# k 278 : score 23.81%
# k 279 : score 23.81%
# k 280 : score 23.81%
# k 281 : score 23.81%
# k 282 : score 23.81%
# k 283 : score 23.81%
# k 284 : score 23.81%
# k 285 : score 23.81%
# k 286 : score 23.81%
# k 287 : score 23.81%
# k 288 : score 23.81%
# k 289 : score 23.81%
# k 290 : score 23.81%
# k 291 : score 23.81%
# k 292 : score 23.81%
# k 293 : score 23.81%
# k 294 : score 23.81%
# k 295 : score 23.81%
# k 296 : score 23.81%
# k 297 : score 23.81%
# k 298 : score 23.81%
# k 299 : score 23.81%
# k 300 : score 23.81%
# k 301 : score 23.81%
# k 302 : score 23.81%
# k 303 : score 23.81%
# k 304 : score 23.81%
# k 305 : score 23.81%
# k 306 : score 23.81%
# k 307 : score 23.81%
# k 308 : score 23.81%
# k 309 : score 23.81%
# k 310 : score 23.81%
# k 311 : score 23.81%
# k 312 : score 23.81%
# k 313 : score 23.81%
# k 314 : score 23.81%
# k 315 : score 23.81%
# k 316 : score 23.81%
# k 317 : score 23.81%
# k 318 : score 23.81%
# k 319 : score 23.81%
# k 320 : score 23.81%
# k 321 : score 23.81%
# k 322 : score 23.81%
# k 323 : score 23.81%
# k 324 : score 23.81%
# k 325 : score 23.81%
# k 326 : score 23.81%
# k 327 : score 23.81%
# k 328 : score 23.81%
# k 329 : score 23.81%
# k 330 : score 23.81%
# k 331 : score 23.81%
# k 332 : score 23.81%
# k 333 : score 23.81%
# k 334 : score 23.81%
# k 335 : score 23.81%
# k 336 : score 23.81%
# k 337 : score 23.81%
# k 338 : score 23.81%
# k 339 : score 23.81%
# k 340 : score 23.81%
# k 341 : score 23.81%
# k 342 : score 23.81%
# k 343 : score 23.81%
# k 344 : score 23.81%
# k 345 : score 23.81%
# k 346 : score 23.81%
# k 347 : score 23.81%
# k 348 : score 23.81%
# k 349 : score 23.81%
# k 350 : score 23.81%
# k 351 : score 23.81%
# k 352 : score 23.81%
# k 353 : score 23.81%
# k 354 : score 23.81%
# k 355 : score 23.81%
# k 356 : score 23.81%
# k 357 : score 23.81%
# k 358 : score 23.81%
# k 359 : score 23.81%
# k 360 : score 23.81%
# k 361 : score 23.81%
# k 362 : score 23.81%
# k 363 : score 23.81%
# k 364 : score 23.81%
# k 365 : score 23.81%
# k 366 : score 23.81%
# k 367 : score 23.81%
# k 368 : score 23.81%
# k 369 : score 23.81%
# k 370 : score 23.81%
# k 371 : score 23.81%
# k 372 : score 23.81%
# k 373 : score 23.81%
# k 374 : score 23.81%
# k 375 : score 23.81%
# k 376 : score 23.81%
# k 377 : score 23.81%
# k 378 : score 23.81%
# k 379 : score 23.81%
# k 380 : score 23.81%
# k 381 : score 23.81%
# k 382 : score 23.81%
# k 383 : score 23.81%
# k 384 : score 23.81%
# k 385 : score 23.81%
# k 386 : score 23.81%
# k 387 : score 23.81%
# k 388 : score 23.81%
# k 389 : score 23.81%
# k 390 : score 23.81%
# k 391 : score 23.81%
# k 392 : score 23.81%
# k 393 : score 23.81%
# k 394 : score 23.81%
# k 395 : score 23.81%
# k 396 : score 23.81%
# k 397 : score 23.81%
# k 398 : score 23.81%
# k 399 : score 23.81%
# k 400 : score 23.81%
# k 401 : score 23.81%
# k 402 : score 23.81%
# k 403 : score 23.81%
# k 404 : score 23.81%
# k 405 : score 23.81%
# k 406 : score 23.81%
# k 407 : score 23.81%
# k 408 : score 23.81%
# k 409 : score 23.81%
# k 410 : score 23.81%
# k 411 : score 23.81%
# k 412 : score 23.81%
# k 413 : score 23.81%
# k 414 : score 23.81%
# k 415 : score 23.81%
# k 416 : score 23.81%
# k 417 : score 23.81%
# k 418 : score 23.81%
# k 419 : score 23.81%
# k 420 : score 23.81%
# k 421 : score 23.81%
# k 422 : score 23.81%
# k 423 : score 23.81%
# k 424 : score 23.81%
# k 425 : score 23.81%
# k 426 : score 23.81%
# k 427 : score 23.81%
# k 428 : score 23.81%
# k 429 : score 23.81%
# k 430 : score 23.81%
# k 431 : score 23.81%
# k 432 : score 23.81%
# k 433 : score 23.81%
# k 434 : score 23.81%
# k 435 : score 23.81%
# k 436 : score 23.81%
# k 437 : score 23.81%
# k 438 : score 23.81%
# k 439 : score 23.81%
# k 440 : score 23.81%
# k 441 : score 23.81%
# k 442 : score 23.81%
# k 443 : score 23.81%
# k 444 : score 23.81%
# k 445 : score 23.81%
# k 446 : score 23.81%
# k 447 : score 23.81%
# k 448 : score 23.81%
# k 449 : score 23.81%
# k 450 : score 23.81%
# k 451 : score 23.81%
# k 452 : score 23.81%
# k 453 : score 23.81%
# k 454 : score 23.81%
# k 455 : score 23.81%
# k 456 : score 23.81%
# k 457 : score 23.81%
# k 458 : score 23.81%
# k 459 : score 23.81%
# k 460 : score 23.81%
# k 461 : score 23.81%
# k 462 : score 23.81%
# k 463 : score 23.81%
# k 464 : score 23.81%
# k 465 : score 23.81%
# k 466 : score 23.81%
# k 467 : score 23.81%
# k 468 : score 23.81%
# k 469 : score 23.81%
# k 470 : score 23.81%
# k 471 : score 23.81%
# k 472 : score 23.81%
# k 473 : score 23.81%
# k 474 : score 23.81%
# k 475 : score 23.81%
# k 476 : score 23.81%
# k 477 : score 23.81%
# k 478 : score 23.81%
# k 479 : score 23.81%
# k 480 : score 23.81%
# k 481 : score 23.81%
# k 482 : score 23.81%
# k 483 : score 23.81%
# k 484 : score 23.81%
# k 485 : score 23.81%
# k 486 : score 23.81%
# k 487 : score 23.81%
# k 488 : score 23.81%
# k 489 : score 23.81%
# k 490 : score 23.81%
# k 491 : score 23.81%
# k 492 : score 23.81%
# k 493 : score 23.81%
# k 494 : score 23.81%
# k 495 : score 23.81%
# k 496 : score 23.81%
# k 497 : score 23.81%
# k 498 : score 23.81%
# k 499 : score 23.81%
# k 500 : score 23.81%
# k 501 : score 23.81%
# k 502 : score 23.81%
# k 503 : score 23.81%
# k 504 : score 23.81%
# k 505 : score 23.81%
# k 506 : score 23.81%
# k 507 : score 23.81%
# k 508 : score 23.81%
# k 509 : score 23.81%
# k 510 : score 23.81%
# k 511 : score 23.81%
# k 512 : score 23.81%
# k 513 : score 23.81%
# k 514 : score 23.81%
# k 515 : score 23.81%
# k 516 : score 23.81%
# k 517 : score 23.81%
# k 518 : score 23.81%
# k 519 : score 23.81%
# k 520 : score 23.81%
# k 521 : score 23.81%
# k 522 : score 23.81%
# k 523 : score 23.81%
# k 524 : score 23.81%
# k 525 : score 23.81%
# k 526 : score 23.81%
# k 527 : score 23.81%
# k 528 : score 23.81%
# k 529 : score 23.81%
# k 530 : score 23.81%
# k 531 : score 23.81%
# k 532 : score 23.81%
# k 533 : score 23.81%
# k 534 : score 23.81%
# k 535 : score 23.81%
# k 536 : score 23.81%
# k 537 : score 23.81%
# k 538 : score 23.81%
# k 539 : score 23.81%
# k 540 : score 23.81%
# k 541 : score 23.81%
# k 542 : score 23.81%
# k 543 : score 23.81%
# k 544 : score 23.81%
# k 545 : score 23.81%
# k 546 : score 23.81%
# k 547 : score 23.81%
# k 548 : score 23.81%
# k 549 : score 23.81%
# k 550 : score 23.81%
# k 551 : score 23.81%
# k 552 : score 23.81%
# k 553 : score 23.81%
# k 554 : score 23.81%
# k 555 : score 23.81%
# k 556 : score 23.81%
# k 557 : score 23.81%
# k 558 : score 23.81%
# k 559 : score 23.81%
# k 560 : score 23.81%
# k 561 : score 23.81%
# k 562 : score 23.81%
# k 563 : score 23.81%
# k 564 : score 23.81%
# k 565 : score 23.81%
# k 566 : score 23.81%
# k 567 : score 23.81%
# k 568 : score 23.81%
# k 569 : score 23.81%
# k 570 : score 23.81%
# k 571 : score 23.81%
# k 572 : score 23.81%
# k 573 : score 23.81%
# k 574 : score 23.81%
# k 575 : score 23.81%
# k 576 : score 23.81%
# k 577 : score 23.81%
# k 578 : score 26.19%
# k 579 : score 26.19%
# k 580 : score 26.19%
# k 581 : score 26.19%
# k 582 : score 26.19%
# k 583 : score 26.19%
# k 584 : score 26.19%
# k 585 : score 26.19%
# k 586 : score 26.19%
# k 587 : score 26.19%
# k 588 : score 26.19%
# k 589 : score 26.19%
# k 590 : score 26.19%
# k 591 : score 26.19%
# k 592 : score 26.19%
# k 593 : score 26.19%
# k 594 : score 26.19%
# k 595 : score 26.19%
# k 596 : score 26.19%
# k 597 : score 26.19%
# k 598 : score 26.19%
# k 599 : score 26.19%
# k 600 : score 26.19%
# k 601 : score 26.19%
# k 602 : score 26.19%
# k 603 : score 26.19%
# k 604 : score 26.19%
# k 605 : score 26.19%
# k 606 : score 26.19%
# k 607 : score 26.19%
# k 608 : score 26.19%
# k 609 : score 26.19%
# k 610 : score 26.19%
# k 611 : score 26.19%
# k 612 : score 26.19%
# k 613 : score 26.19%
# k 614 : score 26.19%
# k 615 : score 26.19%
# k 616 : score 26.19%
# k 617 : score 26.19%
# k 618 : score 26.19%
# k 619 : score 26.19%
# k 620 : score 26.19%
# k 621 : score 26.19%
# k 622 : score 26.19%
# k 623 : score 26.19%
# k 624 : score 26.19%
# k 625 : score 26.19%
# k 626 : score 26.19%
# k 627 : score 26.19%
# k 628 : score 26.19%
# k 629 : score 26.19%
# k 630 : score 26.19%
# k 631 : score 26.19%
# k 632 : score 26.19%
# k 633 : score 26.19%
# k 634 : score 26.19%
# k 635 : score 26.19%
# k 636 : score 26.19%
# k 637 : score 26.19%
# k 638 : score 26.19%
# k 639 : score 26.19%
# k 640 : score 26.19%
# k 641 : score 26.19%
# k 642 : score 26.19%
# k 643 : score 26.19%
# k 644 : score 26.19%
# k 645 : score 26.19%
# k 646 : score 26.19%
# k 647 : score 26.19%
# k 648 : score 26.19%
# k 649 : score 26.19%
# k 650 : score 26.19%
# k 651 : score 26.19%
# k 652 : score 26.19%
# k 653 : score 26.19%
# k 654 : score 26.19%
# k 655 : score 26.19%
# k 656 : score 26.19%
# k 657 : score 26.19%
# k 658 : score 26.19%
# k 659 : score 26.19%
# k 660 : score 26.19%
# k 661 : score 26.19%
# k 662 : score 26.19%
#
# [MAX SCORE] : k 578 : score 0.2619047619047619%
# total_length_of_absence_10.0th,absence_ratio_10.0th,discipline_incidents_10.0th,gpa_est_10.0th,age_10.0th,log_median_10.0th,diff_total_length_of_absence_10.0th,total_length_of_absence_9.0th,diff_total_length_of_absence_8.0th,length_of_unexcused_absence_10.0th,diff_absence_ratio_10.0th,unexcused_absence_ratio_10.0th,absence_ratio_9.0th,gender_M,log_pop_10.0th,unemp_rate_10.0th,discipline_incidents_9.0th,total_length_of_absence_8.0th,other_program_10.0th,missing_intervention_10.0th,age_8.0th,absence_ratio_8.0th,gpa_miss_10.0th,gpa_est_9.0th,eighth_read_pl_Miss,extra_program_10.0th,ogt_math_pl_1.0,school_yr_unemp_rate_10.0th,district_TriValley_10.0th,total_length_of_absence_7.0th,log_mean_10.0th,disability_none_10.0th,gender_F,sixth_science_pl_1.0,age_9.0th,log_pop_8.0th,district_Coshocton_10.0th,absence_consec_count_10.0th,log_median_8.0th,zip_43720_10.0th,special_education_10.0th,fourth_math_pl_1.0,unexcused_absence_ratio_9.0th,sixth_write_pl_1.0,missing_intervention_9.0th,gpa_est_8.0th,gpa_est_7.0th,diff_unexcused_absence_ratio_10.0th,disability_learning disability_9.0th,retained_8.0th,ogt_socstudies_pl_Miss,diff_length_of_unexcused_absence_10.0th,disability_learning disability_10.0th,fourth_ctz_pl_1.0,log_pop_9.0th,disadvantagement_economic_10.0th,log_mean_9.0th,advanced_program_9.0th,zip_43821_10.0th,disadvantagement_Miss_9.0th,district_Franklin_10.0th,unemp_rate_9.0th,school_yr_unemp_rate_9.0th,district_Maysville_10.0th,disability_cognitive disability_9.0th,zip_43822_10.0th,sixth_ctz_pl_1.0,sixth_science_pl_Miss,zip_43842_10.0th,school_yr_unemp_rate_7.0th,other_program_9.0th,log_median_9.0th,ogt_read_pl_Miss,fourth_read_pl_1.0,length_of_unexcused_absence_9.0th,gpa_miss_8.0th,diff_absence_ratio_9.0th,diff_total_length_of_absence_7.0th,disadvantagement_Miss_10.0th,zip_43844_9.0th,ogt_write_pl_Miss,zip_43812_10.0th,advanced_program_10.0th,eighth_science_pl_Miss,sixth_read_pl_Miss,ogt_science_pl_Miss,sixth_write_pl_Miss,fourth_science_pl_Miss,zip_43735_9.0th,seventh_math_pl_Miss,extra_program_8.0th,retained_10.0th,zip_43821_9.0th,zip_43845_10.0th,fourth_write_pl_1.0,zip_43739_10.0th,district_Coshocton_8.0th,absence_suspension_10.0th,eighth_science_pl_1.0,missing_intervention_7.0th,fourth_science_pl_1.0,disability_Miss_10.0th,special_education_9.0th,seventh_read_pl_Miss,missing_intervention_8.0th,disadvantagement_economic_9.0th,log_mean_7.0th,district_Riverview_10.0th,disability_other minor_10.0th,sixth_read_pl_1.0,family_school_career_program_10.0th,sixth_ctz_pl_Miss,district_Coshocton_9.0th,zip_43843_10.0th,zip_43812_9.0th,discipline_incidents_8.0th,zip_43701_9.0th,extra_program_9.0th,age_7.0th,absence_suspension_9.0th,zip_43844_10.0th,limited_english_f_9.0th,disability_cognitive disability_8.0th,district_TriValley_9.0th,fourth_write_pl_Miss,district_Maysville_9.0th,limited_english_f_10.0th,district_Ridgewood_10.0th,fourth_math_pl_Miss,zip_43845_9.0th,log_pop_miss_7.0th,disability_none_9.0th,zip_43821_8.0th,zip_43830_10.0th,zip_0_8.0th,disability_cognitive disability_10.0th,zip_43701_10.0th,district_Ridgewood_9.0th,absence_consec_count_9.0th,tardy_consec_count_9.0th,fourth_ctz_pl_Miss,disability_emotional disturbance_10.0th,disadvantagement_Miss_8.0th,ogt_science_pl_1.0,ogt_write_pl_1.0,gpa_miss_9.0th,log_median_miss_7.0th,log_pop_miss_8.0th,district_TriValley_7.0th,diff_absence_ratio_8.0th,ogt_math_pl_Miss,disability_Miss_9.0th,seventh_read_pl_1.0,district_Riverview_9.0th,disability_none_8.0th,disability_multiple_8.0th,special_education_8.0th,eighth_math_pl_Miss,ethnicity_B,log_mean_8.0th,eighth_read_pl_1.0,gpa_miss_7.0th,diff_total_length_of_absence_9.0th,ogt_socstudies_pl_1.0,limited_english_Miss_10.0th,eighth_math_pl_1.0,district_Maysville_8.0th,retained_9.0th,log_mean_miss_9.0th,log_pop_miss_9.0th,zip_43822_8.0th,seventh_write_pl_Miss,days_tardy_10.0th,zip_0_9.0th,limited_english_Miss_9.0th,zip_43055_10.0th,seventh_math_pl_1.0,zip_43701_8.0th,zip_43777_10.0th,sixth_math_pl_1.0,ethnicity_W,zip_43056_8.0th,district_Franklin ...

# %%
recall_get_feature_importance(x_train, y_train, x_test, y_test, RF)
# Out:
# k   1 : score  7.14%
# k   2 : score 22.62%
# k   3 : score 40.48%
# k   4 : score 60.71%
# k   5 : score 70.24%
# k   6 : score 70.24%
# k   7 : score 78.57%
# k   8 : score 78.57%
# k   9 : score 80.95%
# k  10 : score 82.14%
# k  11 : score 82.14%
# k  12 : score 82.14%
# k  13 : score 82.14%
# k  14 : score 82.14%
# k  15 : score 82.14%
# k  16 : score 82.14%
# k  17 : score 83.33%
# k  18 : score 83.33%
# k  19 : score 83.33%
# k  20 : score 83.33%
# k  21 : score 83.33%
# k  22 : score 83.33%
# k  23 : score 83.33%
# k  24 : score 83.33%
# k  25 : score 83.33%
# k  26 : score 83.33%
# k  27 : score 83.33%
# k  28 : score 83.33%
# k  29 : score 83.33%
# k  30 : score 83.33%
# k  31 : score 83.33%
# k  32 : score 83.33%
# k  33 : score 83.33%
# k  34 : score 83.33%
# k  35 : score 83.33%
# k  36 : score 83.33%
# k  37 : score 83.33%
# k  38 : score 83.33%
# k  39 : score 83.33%
# k  40 : score 84.52%
# k  41 : score 84.52%
# k  42 : score 84.52%
# k  43 : score 84.52%
# k  44 : score 84.52%
# k  45 : score 84.52%
# k  46 : score 84.52%
# k  47 : score 84.52%
# k  48 : score 84.52%
# k  49 : score 84.52%
# k  50 : score 84.52%
# k  51 : score 84.52%
# k  52 : score 84.52%
# k  53 : score 84.52%
# k  54 : score 84.52%
# k  55 : score 84.52%
# k  56 : score 84.52%
# k  57 : score 84.52%
# k  58 : score 84.52%
# k  59 : score 84.52%
# k  60 : score 84.52%
# k  61 : score 84.52%
# k  62 : score 86.90%
# k  63 : score 86.90%
# k  64 : score 86.90%
# k  65 : score 86.90%
# k  66 : score 86.90%
# k  67 : score 86.90%
# k  68 : score 86.90%
# k  69 : score 86.90%
# k  70 : score 86.90%
# k  71 : score 86.90%
# k  72 : score 86.90%
# k  73 : score 86.90%
# k  74 : score 86.90%
# k  75 : score 86.90%
# k  76 : score 86.90%
# k  77 : score 86.90%
# k  78 : score 86.90%
# k  79 : score 86.90%
# k  80 : score 86.90%
# k  81 : score 86.90%
# k  82 : score 86.90%
# k  83 : score 86.90%
# k  84 : score 86.90%
# k  85 : score 86.90%
# k  86 : score 86.90%
# k  87 : score 86.90%
# k  88 : score 86.90%
# k  89 : score 86.90%
# k  90 : score 86.90%
# k  91 : score 86.90%
# k  92 : score 86.90%
# k  93 : score 86.90%
# k  94 : score 86.90%
# k  95 : score 86.90%
# k  96 : score 86.90%
# k  97 : score 86.90%
# k  98 : score 86.90%
# k  99 : score 86.90%
# k 100 : score 86.90%
# k 101 : score 86.90%
# k 102 : score 86.90%
# k 103 : score 86.90%
# k 104 : score 86.90%
# k 105 : score 89.29%
# k 106 : score 89.29%
# k 107 : score 89.29%
# k 108 : score 89.29%
# k 109 : score 89.29%
# k 110 : score 89.29%
# k 111 : score 89.29%
# k 112 : score 89.29%
# k 113 : score 89.29%
# k 114 : score 89.29%
# k 115 : score 89.29%
# k 116 : score 89.29%
# k 117 : score 89.29%
# k 118 : score 89.29%
# k 119 : score 89.29%
# k 120 : score 89.29%
# k 121 : score 89.29%
# k 122 : score 89.29%
# k 123 : score 89.29%
# k 124 : score 89.29%
# k 125 : score 89.29%
# k 126 : score 89.29%
# k 127 : score 89.29%
# k 128 : score 89.29%
# k 129 : score 89.29%
# k 130 : score 89.29%
# k 131 : score 89.29%
# k 132 : score 89.29%
# k 133 : score 89.29%
# k 134 : score 89.29%
# k 135 : score 89.29%
# k 136 : score 89.29%
# k 137 : score 89.29%
# k 138 : score 89.29%
# k 139 : score 89.29%
# k 140 : score 89.29%
# k 141 : score 89.29%
# k 142 : score 89.29%
# k 143 : score 89.29%
# k 144 : score 89.29%
# k 145 : score 89.29%
# k 146 : score 89.29%
# k 147 : score 89.29%
# k 148 : score 89.29%
# k 149 : score 89.29%
# k 150 : score 89.29%
# k 151 : score 89.29%
# k 152 : score 89.29%
# k 153 : score 89.29%
# k 154 : score 89.29%
# k 155 : score 89.29%
# k 156 : score 89.29%
# k 157 : score 89.29%
# k 158 : score 89.29%
# k 159 : score 89.29%
# k 160 : score 89.29%
# k 161 : score 89.29%
# k 162 : score 89.29%
# k 163 : score 89.29%
# k 164 : score 89.29%
# k 165 : score 89.29%
# k 166 : score 89.29%
# k 167 : score 89.29%
# k 168 : score 89.29%
# k 169 : score 89.29%
# k 170 : score 89.29%
# k 171 : score 89.29%
# k 172 : score 89.29%
# k 173 : score 89.29%
# k 174 : score 89.29%
# k 175 : score 89.29%
# k 176 : score 89.29%
# k 177 : score 89.29%
# k 178 : score 89.29%
# k 179 : score 89.29%
# k 180 : score 89.29%
# k 181 : score 89.29%
# k 182 : score 89.29%
# k 183 : score 89.29%
# k 184 : score 89.29%
# k 185 : score 89.29%
# k 186 : score 89.29%
# k 187 : score 89.29%
# k 188 : score 89.29%
# k 189 : score 89.29%
# k 190 : score 89.29%
# k 191 : score 89.29%
# k 192 : score 89.29%
# k 193 : score 89.29%
# k 194 : score 89.29%
# k 195 : score 89.29%
# k 196 : score 89.29%
# k 197 : score 89.29%
# k 198 : score 89.29%
# k 199 : score 89.29%
# k 200 : score 89.29%
# k 201 : score 89.29%
# k 202 : score 89.29%
# k 203 : score 89.29%
# k 204 : score 89.29%
# k 205 : score 89.29%
# k 206 : score 89.29%
# k 207 : score 89.29%
# k 208 : score 89.29%
# k 209 : score 89.29%
# k 210 : score 89.29%
# k 211 : score 89.29%
# k 212 : score 89.29%
# k 213 : score 89.29%
# k 214 : score 89.29%
# k 215 : score 89.29%
# k 216 : score 89.29%
# k 217 : score 89.29%
# k 218 : score 89.29%
# k 219 : score 89.29%
# k 220 : score 89.29%
# k 221 : score 89.29%
# k 222 : score 89.29%
# k 223 : score 89.29%
# k 224 : score 89.29%
# k 225 : score 89.29%
# k 226 : score 89.29%
# k 227 : score 89.29%
# k 228 : score 89.29%
# k 229 : score 89.29%
# k 230 : score 89.29%
# k 231 : score 89.29%
# k 232 : score 89.29%
# k 233 : score 89.29%
# k 234 : score 89.29%
# k 235 : score 89.29%
# k 236 : score 89.29%
# k 237 : score 89.29%
# k 238 : score 89.29%
# k 239 : score 89.29%
# k 240 : score 89.29%
# k 241 : score 89.29%
# k 242 : score 89.29%
# k 243 : score 89.29%
# k 244 : score 89.29%
# k 245 : score 89.29%
# k 246 : score 89.29%
# k 247 : score 89.29%
# k 248 : score 89.29%
# k 249 : score 89.29%
# k 250 : score 89.29%
# k 251 : score 89.29%
# k 252 : score 89.29%
# k 253 : score 89.29%
# k 254 : score 89.29%
# k 255 : score 89.29%
# k 256 : score 89.29%
# k 257 : score 89.29%
# k 258 : score 89.29%
# k 259 : score 89.29%
# k 260 : score 89.29%
# k 261 : score 89.29%
# k 262 : score 89.29%
# k 263 : score 89.29%
# k 264 : score 89.29%
# k 265 : score 89.29%
# k 266 : score 89.29%
# k 267 : score 89.29%
# k 268 : score 89.29%
# k 269 : score 89.29%
# k 270 : score 89.29%
# k 271 : score 89.29%
# k 272 : score 89.29%
# k 273 : score 89.29%
# k 274 : score 89.29%
# k 275 : score 89.29%
# k 276 : score 89.29%
# k 277 : score 89.29%
# k 278 : score 89.29%
# k 279 : score 89.29%
# k 280 : score 89.29%
# k 281 : score 89.29%
# k 282 : score 89.29%
# k 283 : score 89.29%
# k 284 : score 89.29%
# k 285 : score 89.29%
# k 286 : score 89.29%
# k 287 : score 89.29%
# k 288 : score 89.29%
# k 289 : score 89.29%
# k 290 : score 89.29%
# k 291 : score 89.29%
# k 292 : score 89.29%
# k 293 : score 89.29%
# k 294 : score 89.29%
# k 295 : score 89.29%
# k 296 : score 89.29%
# k 297 : score 89.29%
# k 298 : score 89.29%
# k 299 : score 89.29%
# k 300 : score 89.29%
# k 301 : score 89.29%
# k 302 : score 89.29%
# k 303 : score 89.29%
# k 304 : score 89.29%
# k 305 : score 89.29%
# k 306 : score 89.29%
# k 307 : score 89.29%
# k 308 : score 89.29%
# k 309 : score 89.29%
# k 310 : score 89.29%
# k 311 : score 89.29%
# k 312 : score 89.29%
# k 313 : score 89.29%
# k 314 : score 89.29%
# k 315 : score 89.29%
# k 316 : score 89.29%
# k 317 : score 89.29%
# k 318 : score 89.29%
# k 319 : score 89.29%
# k 320 : score 89.29%
# k 321 : score 89.29%
# k 322 : score 89.29%
# k 323 : score 89.29%
# k 324 : score 89.29%
# k 325 : score 89.29%
# k 326 : score 89.29%
# k 327 : score 89.29%
# k 328 : score 89.29%
# k 329 : score 89.29%
# k 330 : score 89.29%
# k 331 : score 89.29%
# k 332 : score 89.29%
# k 333 : score 89.29%
# k 334 : score 89.29%
# k 335 : score 89.29%
# k 336 : score 89.29%
# k 337 : score 89.29%
# k 338 : score 89.29%
# k 339 : score 89.29%
# k 340 : score 89.29%
# k 341 : score 89.29%
# k 342 : score 89.29%
# k 343 : score 89.29%
# k 344 : score 89.29%
# k 345 : score 89.29%
# k 346 : score 89.29%
# k 347 : score 89.29%
# k 348 : score 89.29%
# k 349 : score 89.29%
# k 350 : score 89.29%
# k 351 : score 89.29%
# k 352 : score 89.29%
# k 353 : score 89.29%
# k 354 : score 89.29%
# k 355 : score 89.29%
# k 356 : score 89.29%
# k 357 : score 89.29%
# k 358 : score 89.29%
# k 359 : score 89.29%
# k 360 : score 89.29%
# k 361 : score 89.29%
# k 362 : score 89.29%
# k 363 : score 89.29%
# k 364 : score 89.29%
# k 365 : score 89.29%
# k 366 : score 89.29%
# k 367 : score 89.29%
# k 368 : score 89.29%
# k 369 : score 89.29%
# k 370 : score 89.29%
# k 371 : score 89.29%
# k 372 : score 89.29%
# k 373 : score 89.29%
# k 374 : score 89.29%
# k 375 : score 89.29%
# k 376 : score 89.29%
# k 377 : score 89.29%
# k 378 : score 89.29%
# k 379 : score 89.29%
# k 380 : score 89.29%
# k 381 : score 89.29%
# k 382 : score 89.29%
# k 383 : score 89.29%
# k 384 : score 89.29%
# k 385 : score 89.29%
# k 386 : score 89.29%
# k 387 : score 89.29%
# k 388 : score 89.29%
# k 389 : score 89.29%
# k 390 : score 89.29%
# k 391 : score 89.29%
# k 392 : score 89.29%
# k 393 : score 89.29%
# k 394 : score 89.29%
# k 395 : score 89.29%
# k 396 : score 89.29%
# k 397 : score 89.29%
# k 398 : score 89.29%
# k 399 : score 89.29%
# k 400 : score 89.29%
# k 401 : score 89.29%
# k 402 : score 89.29%
# k 403 : score 89.29%
# k 404 : score 89.29%
# k 405 : score 89.29%
# k 406 : score 89.29%
# k 407 : score 89.29%
# k 408 : score 89.29%
# k 409 : score 89.29%
# k 410 : score 89.29%
# k 411 : score 89.29%
# k 412 : score 89.29%
# k 413 : score 89.29%
# k 414 : score 89.29%
# k 415 : score 89.29%
# k 416 : score 89.29%
# k 417 : score 89.29%
# k 418 : score 89.29%
# k 419 : score 89.29%
# k 420 : score 89.29%
# k 421 : score 89.29%
# k 422 : score 89.29%
# k 423 : score 89.29%
# k 424 : score 89.29%
# k 425 : score 89.29%
# k 426 : score 89.29%
# k 427 : score 89.29%
# k 428 : score 89.29%
# k 429 : score 89.29%
# k 430 : score 89.29%
# k 431 : score 89.29%
# k 432 : score 89.29%
# k 433 : score 89.29%
# k 434 : score 89.29%
# k 435 : score 89.29%
# k 436 : score 89.29%
# k 437 : score 89.29%
# k 438 : score 89.29%
# k 439 : score 89.29%
# k 440 : score 89.29%
# k 441 : score 89.29%
# k 442 : score 89.29%
# k 443 : score 89.29%
# k 444 : score 89.29%
# k 445 : score 89.29%
# k 446 : score 89.29%
# k 447 : score 89.29%
# k 448 : score 89.29%
# k 449 : score 89.29%
# k 450 : score 89.29%
# k 451 : score 89.29%
# k 452 : score 89.29%
# k 453 : score 89.29%
# k 454 : score 89.29%
# k 455 : score 89.29%
# k 456 : score 89.29%
# k 457 : score 89.29%
# k 458 : score 89.29%
# k 459 : score 89.29%
# k 460 : score 89.29%
# k 461 : score 89.29%
# k 462 : score 89.29%
# k 463 : score 89.29%
# k 464 : score 89.29%
# k 465 : score 89.29%
# k 466 : score 89.29%
# k 467 : score 89.29%
# k 468 : score 89.29%
# k 469 : score 89.29%
# k 470 : score 89.29%
# k 471 : score 89.29%
# k 472 : score 89.29%
# k 473 : score 89.29%
# k 474 : score 89.29%
# k 475 : score 89.29%
# k 476 : score 89.29%
# k 477 : score 89.29%
# k 478 : score 89.29%
# k 479 : score 89.29%
# k 480 : score 89.29%
# k 481 : score 89.29%
# k 482 : score 89.29%
# k 483 : score 89.29%
# k 484 : score 89.29%
# k 485 : score 89.29%
# k 486 : score 89.29%
# k 487 : score 89.29%
# k 488 : score 89.29%
# k 489 : score 89.29%
# k 490 : score 89.29%
# k 491 : score 89.29%
# k 492 : score 89.29%
# k 493 : score 89.29%
# k 494 : score 89.29%
# k 495 : score 89.29%
# k 496 : score 89.29%
# k 497 : score 89.29%
# k 498 : score 89.29%
# k 499 : score 89.29%
# k 500 : score 89.29%
# k 501 : score 89.29%
# k 502 : score 89.29%
# k 503 : score 89.29%
# k 504 : score 89.29%
# k 505 : score 89.29%
# k 506 : score 89.29%
# k 507 : score 89.29%
# k 508 : score 89.29%
# k 509 : score 89.29%
# k 510 : score 89.29%
# k 511 : score 89.29%
# k 512 : score 89.29%
# k 513 : score 89.29%
# k 514 : score 89.29%
# k 515 : score 89.29%
# k 516 : score 89.29%
# k 517 : score 89.29%
# k 518 : score 89.29%
# k 519 : score 89.29%
# k 520 : score 89.29%
# k 521 : score 89.29%
# k 522 : score 89.29%
# k 523 : score 89.29%
# k 524 : score 89.29%
# k 525 : score 89.29%
# k 526 : score 89.29%
# k 527 : score 89.29%
# k 528 : score 89.29%
# k 529 : score 89.29%
# k 530 : score 89.29%
# k 531 : score 89.29%
# k 532 : score 89.29%
# k 533 : score 89.29%
# k 534 : score 89.29%
# k 535 : score 89.29%
# k 536 : score 89.29%
# k 537 : score 89.29%
# k 538 : score 89.29%
# k 539 : score 89.29%
# k 540 : score 89.29%
# k 541 : score 89.29%
# k 542 : score 89.29%
# k 543 : score 89.29%
# k 544 : score 89.29%
# k 545 : score 89.29%
# k 546 : score 89.29%
# k 547 : score 89.29%
# k 548 : score 89.29%
# k 549 : score 89.29%
# k 550 : score 89.29%
# k 551 : score 89.29%
# k 552 : score 89.29%
# k 553 : score 89.29%
# k 554 : score 89.29%
# k 555 : score 89.29%
# k 556 : score 89.29%
# k 557 : score 89.29%
# k 558 : score 89.29%
# k 559 : score 89.29%
# k 560 : score 89.29%
# k 561 : score 89.29%
# k 562 : score 89.29%
# k 563 : score 89.29%
# k 564 : score 89.29%
# k 565 : score 89.29%
# k 566 : score 89.29%
# k 567 : score 89.29%
# k 568 : score 89.29%
# k 569 : score 89.29%
# k 570 : score 89.29%
# k 571 : score 89.29%
# k 572 : score 89.29%
# k 573 : score 89.29%
# k 574 : score 89.29%
# k 575 : score 89.29%
# k 576 : score 89.29%
# k 577 : score 89.29%
# k 578 : score 89.29%
# k 579 : score 89.29%
# k 580 : score 89.29%
# k 581 : score 89.29%
# k 582 : score 89.29%
# k 583 : score 89.29%
# k 584 : score 89.29%
# k 585 : score 89.29%
# k 586 : score 89.29%
# k 587 : score 89.29%
# k 588 : score 89.29%
# k 589 : score 89.29%
# k 590 : score 89.29%
# k 591 : score 89.29%
# k 592 : score 89.29%
# k 593 : score 89.29%
# k 594 : score 89.29%
# k 595 : score 89.29%
# k 596 : score 89.29%
# k 597 : score 89.29%
# k 598 : score 89.29%
# k 599 : score 89.29%
# k 600 : score 89.29%
# k 601 : score 89.29%
# k 602 : score 89.29%
# k 603 : score 89.29%
# k 604 : score 89.29%
# k 605 : score 89.29%
# k 606 : score 89.29%
# k 607 : score 89.29%
# k 608 : score 89.29%
# k 609 : score 89.29%
# k 610 : score 89.29%
# k 611 : score 89.29%
# k 612 : score 89.29%
# k 613 : score 89.29%
# k 614 : score 89.29%
# k 615 : score 89.29%
# k 616 : score 89.29%
# k 617 : score 89.29%
# k 618 : score 89.29%
# k 619 : score 89.29%
# k 620 : score 89.29%
# k 621 : score 89.29%
# k 622 : score 89.29%
# k 623 : score 89.29%
# k 624 : score 89.29%
# k 625 : score 89.29%
# k 626 : score 89.29%
# k 627 : score 89.29%
# k 628 : score 89.29%
# k 629 : score 89.29%
# k 630 : score 89.29%
# k 631 : score 89.29%
# k 632 : score 89.29%
# k 633 : score 89.29%
# k 634 : score 89.29%
# k 635 : score 89.29%
# k 636 : score 89.29%
# k 637 : score 89.29%
# k 638 : score 89.29%
# k 639 : score 89.29%
# k 640 : score 89.29%
# k 641 : score 89.29%
# k 642 : score 89.29%
# k 643 : score 89.29%
# k 644 : score 89.29%
# k 645 : score 89.29%
# k 646 : score 89.29%
# k 647 : score 89.29%
# k 648 : score 89.29%
# k 649 : score 89.29%
# k 650 : score 89.29%
# k 651 : score 89.29%
# k 652 : score 89.29%
# k 653 : score 89.29%
# k 654 : score 89.29%
# k 655 : score 89.29%
# k 656 : score 89.29%
# k 657 : score 89.29%
# k 658 : score 89.29%
# k 659 : score 89.29%
# k 660 : score 89.29%
# k 661 : score 89.29%
# k 662 : score 89.29%
#
# [MAX SCORE] : k 105 : score 0.8928571428571429%
# total_length_of_absence_10.0th,absence_ratio_10.0th,discipline_incidents_10.0th,gpa_est_10.0th,age_10.0th,log_median_10.0th,diff_total_length_of_absence_10.0th,total_length_of_absence_9.0th,diff_total_length_of_absence_8.0th,length_of_unexcused_absence_10.0th,diff_absence_ratio_10.0th,unexcused_absence_ratio_10.0th,absence_ratio_9.0th,gender_M,log_pop_10.0th,unemp_rate_10.0th,discipline_incidents_9.0th,total_length_of_absence_8.0th,other_program_10.0th,missing_intervention_10.0th,age_8.0th,absence_ratio_8.0th,gpa_miss_10.0th,gpa_est_9.0th,eighth_read_pl_Miss,extra_program_10.0th,ogt_math_pl_1.0,school_yr_unemp_rate_10.0th,district_TriValley_10.0th,total_length_of_absence_7.0th,log_mean_10.0th,disability_none_10.0th,gender_F,sixth_science_pl_1.0,age_9.0th,log_pop_8.0th,district_Coshocton_10.0th,absence_consec_count_10.0th,log_median_8.0th,zip_43720_10.0th,special_education_10.0th,fourth_math_pl_1.0,unexcused_absence_ratio_9.0th,sixth_write_pl_1.0,missing_intervention_9.0th,gpa_est_8.0th,gpa_est_7.0th,diff_unexcused_absence_ratio_10.0th,disability_learning disability_9.0th,retained_8.0th,ogt_socstudies_pl_Miss,diff_length_of_unexcused_absence_10.0th,disability_learning disability_10.0th,fourth_ctz_pl_1.0,log_pop_9.0th,disadvantagement_economic_10.0th,log_mean_9.0th,advanced_program_9.0th,zip_43821_10.0th,disadvantagement_Miss_9.0th,district_Franklin_10.0th,unemp_rate_9.0th,school_yr_unemp_rate_9.0th,district_Maysville_10.0th,disability_cognitive disability_9.0th,zip_43822_10.0th,sixth_ctz_pl_1.0,sixth_science_pl_Miss,zip_43842_10.0th,school_yr_unemp_rate_7.0th,other_program_9.0th,log_median_9.0th,ogt_read_pl_Miss,fourth_read_pl_1.0,length_of_unexcused_absence_9.0th,gpa_miss_8.0th,diff_absence_ratio_9.0th,diff_total_length_of_absence_7.0th,disadvantagement_Miss_10.0th,zip_43844_9.0th,ogt_write_pl_Miss,zip_43812_10.0th,advanced_program_10.0th,eighth_science_pl_Miss,sixth_read_pl_Miss,ogt_science_pl_Miss,sixth_write_pl_Miss,fourth_science_pl_Miss,zip_43735_9.0th,seventh_math_pl_Miss,extra_program_8.0th,retained_10.0th,zip_43821_9.0th,zip_43845_10.0th,fourth_write_pl_1.0,zip_43739_10.0th,district_Coshocton_8.0th,absence_suspension_10.0th,eighth_science_pl_1.0,missing_intervention_7.0th,fourth_science_pl_1.0,disability_Miss_10.0th,special_education_9.0th,seventh_read_pl_Miss,missing_intervention_8.0th

# %%
recall_get_feature_importance(x_train, y_train, x_test, y_test, BAG)
# Out:
# k   1 : score 11.90%
# k   2 : score 21.43%
# k   3 : score 48.81%
# k   4 : score 75.00%
# k   5 : score 77.38%
# k   6 : score 77.38%
# k   7 : score 79.76%
# k   8 : score 79.76%
# k   9 : score 79.76%
# k  10 : score 79.76%
# k  11 : score 79.76%
# k  12 : score 86.90%
# k  13 : score 86.90%
# k  14 : score 86.90%
# k  15 : score 86.90%
# k  16 : score 86.90%
# k  17 : score 86.90%
# k  18 : score 86.90%
# k  19 : score 86.90%
# k  20 : score 86.90%
# k  21 : score 86.90%
# k  22 : score 86.90%
# k  23 : score 86.90%
# k  24 : score 86.90%
# k  25 : score 86.90%
# k  26 : score 86.90%
# k  27 : score 86.90%
# k  28 : score 86.90%
# k  29 : score 86.90%
# k  30 : score 86.90%
# k  31 : score 86.90%
# k  32 : score 86.90%
# k  33 : score 86.90%
# k  34 : score 86.90%
# k  35 : score 86.90%
# k  36 : score 86.90%
# k  37 : score 86.90%
# k  38 : score 86.90%
# k  39 : score 86.90%
# k  40 : score 86.90%
# k  41 : score 86.90%
# k  42 : score 86.90%
# k  43 : score 86.90%
# k  44 : score 86.90%
# k  45 : score 86.90%
# k  46 : score 86.90%
# k  47 : score 86.90%
# k  48 : score 86.90%
# k  49 : score 86.90%
# k  50 : score 86.90%
# k  51 : score 86.90%
# k  52 : score 86.90%
# k  53 : score 86.90%
# k  54 : score 86.90%
# k  55 : score 86.90%
# k  56 : score 86.90%
# k  57 : score 86.90%
# k  58 : score 86.90%
# k  59 : score 86.90%
# k  60 : score 86.90%
# k  61 : score 86.90%
# k  62 : score 86.90%
# k  63 : score 86.90%
# k  64 : score 86.90%
# k  65 : score 86.90%
# k  66 : score 86.90%
# k  67 : score 86.90%
# k  68 : score 86.90%
# k  69 : score 88.10%
# k  70 : score 88.10%
# k  71 : score 88.10%
# k  72 : score 88.10%
# k  73 : score 88.10%
# k  74 : score 88.10%
# k  75 : score 88.10%
# k  76 : score 88.10%
# k  77 : score 88.10%
# k  78 : score 88.10%
# k  79 : score 88.10%
# k  80 : score 88.10%
# k  81 : score 88.10%
# k  82 : score 88.10%
# k  83 : score 88.10%
# k  84 : score 88.10%
# k  85 : score 88.10%
# k  86 : score 88.10%
# k  87 : score 88.10%
# k  88 : score 88.10%
# k  89 : score 88.10%
# k  90 : score 88.10%
# k  91 : score 88.10%
# k  92 : score 88.10%
# k  93 : score 88.10%
# k  94 : score 88.10%
# k  95 : score 88.10%
# k  96 : score 88.10%
# k  97 : score 88.10%
# k  98 : score 88.10%
# k  99 : score 88.10%
# k 100 : score 88.10%
# k 101 : score 88.10%
# k 102 : score 88.10%
# k 103 : score 88.10%
# k 104 : score 88.10%
# k 105 : score 88.10%
# k 106 : score 88.10%
# k 107 : score 88.10%
# k 108 : score 88.10%
# k 109 : score 88.10%
# k 110 : score 88.10%
# k 111 : score 88.10%
# k 112 : score 88.10%
# k 113 : score 88.10%
# k 114 : score 88.10%
# k 115 : score 88.10%
# k 116 : score 88.10%
# k 117 : score 88.10%
# k 118 : score 88.10%
# k 119 : score 88.10%
# k 120 : score 88.10%
# k 121 : score 88.10%
# k 122 : score 88.10%
# k 123 : score 88.10%
# k 124 : score 88.10%
# k 125 : score 88.10%
# k 126 : score 88.10%
# k 127 : score 88.10%
# k 128 : score 88.10%
# k 129 : score 88.10%
# k 130 : score 88.10%
# k 131 : score 88.10%
# k 132 : score 88.10%
# k 133 : score 88.10%
# k 134 : score 88.10%
# k 135 : score 88.10%
# k 136 : score 88.10%
# k 137 : score 88.10%
# k 138 : score 88.10%
# k 139 : score 88.10%
# k 140 : score 88.10%
# k 141 : score 88.10%
# k 142 : score 88.10%
# k 143 : score 88.10%
# k 144 : score 88.10%
# k 145 : score 88.10%
# k 146 : score 88.10%
# k 147 : score 88.10%
# k 148 : score 88.10%
# k 149 : score 88.10%
# k 150 : score 88.10%
# k 151 : score 88.10%
# k 152 : score 88.10%
# k 153 : score 88.10%
# k 154 : score 88.10%
# k 155 : score 88.10%
# k 156 : score 88.10%
# k 157 : score 88.10%
# k 158 : score 88.10%
# k 159 : score 88.10%
# k 160 : score 88.10%
# k 161 : score 88.10%
# k 162 : score 88.10%
# k 163 : score 88.10%
# k 164 : score 88.10%
# k 165 : score 88.10%
# k 166 : score 88.10%
# k 167 : score 88.10%
# k 168 : score 88.10%
# k 169 : score 88.10%
# k 170 : score 88.10%
# k 171 : score 88.10%
# k 172 : score 88.10%
# k 173 : score 88.10%
# k 174 : score 88.10%
# k 175 : score 88.10%
# k 176 : score 88.10%
# k 177 : score 88.10%
# k 178 : score 88.10%
# k 179 : score 88.10%
# k 180 : score 88.10%
# k 181 : score 88.10%
# k 182 : score 88.10%
# k 183 : score 88.10%
# k 184 : score 88.10%
# k 185 : score 88.10%
# k 186 : score 88.10%
# k 187 : score 88.10%
# k 188 : score 88.10%
# k 189 : score 88.10%
# k 190 : score 88.10%
# k 191 : score 88.10%
# k 192 : score 88.10%
# k 193 : score 89.29%
# k 194 : score 89.29%
# k 195 : score 89.29%
# k 196 : score 89.29%
# k 197 : score 89.29%
# k 198 : score 89.29%
# k 199 : score 89.29%
# k 200 : score 89.29%
# k 201 : score 89.29%
# k 202 : score 89.29%
# k 203 : score 89.29%
# k 204 : score 89.29%
# k 205 : score 90.48%
# k 206 : score 90.48%
# k 207 : score 90.48%
# k 208 : score 90.48%
# k 209 : score 90.48%
# k 210 : score 90.48%
# k 211 : score 90.48%
# k 212 : score 90.48%
# k 213 : score 90.48%
# k 214 : score 90.48%
# k 215 : score 90.48%
# k 216 : score 90.48%
# k 217 : score 90.48%
# k 218 : score 90.48%
# k 219 : score 90.48%
# k 220 : score 90.48%
# k 221 : score 90.48%
# k 222 : score 90.48%
# k 223 : score 90.48%
# k 224 : score 90.48%
# k 225 : score 90.48%
# k 226 : score 90.48%
# k 227 : score 90.48%
# k 228 : score 90.48%
# k 229 : score 90.48%
# k 230 : score 90.48%
# k 231 : score 90.48%
# k 232 : score 90.48%
# k 233 : score 90.48%
# k 234 : score 90.48%
# k 235 : score 90.48%
# k 236 : score 90.48%
# k 237 : score 90.48%
# k 238 : score 90.48%
# k 239 : score 90.48%
# k 240 : score 90.48%
# k 241 : score 90.48%
# k 242 : score 90.48%
# k 243 : score 90.48%
# k 244 : score 90.48%
# k 245 : score 90.48%
# k 246 : score 90.48%
# k 247 : score 90.48%
# k 248 : score 90.48%
# k 249 : score 90.48%
# k 250 : score 90.48%
# k 251 : score 90.48%
# k 252 : score 90.48%
# k 253 : score 90.48%
# k 254 : score 90.48%
# k 255 : score 90.48%
# k 256 : score 90.48%
# k 257 : score 90.48%
# k 258 : score 90.48%
# k 259 : score 90.48%
# k 260 : score 90.48%
# k 261 : score 90.48%
# k 262 : score 90.48%
# k 263 : score 90.48%
# k 264 : score 90.48%
# k 265 : score 90.48%
# k 266 : score 90.48%
# k 267 : score 90.48%
# k 268 : score 90.48%
# k 269 : score 90.48%
# k 270 : score 90.48%
# k 271 : score 90.48%
# k 272 : score 90.48%
# k 273 : score 90.48%
# k 274 : score 90.48%
# k 275 : score 90.48%
# k 276 : score 90.48%
# k 277 : score 90.48%
# k 278 : score 90.48%
# k 279 : score 90.48%
# k 280 : score 90.48%
# k 281 : score 90.48%
# k 282 : score 90.48%
# k 283 : score 90.48%
# k 284 : score 90.48%
# k 285 : score 90.48%
# k 286 : score 90.48%
# k 287 : score 90.48%
# k 288 : score 90.48%
# k 289 : score 90.48%
# k 290 : score 90.48%
# k 291 : score 90.48%
# k 292 : score 90.48%
# k 293 : score 90.48%
# k 294 : score 90.48%
# k 295 : score 90.48%
# k 296 : score 90.48%
# k 297 : score 90.48%
# k 298 : score 90.48%
# k 299 : score 90.48%
# k 300 : score 90.48%
# k 301 : score 90.48%
# k 302 : score 90.48%
# k 303 : score 90.48%
# k 304 : score 90.48%
# k 305 : score 90.48%
# k 306 : score 90.48%
# k 307 : score 90.48%
# k 308 : score 90.48%
# k 309 : score 90.48%
# k 310 : score 90.48%
# k 311 : score 90.48%
# k 312 : score 90.48%
# k 313 : score 90.48%
# k 314 : score 90.48%
# k 315 : score 90.48%
# k 316 : score 90.48%
# k 317 : score 90.48%
# k 318 : score 90.48%
# k 319 : score 90.48%
# k 320 : score 90.48%
# k 321 : score 90.48%
# k 322 : score 90.48%
# k 323 : score 90.48%
# k 324 : score 90.48%
# k 325 : score 90.48%
# k 326 : score 90.48%
# k 327 : score 90.48%
# k 328 : score 90.48%
# k 329 : score 90.48%
# k 330 : score 90.48%
# k 331 : score 90.48%
# k 332 : score 90.48%
# k 333 : score 90.48%
# k 334 : score 90.48%
# k 335 : score 90.48%
# k 336 : score 90.48%
# k 337 : score 90.48%
# k 338 : score 90.48%
# k 339 : score 90.48%
# k 340 : score 90.48%
# k 341 : score 90.48%
# k 342 : score 90.48%
# k 343 : score 90.48%
# k 344 : score 90.48%
# k 345 : score 90.48%
# k 346 : score 90.48%
# k 347 : score 90.48%
# k 348 : score 90.48%
# k 349 : score 90.48%
# k 350 : score 90.48%
# k 351 : score 90.48%
# k 352 : score 90.48%
# k 353 : score 90.48%
# k 354 : score 90.48%
# k 355 : score 90.48%
# k 356 : score 90.48%
# k 357 : score 90.48%
# k 358 : score 90.48%
# k 359 : score 90.48%
# k 360 : score 90.48%
# k 361 : score 90.48%
# k 362 : score 90.48%
# k 363 : score 90.48%
# k 364 : score 90.48%
# k 365 : score 90.48%
# k 366 : score 90.48%
# k 367 : score 90.48%
# k 368 : score 90.48%
# k 369 : score 90.48%
# k 370 : score 90.48%
# k 371 : score 90.48%
# k 372 : score 90.48%
# k 373 : score 90.48%
# k 374 : score 90.48%
# k 375 : score 90.48%
# k 376 : score 90.48%
# k 377 : score 90.48%
# k 378 : score 90.48%
# k 379 : score 90.48%
# k 380 : score 90.48%
# k 381 : score 90.48%
# k 382 : score 90.48%
# k 383 : score 90.48%
# k 384 : score 90.48%
# k 385 : score 90.48%
# k 386 : score 90.48%
# k 387 : score 90.48%
# k 388 : score 90.48%
# k 389 : score 90.48%
# k 390 : score 90.48%
# k 391 : score 90.48%
# k 392 : score 90.48%
# k 393 : score 90.48%
# k 394 : score 90.48%
# k 395 : score 90.48%
# k 396 : score 90.48%
# k 397 : score 90.48%
# k 398 : score 90.48%
# k 399 : score 90.48%
# k 400 : score 90.48%
# k 401 : score 90.48%
# k 402 : score 90.48%
# k 403 : score 90.48%
# k 404 : score 90.48%
# k 405 : score 90.48%
# k 406 : score 90.48%
# k 407 : score 90.48%
# k 408 : score 90.48%
# k 409 : score 90.48%
# k 410 : score 90.48%
# k 411 : score 90.48%
# k 412 : score 90.48%
# k 413 : score 90.48%
# k 414 : score 90.48%
# k 415 : score 90.48%
# k 416 : score 90.48%
# k 417 : score 90.48%
# k 418 : score 90.48%
# k 419 : score 90.48%
# k 420 : score 90.48%
# k 421 : score 90.48%
# k 422 : score 90.48%
# k 423 : score 90.48%
# k 424 : score 90.48%
# k 425 : score 90.48%
# k 426 : score 90.48%
# k 427 : score 90.48%
# k 428 : score 90.48%
# k 429 : score 90.48%
# k 430 : score 90.48%
# k 431 : score 90.48%
# k 432 : score 90.48%
# k 433 : score 90.48%
# k 434 : score 90.48%
# k 435 : score 90.48%
# k 436 : score 90.48%
# k 437 : score 90.48%
# k 438 : score 90.48%
# k 439 : score 90.48%
# k 440 : score 90.48%
# k 441 : score 90.48%
# k 442 : score 90.48%
# k 443 : score 90.48%
# k 444 : score 90.48%
# k 445 : score 90.48%
# k 446 : score 90.48%
# k 447 : score 90.48%
# k 448 : score 90.48%
# k 449 : score 90.48%
# k 450 : score 90.48%
# k 451 : score 90.48%
# k 452 : score 90.48%
# k 453 : score 90.48%
# k 454 : score 90.48%
# k 455 : score 90.48%
# k 456 : score 90.48%
# k 457 : score 90.48%
# k 458 : score 90.48%
# k 459 : score 90.48%
# k 460 : score 90.48%
# k 461 : score 90.48%
# k 462 : score 90.48%
# k 463 : score 90.48%
# k 464 : score 90.48%
# k 465 : score 90.48%
# k 466 : score 90.48%
# k 467 : score 90.48%
# k 468 : score 90.48%
# k 469 : score 90.48%
# k 470 : score 90.48%
# k 471 : score 90.48%
# k 472 : score 90.48%
# k 473 : score 90.48%
# k 474 : score 90.48%
# k 475 : score 90.48%
# k 476 : score 90.48%
# k 477 : score 90.48%
# k 478 : score 90.48%
# k 479 : score 90.48%
# k 480 : score 90.48%
# k 481 : score 90.48%
# k 482 : score 90.48%
# k 483 : score 90.48%
# k 484 : score 90.48%
# k 485 : score 90.48%
# k 486 : score 90.48%
# k 487 : score 90.48%
# k 488 : score 90.48%
# k 489 : score 90.48%
# k 490 : score 90.48%
# k 491 : score 90.48%
# k 492 : score 90.48%
# k 493 : score 90.48%
# k 494 : score 90.48%
# k 495 : score 90.48%
# k 496 : score 90.48%
# k 497 : score 90.48%
# k 498 : score 90.48%
# k 499 : score 90.48%
# k 500 : score 90.48%
# k 501 : score 90.48%
# k 502 : score 90.48%
# k 503 : score 90.48%
# k 504 : score 90.48%
# k 505 : score 90.48%
# k 506 : score 90.48%
# k 507 : score 90.48%
# k 508 : score 90.48%
# k 509 : score 90.48%
# k 510 : score 90.48%
# k 511 : score 90.48%
# k 512 : score 90.48%
# k 513 : score 90.48%
# k 514 : score 90.48%
# k 515 : score 90.48%
# k 516 : score 90.48%
# k 517 : score 90.48%
# k 518 : score 90.48%
# k 519 : score 90.48%
# k 520 : score 90.48%
# k 521 : score 90.48%
# k 522 : score 90.48%
# k 523 : score 90.48%
# k 524 : score 90.48%
# k 525 : score 90.48%
# k 526 : score 90.48%
# k 527 : score 90.48%
# k 528 : score 90.48%
# k 529 : score 90.48%
# k 530 : score 90.48%
# k 531 : score 90.48%
# k 532 : score 90.48%
# k 533 : score 90.48%
# k 534 : score 90.48%
# k 535 : score 90.48%
# k 536 : score 90.48%
# k 537 : score 90.48%
# k 538 : score 90.48%
# k 539 : score 90.48%
# k 540 : score 90.48%
# k 541 : score 90.48%
# k 542 : score 90.48%
# k 543 : score 90.48%
# k 544 : score 90.48%
# k 545 : score 90.48%
# k 546 : score 90.48%
# k 547 : score 90.48%
# k 548 : score 90.48%
# k 549 : score 90.48%
# k 550 : score 90.48%
# k 551 : score 90.48%
# k 552 : score 90.48%
# k 553 : score 90.48%
# k 554 : score 90.48%
# k 555 : score 90.48%
# k 556 : score 90.48%
# k 557 : score 90.48%
# k 558 : score 90.48%
# k 559 : score 90.48%
# k 560 : score 90.48%
# k 561 : score 90.48%
# k 562 : score 90.48%
# k 563 : score 90.48%
# k 564 : score 90.48%
# k 565 : score 90.48%
# k 566 : score 90.48%
# k 567 : score 90.48%
# k 568 : score 90.48%
# k 569 : score 90.48%
# k 570 : score 90.48%
# k 571 : score 90.48%
# k 572 : score 90.48%
# k 573 : score 90.48%
# k 574 : score 90.48%
# k 575 : score 90.48%
# k 576 : score 90.48%
# k 577 : score 90.48%
# k 578 : score 90.48%
# k 579 : score 90.48%
# k 580 : score 90.48%
# k 581 : score 90.48%
# k 582 : score 90.48%
# k 583 : score 90.48%
# k 584 : score 90.48%
# k 585 : score 90.48%
# k 586 : score 90.48%
# k 587 : score 90.48%
# k 588 : score 90.48%
# k 589 : score 90.48%
# k 590 : score 90.48%
# k 591 : score 90.48%
# k 592 : score 90.48%
# k 593 : score 90.48%
# k 594 : score 90.48%
# k 595 : score 90.48%
# k 596 : score 90.48%
# k 597 : score 90.48%
# k 598 : score 90.48%
# k 599 : score 90.48%
# k 600 : score 90.48%
# k 601 : score 90.48%
# k 602 : score 90.48%
# k 603 : score 90.48%
# k 604 : score 90.48%
# k 605 : score 90.48%
# k 606 : score 90.48%
# k 607 : score 90.48%
# k 608 : score 90.48%
# k 609 : score 90.48%
# k 610 : score 90.48%
# k 611 : score 90.48%
# k 612 : score 90.48%
# k 613 : score 90.48%
# k 614 : score 90.48%
# k 615 : score 90.48%
# k 616 : score 90.48%
# k 617 : score 90.48%
# k 618 : score 90.48%
# k 619 : score 90.48%
# k 620 : score 90.48%
# k 621 : score 90.48%
# k 622 : score 90.48%
# k 623 : score 90.48%
# k 624 : score 90.48%
# k 625 : score 90.48%
# k 626 : score 90.48%
# k 627 : score 90.48%
# k 628 : score 90.48%
# k 629 : score 90.48%
# k 630 : score 90.48%
# k 631 : score 90.48%
# k 632 : score 90.48%
# k 633 : score 90.48%
# k 634 : score 90.48%
# k 635 : score 90.48%
# k 636 : score 90.48%
# k 637 : score 90.48%
# k 638 : score 90.48%
# k 639 : score 90.48%
# k 640 : score 90.48%
# k 641 : score 90.48%
# k 642 : score 90.48%
# k 643 : score 90.48%
# k 644 : score 90.48%
# k 645 : score 90.48%
# k 646 : score 90.48%
# k 647 : score 90.48%
# k 648 : score 90.48%
# k 649 : score 90.48%
# k 650 : score 90.48%
# k 651 : score 90.48%
# k 652 : score 90.48%
# k 653 : score 90.48%
# k 654 : score 90.48%
# k 655 : score 90.48%
# k 656 : score 90.48%
# k 657 : score 90.48%
# k 658 : score 90.48%
# k 659 : score 90.48%
# k 660 : score 90.48%
# k 661 : score 90.48%
# k 662 : score 90.48%
#
# [MAX SCORE] : k 205 : score 0.9047619047619048%
# total_length_of_absence_10.0th,absence_ratio_10.0th,discipline_incidents_10.0th,gpa_est_10.0th,age_10.0th,log_median_10.0th,diff_total_length_of_absence_10.0th,total_length_of_absence_9.0th,diff_total_length_of_absence_8.0th,length_of_unexcused_absence_10.0th,diff_absence_ratio_10.0th,unexcused_absence_ratio_10.0th,absence_ratio_9.0th,gender_M,log_pop_10.0th,unemp_rate_10.0th,discipline_incidents_9.0th,total_length_of_absence_8.0th,other_program_10.0th,missing_intervention_10.0th,age_8.0th,absence_ratio_8.0th,gpa_miss_10.0th,gpa_est_9.0th,eighth_read_pl_Miss,extra_program_10.0th,ogt_math_pl_1.0,school_yr_unemp_rate_10.0th,district_TriValley_10.0th,total_length_of_absence_7.0th,log_mean_10.0th,disability_none_10.0th,gender_F,sixth_science_pl_1.0,age_9.0th,log_pop_8.0th,district_Coshocton_10.0th,absence_consec_count_10.0th,log_median_8.0th,zip_43720_10.0th,special_education_10.0th,fourth_math_pl_1.0,unexcused_absence_ratio_9.0th,sixth_write_pl_1.0,missing_intervention_9.0th,gpa_est_8.0th,gpa_est_7.0th,diff_unexcused_absence_ratio_10.0th,disability_learning disability_9.0th,retained_8.0th,ogt_socstudies_pl_Miss,diff_length_of_unexcused_absence_10.0th,disability_learning disability_10.0th,fourth_ctz_pl_1.0,log_pop_9.0th,disadvantagement_economic_10.0th,log_mean_9.0th,advanced_program_9.0th,zip_43821_10.0th,disadvantagement_Miss_9.0th,district_Franklin_10.0th,unemp_rate_9.0th,school_yr_unemp_rate_9.0th,district_Maysville_10.0th,disability_cognitive disability_9.0th,zip_43822_10.0th,sixth_ctz_pl_1.0,sixth_science_pl_Miss,zip_43842_10.0th,school_yr_unemp_rate_7.0th,other_program_9.0th,log_median_9.0th,ogt_read_pl_Miss,fourth_read_pl_1.0,length_of_unexcused_absence_9.0th,gpa_miss_8.0th,diff_absence_ratio_9.0th,diff_total_length_of_absence_7.0th,disadvantagement_Miss_10.0th,zip_43844_9.0th,ogt_write_pl_Miss,zip_43812_10.0th,advanced_program_10.0th,eighth_science_pl_Miss,sixth_read_pl_Miss,ogt_science_pl_Miss,sixth_write_pl_Miss,fourth_science_pl_Miss,zip_43735_9.0th,seventh_math_pl_Miss,extra_program_8.0th,retained_10.0th,zip_43821_9.0th,zip_43845_10.0th,fourth_write_pl_1.0,zip_43739_10.0th,district_Coshocton_8.0th,absence_suspension_10.0th,eighth_science_pl_1.0,missing_intervention_7.0th,fourth_science_pl_1.0,disability_Miss_10.0th,special_education_9.0th,seventh_read_pl_Miss,missing_intervention_8.0th,disadvantagement_economic_9.0th,log_mean_7.0th,district_Riverview_10.0th,disability_other minor_10.0th,sixth_read_pl_1.0,family_school_career_program_10.0th,sixth_ctz_pl_Miss,district_Coshocton_9.0th,zip_43843_10.0th,zip_43812_9.0th,discipline_incidents_8.0th,zip_43701_9.0th,extra_program_9.0th,age_7.0th,absence_suspension_9.0th,zip_43844_10.0th,limited_english_f_9.0th,disability_cognitive disability_8.0th,district_TriValley_9.0th,fourth_write_pl_Miss,district_Maysville_9.0th,limited_english_f_10.0th,district_Ridgewood_10.0th,fourth_math_pl_Miss,zip_43845_9.0th,log_pop_miss_7.0th,disability_none_9.0th,zip_43821_8.0th,zip_43830_10.0th,zip_0_8.0th,disability_cognitive disability_10.0th,zip_43701_10.0th,district_Ridgewood_9.0th,absence_consec_count_9.0th,tardy_consec_count_9.0th,fourth_ctz_pl_Miss,disability_emotional disturbance_10.0th,disadvantagement_Miss_8.0th,ogt_science_pl_1.0,ogt_write_pl_1.0,gpa_miss_9.0th,log_median_miss_7.0th,log_pop_miss_8.0th,district_TriValley_7.0th,diff_absence_ratio_8.0th,ogt_math_pl_Miss,disability_Miss_9.0th,seventh_read_pl_1.0,district_Riverview_9.0th,disability_none_8.0th,disability_multiple_8.0th,special_education_8.0th,eighth_math_pl_Miss,ethnicity_B,log_mean_8.0th,eighth_read_pl_1.0,gpa_miss_7.0th,diff_total_length_of_absence_9.0th,ogt_socstudies_pl_1.0,limited_english_Miss_10.0th,eighth_math_pl_1.0,district_Maysville_8.0th,retained_9.0th,log_mean_miss_9.0th,log_pop_miss_9.0th,zip_43822_8.0th,seventh_write_pl_Miss,days_tardy_10.0th,zip_0_9.0th,limited_english_Miss_9.0th,zip_43055_10.0th,seventh_math_pl_1.0,zip_43701_8.0th,zip_43777_10.0th,sixth_math_pl_1.0,ethnicity_W,zip_43056_8.0th,district_Franklin ...

# %%
recall_get_feature_importance(x_train, y_train, x_test, y_test, SVM)
# Out:
# k   1 : score  2.38%
# k   2 : score  2.38%
# k   3 : score  4.76%
# k   4 : score  9.52%
# k   5 : score  9.52%
# k   6 : score  9.52%
# k   7 : score 14.29%
# k   8 : score 20.24%
# k   9 : score 29.76%
# k  10 : score 34.52%
# k  11 : score 34.52%
# k  12 : score 34.52%
# k  13 : score 34.52%
# k  14 : score 34.52%
# k  15 : score 34.52%
# k  16 : score 34.52%
# k  17 : score 39.29%
# k  18 : score 42.86%
# k  19 : score 42.86%
# k  20 : score 42.86%
# k  21 : score 42.86%
# k  22 : score 42.86%
# k  23 : score 42.86%
# k  24 : score 42.86%
# k  25 : score 42.86%
# k  26 : score 42.86%
# k  27 : score 42.86%
# k  28 : score 42.86%
# k  29 : score 42.86%
# k  30 : score 42.86%
# k  31 : score 42.86%
# k  32 : score 42.86%
# k  33 : score 42.86%
# k  34 : score 42.86%
# k  35 : score 42.86%
# k  36 : score 42.86%
# k  37 : score 42.86%
# k  38 : score 42.86%
# k  39 : score 42.86%
# k  40 : score 42.86%
# k  41 : score 42.86%
# k  42 : score 42.86%
# k  43 : score 42.86%
# k  44 : score 42.86%
# k  45 : score 42.86%
# k  46 : score 42.86%
# k  47 : score 42.86%
# k  48 : score 42.86%
# k  49 : score 42.86%
# k  50 : score 42.86%
# k  51 : score 42.86%
# k  52 : score 42.86%
# k  53 : score 42.86%
# k  54 : score 42.86%
# k  55 : score 42.86%
# k  56 : score 42.86%
# k  57 : score 42.86%
# k  58 : score 42.86%
# k  59 : score 42.86%
# k  60 : score 42.86%
# k  61 : score 42.86%
# k  62 : score 42.86%
# k  63 : score 42.86%
# k  64 : score 42.86%
# k  65 : score 42.86%
# k  66 : score 42.86%
# k  67 : score 42.86%
# k  68 : score 42.86%
# k  69 : score 42.86%
# k  70 : score 42.86%
# k  71 : score 42.86%
# k  72 : score 42.86%
# k  73 : score 42.86%
# k  74 : score 42.86%
# k  75 : score 42.86%
# k  76 : score 42.86%
# k  77 : score 42.86%
# k  78 : score 42.86%
# k  79 : score 42.86%
# k  80 : score 42.86%
# k  81 : score 42.86%
# k  82 : score 42.86%
# k  83 : score 42.86%
# k  84 : score 42.86%
# k  85 : score 42.86%
# k  86 : score 42.86%
# k  87 : score 42.86%
# k  88 : score 42.86%
# k  89 : score 42.86%
# k  90 : score 42.86%
# k  91 : score 42.86%
# k  92 : score 42.86%
# k  93 : score 42.86%
# k  94 : score 42.86%
# k  95 : score 42.86%
# k  96 : score 42.86%
# k  97 : score 42.86%
# k  98 : score 42.86%
# k  99 : score 42.86%
# k 100 : score 42.86%
# k 101 : score 42.86%
# k 102 : score 42.86%
# k 103 : score 42.86%
# k 104 : score 42.86%
# k 105 : score 42.86%
# k 106 : score 42.86%
# k 107 : score 42.86%
# k 108 : score 42.86%
# k 109 : score 42.86%
# k 110 : score 42.86%
# k 111 : score 42.86%
# k 112 : score 42.86%
# k 113 : score 42.86%
# k 114 : score 42.86%
# k 115 : score 42.86%
# k 116 : score 42.86%
# k 117 : score 42.86%
# k 118 : score 42.86%
# k 119 : score 42.86%
# k 120 : score 42.86%
# k 121 : score 42.86%
# k 122 : score 42.86%
# k 123 : score 42.86%
# k 124 : score 42.86%
# k 125 : score 42.86%
# k 126 : score 42.86%
# k 127 : score 42.86%
# k 128 : score 42.86%
# k 129 : score 42.86%
# k 130 : score 42.86%
# k 131 : score 42.86%
# k 132 : score 42.86%
# k 133 : score 42.86%
# k 134 : score 42.86%
# k 135 : score 42.86%
# k 136 : score 42.86%
# k 137 : score 42.86%
# k 138 : score 42.86%
# k 139 : score 42.86%
# k 140 : score 42.86%
# k 141 : score 42.86%
# k 142 : score 42.86%
# k 143 : score 42.86%
# k 144 : score 42.86%
# k 145 : score 42.86%
# k 146 : score 42.86%
# k 147 : score 42.86%
# k 148 : score 42.86%
# k 149 : score 42.86%
# k 150 : score 42.86%
# k 151 : score 42.86%
# k 152 : score 42.86%
# k 153 : score 42.86%
# k 154 : score 42.86%
# k 155 : score 42.86%
# k 156 : score 42.86%
# k 157 : score 42.86%
# k 158 : score 42.86%
# k 159 : score 42.86%
# k 160 : score 42.86%
# k 161 : score 42.86%
# k 162 : score 42.86%
# k 163 : score 42.86%
# k 164 : score 42.86%
# k 165 : score 42.86%
# k 166 : score 42.86%
# k 167 : score 42.86%
# k 168 : score 42.86%
# k 169 : score 42.86%
# k 170 : score 42.86%
# k 171 : score 42.86%
# k 172 : score 42.86%
# k 173 : score 42.86%
# k 174 : score 42.86%
# k 175 : score 42.86%
# k 176 : score 42.86%
# k 177 : score 42.86%
# k 178 : score 42.86%
# k 179 : score 42.86%
# k 180 : score 42.86%
# k 181 : score 42.86%
# k 182 : score 42.86%
# k 183 : score 42.86%
# k 184 : score 42.86%
# k 185 : score 42.86%
# k 186 : score 42.86%
# k 187 : score 42.86%
# k 188 : score 42.86%
# k 189 : score 42.86%
# k 190 : score 42.86%
# k 191 : score 42.86%
# k 192 : score 42.86%
# k 193 : score 42.86%
# k 194 : score 42.86%
# k 195 : score 42.86%
# k 196 : score 42.86%
# k 197 : score 42.86%
# k 198 : score 42.86%
# k 199 : score 42.86%
# k 200 : score 42.86%
# k 201 : score 42.86%
# k 202 : score 42.86%
# k 203 : score 42.86%
# k 204 : score 42.86%
# k 205 : score 42.86%
# k 206 : score 42.86%
# k 207 : score 42.86%
# k 208 : score 42.86%
# k 209 : score 42.86%
# k 210 : score 42.86%
# k 211 : score 42.86%
# k 212 : score 42.86%
# k 213 : score 42.86%
# k 214 : score 42.86%
# k 215 : score 42.86%
# k 216 : score 42.86%
# k 217 : score 42.86%
# k 218 : score 42.86%
# k 219 : score 42.86%
# k 220 : score 42.86%
# k 221 : score 42.86%
# k 222 : score 42.86%
# k 223 : score 42.86%
# k 224 : score 42.86%
# k 225 : score 42.86%
# k 226 : score 42.86%
# k 227 : score 42.86%
# k 228 : score 42.86%
# k 229 : score 42.86%
# k 230 : score 42.86%
# k 231 : score 42.86%
# k 232 : score 42.86%
# k 233 : score 42.86%
# k 234 : score 42.86%
# k 235 : score 42.86%
# k 236 : score 42.86%
# k 237 : score 42.86%
# k 238 : score 42.86%
# k 239 : score 42.86%
# k 240 : score 42.86%
# k 241 : score 42.86%
# k 242 : score 42.86%
# k 243 : score 42.86%
# k 244 : score 42.86%
# k 245 : score 42.86%
# k 246 : score 42.86%
# k 247 : score 42.86%
# k 248 : score 42.86%
# k 249 : score 42.86%
# k 250 : score 42.86%
# k 251 : score 42.86%
# k 252 : score 42.86%
# k 253 : score 42.86%
# k 254 : score 42.86%
# k 255 : score 42.86%
# k 256 : score 42.86%
# k 257 : score 42.86%
# k 258 : score 42.86%
# k 259 : score 42.86%
# k 260 : score 42.86%
# k 261 : score 42.86%
# k 262 : score 42.86%
# k 263 : score 42.86%
# k 264 : score 42.86%
# k 265 : score 42.86%
# k 266 : score 42.86%
# k 267 : score 42.86%
# k 268 : score 42.86%
# k 269 : score 42.86%
# k 270 : score 42.86%
# k 271 : score 42.86%
# k 272 : score 42.86%
# k 273 : score 42.86%
# k 274 : score 42.86%
# k 275 : score 42.86%
# k 276 : score 42.86%
# k 277 : score 42.86%
# k 278 : score 42.86%
# k 279 : score 42.86%
# k 280 : score 42.86%
# k 281 : score 42.86%
# k 282 : score 42.86%
# k 283 : score 42.86%
# k 284 : score 42.86%
# k 285 : score 42.86%
# k 286 : score 42.86%
# k 287 : score 42.86%
# k 288 : score 42.86%
# k 289 : score 42.86%
# k 290 : score 42.86%
# k 291 : score 42.86%
# k 292 : score 42.86%
# k 293 : score 42.86%
# k 294 : score 42.86%
# k 295 : score 42.86%
# k 296 : score 42.86%
# k 297 : score 42.86%
# k 298 : score 42.86%
# k 299 : score 42.86%
# k 300 : score 42.86%
# k 301 : score 42.86%
# k 302 : score 42.86%
# k 303 : score 42.86%
# k 304 : score 42.86%
# k 305 : score 42.86%
# k 306 : score 42.86%
# k 307 : score 42.86%
# k 308 : score 42.86%
# k 309 : score 42.86%
# k 310 : score 42.86%
# k 311 : score 42.86%
# k 312 : score 42.86%
# k 313 : score 42.86%
# k 314 : score 42.86%
# k 315 : score 42.86%
# k 316 : score 42.86%
# k 317 : score 42.86%
# k 318 : score 42.86%
# k 319 : score 42.86%
# k 320 : score 42.86%
# k 321 : score 42.86%
# k 322 : score 42.86%
# k 323 : score 42.86%
# k 324 : score 42.86%
# k 325 : score 42.86%
# k 326 : score 42.86%
# k 327 : score 42.86%
# k 328 : score 42.86%
# k 329 : score 42.86%
# k 330 : score 42.86%
# k 331 : score 42.86%
# k 332 : score 42.86%
# k 333 : score 42.86%
# k 334 : score 42.86%
# k 335 : score 42.86%
# k 336 : score 42.86%
# k 337 : score 42.86%
# k 338 : score 42.86%
# k 339 : score 42.86%
# k 340 : score 42.86%
# k 341 : score 42.86%
# k 342 : score 42.86%
# k 343 : score 42.86%
# k 344 : score 42.86%
# k 345 : score 42.86%
# k 346 : score 42.86%
# k 347 : score 42.86%
# k 348 : score 42.86%
# k 349 : score 42.86%
# k 350 : score 42.86%
# k 351 : score 42.86%
# k 352 : score 42.86%
# k 353 : score 42.86%
# k 354 : score 42.86%
# k 355 : score 42.86%
# k 356 : score 42.86%
# k 357 : score 42.86%
# k 358 : score 42.86%
# k 359 : score 42.86%
# k 360 : score 42.86%
# k 361 : score 42.86%
# k 362 : score 42.86%
# k 363 : score 42.86%
# k 364 : score 42.86%
# k 365 : score 42.86%
# k 366 : score 42.86%
# k 367 : score 42.86%
# k 368 : score 42.86%
# k 369 : score 42.86%
# k 370 : score 42.86%
# k 371 : score 42.86%
# k 372 : score 42.86%
# k 373 : score 42.86%
# k 374 : score 42.86%
# k 375 : score 42.86%
# k 376 : score 42.86%
# k 377 : score 42.86%
# k 378 : score 42.86%
# k 379 : score 42.86%
# k 380 : score 42.86%
# k 381 : score 42.86%
# k 382 : score 42.86%
# k 383 : score 42.86%
# k 384 : score 42.86%
# k 385 : score 42.86%
# k 386 : score 42.86%
# k 387 : score 42.86%
# k 388 : score 42.86%
# k 389 : score 42.86%
# k 390 : score 42.86%
# k 391 : score 42.86%
# k 392 : score 42.86%
# k 393 : score 42.86%
# k 394 : score 42.86%
# k 395 : score 42.86%
# k 396 : score 42.86%
# k 397 : score 42.86%
# k 398 : score 42.86%
# k 399 : score 42.86%
# k 400 : score 42.86%
# k 401 : score 42.86%
# k 402 : score 42.86%
# k 403 : score 42.86%
# k 404 : score 42.86%
# k 405 : score 42.86%
# k 406 : score 42.86%
# k 407 : score 42.86%
# k 408 : score 42.86%
# k 409 : score 42.86%
# k 410 : score 42.86%
# k 411 : score 42.86%
# k 412 : score 42.86%
# k 413 : score 42.86%
# k 414 : score 42.86%
# k 415 : score 42.86%
# k 416 : score 42.86%
# k 417 : score 42.86%
# k 418 : score 42.86%
# k 419 : score 42.86%
# k 420 : score 42.86%
# k 421 : score 42.86%
# k 422 : score 42.86%
# k 423 : score 42.86%
# k 424 : score 42.86%
# k 425 : score 42.86%
# k 426 : score 42.86%
# k 427 : score 42.86%
# k 428 : score 42.86%
# k 429 : score 42.86%
# k 430 : score 42.86%
# k 431 : score 42.86%
# k 432 : score 42.86%
# k 433 : score 42.86%
# k 434 : score 42.86%
# k 435 : score 42.86%
# k 436 : score 42.86%
# k 437 : score 42.86%
# k 438 : score 42.86%
# k 439 : score 42.86%
# k 440 : score 42.86%
# k 441 : score 42.86%
# k 442 : score 42.86%
# k 443 : score 42.86%
# k 444 : score 42.86%
# k 445 : score 42.86%
# k 446 : score 42.86%
# k 447 : score 42.86%
# k 448 : score 42.86%
# k 449 : score 42.86%
# k 450 : score 42.86%
# k 451 : score 42.86%
# k 452 : score 42.86%
# k 453 : score 42.86%
# k 454 : score 42.86%
# k 455 : score 42.86%
# k 456 : score 42.86%
# k 457 : score 42.86%
# k 458 : score 42.86%
# k 459 : score 42.86%
# k 460 : score 42.86%
# k 461 : score 42.86%
# k 462 : score 42.86%
# k 463 : score 42.86%
# k 464 : score 42.86%
# k 465 : score 42.86%
# k 466 : score 42.86%
# k 467 : score 42.86%
# k 468 : score 42.86%
# k 469 : score 42.86%
# k 470 : score 42.86%
# k 471 : score 42.86%
# k 472 : score 42.86%
# k 473 : score 42.86%
# k 474 : score 42.86%
# k 475 : score 42.86%
# k 476 : score 42.86%
# k 477 : score 42.86%
# k 478 : score 42.86%
# k 479 : score 42.86%
# k 480 : score 42.86%
# k 481 : score 42.86%
# k 482 : score 42.86%
# k 483 : score 42.86%
# k 484 : score 42.86%
# k 485 : score 42.86%
# k 486 : score 42.86%
# k 487 : score 42.86%
# k 488 : score 42.86%
# k 489 : score 42.86%
# k 490 : score 42.86%
# k 491 : score 42.86%
# k 492 : score 42.86%
# k 493 : score 42.86%
# k 494 : score 42.86%
# k 495 : score 42.86%
# k 496 : score 42.86%
# k 497 : score 42.86%
# k 498 : score 42.86%
# k 499 : score 42.86%
# k 500 : score 42.86%
# k 501 : score 42.86%
# k 502 : score 42.86%
# k 503 : score 42.86%
# k 504 : score 42.86%
# k 505 : score 42.86%
# k 506 : score 42.86%
# k 507 : score 42.86%
# k 508 : score 42.86%
# k 509 : score 42.86%
# k 510 : score 42.86%
# k 511 : score 42.86%
# k 512 : score 42.86%
# k 513 : score 42.86%
# k 514 : score 42.86%
# k 515 : score 42.86%
# k 516 : score 42.86%
# k 517 : score 42.86%
# k 518 : score 42.86%
# k 519 : score 42.86%
# k 520 : score 42.86%
# k 521 : score 42.86%
# k 522 : score 42.86%
# k 523 : score 42.86%
# k 524 : score 42.86%
# k 525 : score 42.86%
# k 526 : score 42.86%
# k 527 : score 42.86%
# k 528 : score 42.86%
# k 529 : score 42.86%
# k 530 : score 42.86%
# k 531 : score 42.86%
# k 532 : score 42.86%
# k 533 : score 42.86%
# k 534 : score 42.86%
# k 535 : score 42.86%
# k 536 : score 42.86%
# k 537 : score 42.86%
# k 538 : score 42.86%
# k 539 : score 42.86%
# k 540 : score 42.86%
# k 541 : score 42.86%
# k 542 : score 42.86%
# k 543 : score 42.86%
# k 544 : score 42.86%
# k 545 : score 42.86%
# k 546 : score 42.86%
# k 547 : score 42.86%
# k 548 : score 42.86%
# k 549 : score 42.86%
# k 550 : score 42.86%
# k 551 : score 42.86%
# k 552 : score 42.86%
# k 553 : score 42.86%
# k 554 : score 42.86%
# k 555 : score 42.86%
# k 556 : score 42.86%
# k 557 : score 42.86%
# k 558 : score 42.86%
# k 559 : score 42.86%
# k 560 : score 42.86%
# k 561 : score 42.86%
# k 562 : score 42.86%
# k 563 : score 42.86%
# k 564 : score 42.86%
# k 565 : score 42.86%
# k 566 : score 42.86%
# k 567 : score 42.86%
# k 568 : score 42.86%
# k 569 : score 42.86%
# k 570 : score 42.86%
# k 571 : score 42.86%
# k 572 : score 42.86%
# k 573 : score 42.86%
# k 574 : score 42.86%
# k 575 : score 42.86%
# k 576 : score 42.86%
# k 577 : score 42.86%
# k 578 : score 42.86%
# k 579 : score 42.86%
# k 580 : score 42.86%
# k 581 : score 42.86%
# k 582 : score 42.86%
# k 583 : score 42.86%
# k 584 : score 42.86%
# k 585 : score 42.86%
# k 586 : score 42.86%
# k 587 : score 42.86%
# k 588 : score 42.86%
# k 589 : score 42.86%
# k 590 : score 42.86%
# k 591 : score 42.86%
# k 592 : score 42.86%
# k 593 : score 42.86%
# k 594 : score 42.86%
# k 595 : score 42.86%
# k 596 : score 42.86%
# k 597 : score 42.86%
# k 598 : score 42.86%
# k 599 : score 42.86%
# k 600 : score 42.86%
# k 601 : score 42.86%
# k 602 : score 42.86%
# k 603 : score 42.86%
# k 604 : score 42.86%
# k 605 : score 42.86%
# k 606 : score 42.86%
# k 607 : score 42.86%
# k 608 : score 42.86%
# k 609 : score 42.86%
# k 610 : score 42.86%
# k 611 : score 42.86%
# k 612 : score 42.86%
# k 613 : score 42.86%
# k 614 : score 42.86%
# k 615 : score 42.86%
# k 616 : score 42.86%
# k 617 : score 42.86%
# k 618 : score 42.86%
# k 619 : score 42.86%
# k 620 : score 42.86%
# k 621 : score 42.86%
# k 622 : score 42.86%
# k 623 : score 42.86%
# k 624 : score 42.86%
# k 625 : score 42.86%
# k 626 : score 42.86%
# k 627 : score 42.86%
# k 628 : score 42.86%
# k 629 : score 42.86%
# k 630 : score 42.86%
# k 631 : score 42.86%
# k 632 : score 42.86%
# k 633 : score 42.86%
# k 634 : score 42.86%
# k 635 : score 42.86%
# k 636 : score 42.86%
# k 637 : score 42.86%
# k 638 : score 42.86%
# k 639 : score 42.86%
# k 640 : score 42.86%
# k 641 : score 42.86%
# k 642 : score 42.86%
# k 643 : score 42.86%
# k 644 : score 42.86%
# k 645 : score 42.86%
# k 646 : score 42.86%
# k 647 : score 42.86%
# k 648 : score 42.86%
# k 649 : score 42.86%
# k 650 : score 42.86%
# k 651 : score 42.86%
# k 652 : score 42.86%
# k 653 : score 42.86%
# k 654 : score 42.86%
# k 655 : score 42.86%
# k 656 : score 42.86%
# k 657 : score 42.86%
# k 658 : score 42.86%
# k 659 : score 42.86%
# k 660 : score 42.86%
# k 661 : score 42.86%
# k 662 : score 42.86%
#
# [MAX SCORE] : k 18 : score 0.42857142857142855%
# total_length_of_absence_10.0th,absence_ratio_10.0th,discipline_incidents_10.0th,gpa_est_10.0th,age_10.0th,log_median_10.0th,diff_total_length_of_absence_10.0th,total_length_of_absence_9.0th,diff_total_length_of_absence_8.0th,length_of_unexcused_absence_10.0th,diff_absence_ratio_10.0th,unexcused_absence_ratio_10.0th,absence_ratio_9.0th,gender_M,log_pop_10.0th,unemp_rate_10.0th,discipline_incidents_9.0th,total_length_of_absence_8.0th

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_explained_var(X_train, col_length):

    cov_mat = np.cov(X_train.T)
    eigen_vals, eigen_vecs = np.linalg.eig(cov_mat)

    print('\nEigenvalues \n{}s'.format(eigen_vals))

    tot = sum(eigen_vals)
    var_exp = [(i / tot) for i in sorted(eigen_vals, reverse=True)]
    cum_var_exp = np.cumsum(var_exp)

    plt.bar(range(1, col_length+1), var_exp, alpha=0.5, align='center',
            label='individual explained variance')
    plt.step(range(1, col_length+1), cum_var_exp, where='mid',
             label='cumulative explained variance')
    plt.ylabel('Explained variance ratio')
    plt.xlabel('Principal components')
    plt.legend(loc='best')
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_importance(classifier, X, Y):
    '''
    Evaluate a classifier and identify important feature
    and show each score for evaluation
    Inputs:
      classifier (sklearn model)
      X (dataframe)
      Y (dataframe)
    '''
    classifier.fit(X, Y)
    values, names = zip(*sorted(
                    zip(classifier.feature_importances_,
                        X.columns)))
    length = len(X.columns)
    plt.figure(figsize=(length,length))
    plt.barh(range(len(names)), values, align='center')
    plt.yticks(range(len(names)), names)

# %%
a = 'total_length_of_absence_10.0th,absence_ratio_10.0th,discipline_incidents_10.0th,gpa_est_10.0th,age_10.0th,log_median_10.0th,diff_total_length_of_absence_10.0th,total_length_of_absence_9.0th,diff_total_length_of_absence_8.0th,length_of_unexcused_absence_10.0th,diff_absence_ratio_10.0th,unexcused_absence_ratio_10.0th,absence_ratio_9.0th,gender_M,log_pop_10.0th,unemp_rate_10.0th,discipline_incidents_9.0th,total_length_of_absence_8.0th,other_program_10.0th,missing_intervention_10.0th,age_8.0th,absence_ratio_8.0th,gpa_miss_10.0th,gpa_est_9.0th,eighth_read_pl_Miss'

# %%
al = a.split(',')

# %%
X_train = x_train[al]
X_test = x_test[al]

# %%
plot_importance(RF, x_train[al], y_train)

# %%
plot_explained_var(X_train, len(al))
# Out:
# Eigenvalues
# [1.12438648e+02 7.24542161e+01 4.20746503e+01 2.49453180e+01
#  1.13447700e+01 9.27398289e+00 7.61693370e+00 3.53203560e+00
#  2.91884808e+00 2.47738315e+00 2.13088833e+00 1.92243026e+00
#  7.63526879e-01 3.58420718e-01 2.56481039e-01 2.15746044e-01
#  1.18261709e-01 7.90495528e-02 3.63788349e-02 1.06410912e-02
#  1.77433984e-03 8.38472053e-04 4.64468283e-04 1.91068748e-04
#  2.68441363e-04]s

# %%
b = 'total_length_of_absence_10.0th,absence_ratio_10.0th,discipline_incidents_10.0th,gpa_est_10.0th,age_10.0th,log_median_10.0th,diff_total_length_of_absence_10.0th,total_length_of_absence_9.0th,diff_total_length_of_absence_8.0th,length_of_unexcused_absence_10.0th,diff_absence_ratio_10.0th,unexcused_absence_ratio_10.0th,absence_ratio_9.0th,gender_M,log_pop_10.0th,unemp_rate_10.0th,discipline_incidents_9.0th,total_length_of_absence_8.0th'

# %%
bl = b.split(',')

# %%
X_train2 = x_train[bl]
X_test2 = x_test[bl]

# %%
plot_importance(RF, x_train[bl], y_train)

# %%
plot_explained_var(X_train2, len(bl))
# Out:
# Eigenvalues
# [9.96501374e+01 6.84758970e+01 2.96701893e+01 1.55460177e+01
#  1.13337136e+01 8.82812043e+00 3.52919483e+00 3.07380707e+00
#  2.48671598e+00 2.09376157e+00 1.76485896e+00 3.53009335e-01
#  2.34573881e-01 1.08661376e-02 1.80038270e-03 8.49430594e-04
#  1.94412176e-04 4.81407190e-04]s

# %%
bl
# Out:
# ['total_length_of_absence_10.0th',
#  'absence_ratio_10.0th',
#  'discipline_incidents_10.0th',
#  'gpa_est_10.0th',
#  'age_10.0th',
#  'log_median_10.0th',
#  'diff_total_length_of_absence_10.0th',
#  'total_length_of_absence_9.0th',
#  'diff_total_length_of_absence_8.0th',
#  'length_of_unexcused_absence_10.0th',
#  'diff_absence_ratio_10.0th',
#  'unexcused_absence_ratio_10.0th',
#  'absence_ratio_9.0th',
#  'gender_M',
#  'log_pop_10.0th',
#  'unemp_rate_10.0th',
#  'discipline_incidents_9.0th',
#  'total_length_of_absence_8.0th']

# %%
['total_length_of_absence_10.0th',
 'absence_ratio_10.0th',
 'discipline_incidents_10.0th',
 'gpa_est_10.0th',
 'log_median_10.0th',
 'total_length_of_absence_9.0th']
