# %% [markdown]
# # 1 Read Data

# %%
import Analysis
# %matplotlib inline

# %%
df = Analysis.load_data()

# %% [markdown]
# # 2 Explore Data

# %%
Analysis.summary_x(df)
# Out:
#        RevolvingUtilizationOfUnsecuredLines            age        zipcode  \
# count                         150000.000000  150000.000000  150000.000000
# mean                               6.048438      52.295207   60648.810013
# std                              249.755371      14.771866      56.748197
# min                                0.000000       0.000000   60601.000000
# 25%                                0.029867      41.000000   60625.000000
# 50%                                0.154181      52.000000   60629.000000
# 75%                                0.559046      63.000000   60644.000000
# max                            50708.000000     109.000000   60804.000000
#
#          Less2months      DebtRatio  MonthlyIncome  \
# count  150000.000000  150000.000000   1.202690e+05
# mean        0.421033     353.005076   6.670221e+03
# std         4.192781    2037.818523   1.438467e+04
# min         0.000000       0.000000   0.000000e+00
# ...

# %%
Analysis.summary_y(df)
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64

# %%
Analysis.corr(df)
# Out:
#                                       RevolvingUtilizationOfUnsecuredLines  \
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.005898
# zipcode                                                          -0.003571
# Less2months                                                      -0.001314
# DebtRatio                                                         0.003961
# MonthlyIncome                                                     0.007124
# NumberOfOpenCreditLinesAndLoans                                  -0.011281
# More3months                                                      -0.001061
# NumberRealEstateLoansOrLines                                      0.006235
# Less3months                                                      -0.001048
# NumberOfDependents                                                0.001557
#
# ...

# %%
Analysis.plot_corr(df)

# %%
Analysis.count_null(df)
# Out:
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# zipcode                                     0
# Less2months                                 0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# More3months                                 0
# NumberRealEstateLoansOrLines                0
# Less3months                                 0
# NumberOfDependents                       3924
# dtype: int64

# %%
Analysis.show_dist(df, 'SeriousDlqin2yrs')
