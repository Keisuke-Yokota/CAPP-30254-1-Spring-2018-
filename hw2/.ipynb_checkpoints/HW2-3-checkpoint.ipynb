# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('cs-training.csv', header=0)
df.reset_index()
df = df.rename(columns={'Unnamed: 0':'ID', 
                        'NumberOfTime30-59DaysPastDueNotWorse':'Less2months',
                       'NumberOfTimes90DaysLate':'More3months',
                       'NumberOfTime60-89DaysPastDueNotWorse':'Less3months'})
df = df.set_index('ID')

# %%
df = df.fillna(df.mean())

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
df_std = sc.fit_transform( df.iloc[:, 1:])

# %%
df_std = pd.DataFrame(df_std)
df_std.index = df_std.index + 1
df_std.columns = df.iloc[:, 1:].columns
df_std.describe()
# Out:
#        RevolvingUtilizationOfUnsecuredLines           age   Less2months  \
# count                          1.500000e+05  1.500000e+05  1.500000e+05
# mean                          -5.684342e-18  9.274951e-17  8.715991e-18
# std                            1.000003e+00  1.000003e+00  1.000003e+00
# min                           -2.421753e-02 -3.540201e+00 -1.004190e-01
# 25%                           -2.409794e-02 -7.646457e-01 -1.004190e-01
# 50%                           -2.360020e-02 -1.998445e-02 -1.004190e-01
# 75%                           -2.197915e-02  7.246768e-01 -1.004190e-01
# max                            2.030071e+02  3.838715e+00  2.327317e+01
#
#           DebtRatio  MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# count  1.500000e+05   1.500000e+05                     1.500000e+05
# mean  -2.415845e-18  -1.999941e-16                     8.014922e-17
# std    1.000003e+00   1.000003e+00                     1.000003e+00
# min   -1.732275e-01  -5.178581e-01                    -1.642610e+00
# 25%   -1.731416e-01  -2.148397e-01                    -6.709686e-01
# 50%   -1.730477e-01  -5.451789e-03                    -8.798403e-02
# 75%   -1.728015e-01   5.665807e-02                     4.950005e-01
# max    1.616003e+02   2.330734e+02                     9.628425e+00
#
#         More3months  NumberRealEstateLoansOrLines   Less3months  \
# count  1.500000e+05                  1.500000e+05  1.500000e+05
# mean   1.667407e-17                 -1.610564e-17  2.354265e-17
# std    1.000003e+00                  1.000003e+00  1.000003e+00
# min   -6.379344e-02                 -9.012830e-01 -5.785249e-02
# 25%   -6.379344e-02                 -9.012830e-01 -5.785249e-02
# 50%   -6.379344e-02                 -1.614492e-02 -5.785249e-02
# 75%   -6.379344e-02                  8.689932e-01 -5.785249e-02
# max    2.344141e+01                  4.689617e+01  2.352725e+01
#
#        NumberOfDependents
# count        1.500000e+05
# mean         6.077509e-17
# std          1.000003e+00
# min         -6.881334e-01
# 25%         -6.881334e-01
# 50%         -6.881334e-01
# 75%          2.206267e-01
# max          1.748707e+01

# %%
new_df = pd.concat([df.iloc[:, 0], df_std], axis=1)
new_df.corr()
# Out:
#                                       SeriousDlqin2yrs  \
# SeriousDlqin2yrs                              1.000000
# RevolvingUtilizationOfUnsecuredLines         -0.001802
# age                                          -0.115386
# Less2months                                   0.125587
# DebtRatio                                    -0.007602
# MonthlyIncome                                -0.018002
# NumberOfOpenCreditLinesAndLoans              -0.029669
# More3months                                   0.117175
# NumberRealEstateLoansOrLines                 -0.007038
# Less3months                                   0.102261
# NumberOfDependents                            0.045621
#
#                                       RevolvingUtilizationOfUnsecuredLines  \
# SeriousDlqin2yrs                                                 -0.001802
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.005898
# Less2months                                                      -0.001314
# DebtRatio                                                         0.003961
# MonthlyIncome                                                     0.006565
# NumberOfOpenCreditLinesAndLoans                                  -0.011281
# More3months                                                      -0.001061
# NumberRealEstateLoansOrLines                                      0.006235
# Less3months                                                      -0.001048
# NumberOfDependents                                                0.001539
#
#                                            age  Less2months  DebtRatio  \
# SeriousDlqin2yrs                     -0.115386     0.125587  -0.007602
# RevolvingUtilizationOfUnsecuredLines -0.005898    -0.001314   0.003961
# age                                   1.000000    -0.062995   0.024188
# Less2months                          -0.062995     1.000000  -0.006542
# DebtRatio                             0.024188    -0.006542   1.000000
# MonthlyIncome                         0.032984    -0.007636  -0.005355
# NumberOfOpenCreditLinesAndLoans       0.147705    -0.055312   0.049565
# More3months                          -0.061005     0.983603  -0.008320
# NumberRealEstateLoansOrLines          0.033150    -0.030565   0.120046
# Less3months                          -0.057159     0.987005  -0.007533
# NumberOfDependents                   -0.208102    -0.002525  -0.038287
#
#                                       MonthlyIncome  \
# SeriousDlqin2yrs                          -0.018002
# RevolvingUtilizationOfUnsecuredLines       0.006565
# age                                        0.032984
# Less2months                               -0.007636
# DebtRatio                                 -0.005355
# MonthlyIncome                              1.000000
# NumberOfOpenCreditLinesAndLoans            0.082319
# More3months                               -0.009484
# NumberRealEstateLoansOrLines               0.113823
# Less3months                               -0.008259
# NumberOfDependents                         0.058542
#
#                                       NumberOfOpenCreditLinesAndLoans  \
# SeriousDlqin2yrs                                            -0.029669
# RevolvingUtilizationOfUnsecuredLines                        -0.011281
# age                                                          0.147705
# Less2months                                                 -0.055312
# DebtRatio                                                    0.049565
# MonthlyIncome                                                0.082319
# NumberOfOpenCreditLinesAndLoans                              1.000000
# More3months                                                 -0.079984
# NumberRealEstateLoansOrLines                                 0.433959
# Less3months                                                 -0.071077
# NumberOfDependents                                           0.064507
#
#                                       More3months  \
# SeriousDlqin2yrs                         0.117175
# RevolvingUtilizationOfUnsecuredLines    -0.001061
# age                                     -0.061005
# Less2months                              0.983603
# DebtRatio                               -0.008320
# MonthlyIncome                           -0.009484
# NumberOfOpenCreditLinesAndLoans         -0.079984
# More3months                              1.000000
# NumberRealEstateLoansOrLines            -0.045205
# Less3months                              0.992796
# NumberOfDependents                      -0.009579
#
#                                       NumberRealEstateLoansOrLines  \
# SeriousDlqin2yrs                                         -0.007038
# RevolvingUtilizationOfUnsecuredLines                      0.006235
# age                                                       0.033150
# Less2months                                              -0.030565
# DebtRatio                                                 0.120046
# MonthlyIncome                                             0.113823
# NumberOfOpenCreditLinesAndLoans                           0.433959
# More3months                                              -0.045205
# NumberRealEstateLoansOrLines                              1.000000
# Less3months                                              -0.039722
# NumberOfDependents                                        0.123370
#
#                                       Less3months  NumberOfDependents
# SeriousDlqin2yrs                         0.102261            0.045621
# RevolvingUtilizationOfUnsecuredLines    -0.001048            0.001539
# age                                     -0.057159           -0.208102
# Less2months                              0.987005           -0.002525
# DebtRatio                               -0.007533           -0.038287
# MonthlyIncome                           -0.008259            0.058542
# NumberOfOpenCreditLinesAndLoans         -0.071077            0.064507
# More3months                              0.992796           -0.009579
# NumberRealEstateLoansOrLines            -0.039722            0.123370
# Less3months                              1.000000           -0.010277
# NumberOfDependents                      -0.010277            1.000000

# %%
import Analysis

# %%
winzored_df = Analysis.outlier_iqr(df.iloc[:, 1:].fillna(df.mean()))
winzored_df.describe()
# Out:
# /home/student/CAPP-30254-1-Spring-2018-/hw2/Analysis.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   col[col < outlier_min] = None
# /home/student/CAPP-30254-1-Spring-2018-/hw2/Analysis.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   col[col > outlier_max] = None
#        RevolvingUtilizationOfUnsecuredLines            age  Less2months  \
# count                         150000.000000  149954.000000     126018.0
# mean                               6.048438      52.281400          0.0
# std                              249.755371      14.750789          0.0
# min                                0.000000      21.000000          0.0
# 25%                                0.029867      41.000000          0.0
# 50%                                0.154181      52.000000          0.0
# 75%                                0.559046      63.000000          0.0
# max                            50708.000000      96.000000          0.0
#
#            DebtRatio  MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# count  118689.000000  140851.000000                    146020.000000
# mean        0.334880    5705.734390                         8.009690
# std         0.285963    2636.930625                         4.385546
# min         0.000000       0.000000                         0.000000
# 25%         0.131934    3750.000000                         5.000000
# 50%         0.284085    6172.000000                         7.000000
# 75%         0.459711    6670.221237                        11.000000
# max         1.906765   12645.000000                        20.000000
#
#        More3months  NumberRealEstateLoansOrLines  Less3months  \
# count     141662.0                 149207.000000     142396.0
# mean           0.0                      0.981234          0.0
# std            0.0                      0.980390          0.0
# min            0.0                      0.000000          0.0
# 25%            0.0                      0.000000          0.0
# 50%            0.0                      1.000000          0.0
# 75%            0.0                      2.000000          0.0
# max            0.0                      5.000000          0.0
#
#        NumberOfDependents
# count       136664.000000
# mean             0.499995
# std              0.728299
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              2.000000

# %%
winzored_df.corr()
# Out:
#                                       RevolvingUtilizationOfUnsecuredLines  \
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.005885
# Less2months                                                            NaN
# DebtRatio                                                         0.001275
# MonthlyIncome                                                     0.010511
# NumberOfOpenCreditLinesAndLoans                                  -0.011707
# More3months                                                            NaN
# NumberRealEstateLoansOrLines                                      0.007670
# Less3months                                                            NaN
# NumberOfDependents                                                0.002190
#
#                                            age  Less2months  DebtRatio  \
# RevolvingUtilizationOfUnsecuredLines -0.005885          NaN   0.001275
# age                                   1.000000          NaN  -0.059915
# Less2months                                NaN          NaN        NaN
# DebtRatio                            -0.059915          NaN   1.000000
# MonthlyIncome                         0.122596          NaN  -0.128157
# NumberOfOpenCreditLinesAndLoans       0.140767          NaN   0.338743
# More3months                                NaN          NaN        NaN
# NumberRealEstateLoansOrLines          0.036529          NaN   0.493821
# Less3months                                NaN          NaN        NaN
# NumberOfDependents                   -0.173027          NaN   0.088066
#
#                                       MonthlyIncome  \
# RevolvingUtilizationOfUnsecuredLines       0.010511
# age                                        0.122596
# Less2months                                     NaN
# DebtRatio                                 -0.128157
# MonthlyIncome                              1.000000
# NumberOfOpenCreditLinesAndLoans            0.209894
# More3months                                     NaN
# NumberRealEstateLoansOrLines               0.288119
# Less3months                                     NaN
# NumberOfDependents                         0.102164
#
#                                       NumberOfOpenCreditLinesAndLoans  \
# RevolvingUtilizationOfUnsecuredLines                        -0.011707
# age                                                          0.140767
# Less2months                                                       NaN
# DebtRatio                                                    0.338743
# MonthlyIncome                                                0.209894
# NumberOfOpenCreditLinesAndLoans                              1.000000
# More3months                                                       NaN
# NumberRealEstateLoansOrLines                                 0.434484
# Less3months                                                       NaN
# NumberOfDependents                                           0.085088
#
#                                       More3months  \
# RevolvingUtilizationOfUnsecuredLines          NaN
# age                                           NaN
# Less2months                                   NaN
# DebtRatio                                     NaN
# MonthlyIncome                                 NaN
# NumberOfOpenCreditLinesAndLoans               NaN
# More3months                                   NaN
# NumberRealEstateLoansOrLines                  NaN
# Less3months                                   NaN
# NumberOfDependents                            NaN
#
#                                       NumberRealEstateLoansOrLines  \
# RevolvingUtilizationOfUnsecuredLines                      0.007670
# age                                                       0.036529
# Less2months                                                    NaN
# DebtRatio                                                 0.493821
# MonthlyIncome                                             0.288119
# NumberOfOpenCreditLinesAndLoans                           0.434484
# More3months                                                    NaN
# NumberRealEstateLoansOrLines                              1.000000
# Less3months                                                    NaN
# NumberOfDependents                                        0.135321
#
#                                       Less3months  NumberOfDependents
# RevolvingUtilizationOfUnsecuredLines          NaN            0.002190
# age                                           NaN           -0.173027
# Less2months                                   NaN                 NaN
# DebtRatio                                     NaN            0.088066
# MonthlyIncome                                 NaN            0.102164
# NumberOfOpenCreditLinesAndLoans               NaN            0.085088
# More3months                                   NaN                 NaN
# NumberRealEstateLoansOrLines                  NaN            0.135321
# Less3months                                   NaN                 NaN
# NumberOfDependents                            NaN            1.000000
