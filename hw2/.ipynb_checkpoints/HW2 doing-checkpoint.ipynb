# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('cs-training.csv')
df = df.rename(columns={'Unnamed: 0':'ID', 
                        'NumberOfTime30-59DaysPastDueNotWorse':'Less2months',
                       'NumberOfTimes90DaysLate':'More3months',
                       'NumberOfTime60-89DaysPastDueNotWorse':'Less3months'})
df = df.set_index('ID')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150000 entries, 1 to 150000
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        150000 non-null int64
# RevolvingUtilizationOfUnsecuredLines    150000 non-null float64
# age                                     150000 non-null int64
# Less2months                             150000 non-null int64
# DebtRatio                               150000 non-null float64
# MonthlyIncome                           120269 non-null float64
# NumberOfOpenCreditLinesAndLoans         150000 non-null int64
# More3months                             150000 non-null int64
# NumberRealEstateLoansOrLines            150000 non-null int64
# Less3months                             150000 non-null int64
# NumberOfDependents                      146076 non-null float64
# dtypes: float64(4), int64(7)
# memory usage: 13.7 MB

# %%
df.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count     150000.000000                         150000.000000  150000.000000
# mean           0.066840                              6.048438      52.295207
# std            0.249746                            249.755371      14.771866
# min            0.000000                              0.000000       0.000000
# 25%            0.000000                              0.029867      41.000000
# 50%            0.000000                              0.154181      52.000000
# 75%            0.000000                              0.559046      63.000000
# max            1.000000                          50708.000000     109.000000
#
#          Less2months      DebtRatio  MonthlyIncome  \
# count  150000.000000  150000.000000   1.202690e+05
# mean        0.421033     353.005076   6.670221e+03
# std         4.192781    2037.818523   1.438467e+04
# min         0.000000       0.000000   0.000000e+00
# ...

# %%
sns.distplot(df.SeriousDlqin2yrs,kde = True)
plt.show()

# %%
sns.distplot(df.RevolvingUtilizationOfUnsecuredLines,kde = True)
plt.show()

# %%
sns.distplot(df.age,kde = True)
plt.show()

# %%
sns.distplot(df.Less2months,kde = True)
plt.show()

# %%
sns.distplot(df.DebtRatio,kde = True)
plt.show()

# %%
sns.distplot(df.dropna(subset=['MonthlyIncome']).MonthlyIncome,kde = True)
plt.show()

# %%
sns.distplot(df.NumberOfOpenCreditLinesAndLoans,kde = True)
plt.show()

# %%
sns.distplot(df.More3months,kde = True)
plt.show()

# %%
sns.distplot(df.NumberRealEstateLoansOrLines,kde = True)
plt.show()

# %%
sns.distplot(df.Less3months,kde = True)
plt.show()

# %%
sns.distplot(df.dropna(subset=['NumberOfDependents']).NumberOfDependents,kde = True)
plt.show()

# %%
df0 = df[df['SeriousDlqin2yrs']==0]
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 139974 entries, 2 to 150000
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        139974 non-null int64
# RevolvingUtilizationOfUnsecuredLines    139974 non-null float64
# age                                     139974 non-null int64
# Less2months                             139974 non-null int64
# DebtRatio                               139974 non-null float64
# MonthlyIncome                           111912 non-null float64
# NumberOfOpenCreditLinesAndLoans         139974 non-null int64
# More3months                             139974 non-null int64
# NumberRealEstateLoansOrLines            139974 non-null int64
# Less3months                             139974 non-null int64
# NumberOfDependents                      136229 non-null float64
# dtypes: float64(4), int64(7)
# memory usage: 12.8 MB

# %%
df1 = df[df['SeriousDlqin2yrs']==1]
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10026 entries, 1 to 149980
# Data columns (total 11 columns):
# SeriousDlqin2yrs                        10026 non-null int64
# RevolvingUtilizationOfUnsecuredLines    10026 non-null float64
# age                                     10026 non-null int64
# Less2months                             10026 non-null int64
# DebtRatio                               10026 non-null float64
# MonthlyIncome                           8357 non-null float64
# NumberOfOpenCreditLinesAndLoans         10026 non-null int64
# More3months                             10026 non-null int64
# NumberRealEstateLoansOrLines            10026 non-null int64
# Less3months                             10026 non-null int64
# NumberOfDependents                      9847 non-null float64
# dtypes: float64(4), int64(7)
# memory usage: 939.9 KB

# %%
df0.corr()
# Out:
#                                       SeriousDlqin2yrs  \
# SeriousDlqin2yrs                                   NaN
# RevolvingUtilizationOfUnsecuredLines               NaN
# age                                                NaN
# Less2months                                        NaN
# DebtRatio                                          NaN
# MonthlyIncome                                      NaN
# NumberOfOpenCreditLinesAndLoans                    NaN
# More3months                                        NaN
# NumberRealEstateLoansOrLines                       NaN
# Less3months                                        NaN
# NumberOfDependents                                 NaN
#
#                                       RevolvingUtilizationOfUnsecuredLines  \
# SeriousDlqin2yrs                                                       NaN
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.005941
# ...

# %%
df1.corr()
# Out:
#                                       SeriousDlqin2yrs  \
# SeriousDlqin2yrs                                   NaN
# RevolvingUtilizationOfUnsecuredLines               NaN
# age                                                NaN
# Less2months                                        NaN
# DebtRatio                                          NaN
# MonthlyIncome                                      NaN
# NumberOfOpenCreditLinesAndLoans                    NaN
# More3months                                        NaN
# NumberRealEstateLoansOrLines                       NaN
# Less3months                                        NaN
# NumberOfDependents                                 NaN
#
#                                       RevolvingUtilizationOfUnsecuredLines  \
# SeriousDlqin2yrs                                                       NaN
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.013386
# ...

# %%
df0.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines            age  \
# count          139974.0                         139974.000000  139974.000000
# mean                0.0                              6.168855      52.751375
# std                 0.0                            256.126350      14.791079
# min                 0.0                              0.000000       0.000000
# 25%                 0.0                              0.026983      42.000000
# 50%                 0.0                              0.133288      52.000000
# 75%                 0.0                              0.487686      63.000000
# max                 0.0                          50708.000000     109.000000
#
#          Less2months      DebtRatio  MonthlyIncome  \
# count  139974.000000  139974.000000   1.119120e+05
# mean        0.280109     357.151168   6.747838e+03
# std         2.946075    2083.282060   1.481350e+04
# min         0.000000       0.000000   0.000000e+00
# ...

# %%
df1.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines           age  \
# count           10026.0                          10026.000000  10026.000000
# mean                1.0                              4.367282     45.926591
# std                 0.0                            131.835778     12.916289
# min                 1.0                              0.000000     21.000000
# 25%                 1.0                              0.398219     36.000000
# 50%                 1.0                              0.838853     45.000000
# 75%                 1.0                              1.000000     54.000000
# max                 1.0                           8328.000000    101.000000
#
#        Less2months     DebtRatio  MonthlyIncome  \
# count  10026.00000  10026.000000    8357.000000
# mean       2.38849    295.121066    5630.826493
# std       11.73451   1238.360283    6171.719674
# min        0.00000      0.000000       0.000000
# ...
