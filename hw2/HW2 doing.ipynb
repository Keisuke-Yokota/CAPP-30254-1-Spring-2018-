# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('cs-training.csv')
df = df.rename(columns={'Unnamed: 0':'ID', 
                        'NumberOfTime30-59DaysPastDueNotWorse':'Less2months',
                       'NumberOfTimes90DaysLate':'More3months',
                       'NumberOfTime60-89DaysPastDueNotWorse':'Less3months'})
df = df.set_index('ID')

# %%
df.iloc[:, 1:].describe()
# Out:
#        RevolvingUtilizationOfUnsecuredLines            age    Less2months  \
# count                         150000.000000  150000.000000  150000.000000
# mean                               6.048438      52.295207       0.421033
# std                              249.755371      14.771866       4.192781
# min                                0.000000       0.000000       0.000000
# 25%                                0.029867      41.000000       0.000000
# 50%                                0.154181      52.000000       0.000000
# 75%                                0.559046      63.000000       0.000000
# max                            50708.000000     109.000000      98.000000
#
#            DebtRatio  MonthlyIncome  NumberOfOpenCreditLinesAndLoans  \
# count  150000.000000   1.202690e+05                    150000.000000
# mean      353.005076   6.670221e+03                         8.452760
# std      2037.818523   1.438467e+04                         5.145951
# min         0.000000   0.000000e+00                         0.000000
# 25%         0.175074   3.400000e+03                         5.000000
# 50%         0.366508   5.400000e+03                         8.000000
# 75%         0.868254   8.249000e+03                        11.000000
# max    329664.000000   3.008750e+06                        58.000000
#
#          More3months  NumberRealEstateLoansOrLines    Less3months  \
# count  150000.000000                 150000.000000  150000.000000
# mean        0.265973                      1.018240       0.240387
# std         4.169304                      1.129771       4.155179
# min         0.000000                      0.000000       0.000000
# 25%         0.000000                      0.000000       0.000000
# 50%         0.000000                      1.000000       0.000000
# 75%         0.000000                      2.000000       0.000000
# max        98.000000                     54.000000      98.000000
#
#        NumberOfDependents
# count       146076.000000
# mean             0.757222
# std              1.115086
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max             20.000000

# %%
df.iloc[:, 0].value_counts()
# Out:
# 0    139974
# 1     10026
# Name: SeriousDlqin2yrs, dtype: int64

# %%
df.iloc[:, 1:].corr()
# Out:
#                                       RevolvingUtilizationOfUnsecuredLines  \
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.005898
# Less2months                                                      -0.001314
# DebtRatio                                                         0.003961
# MonthlyIncome                                                     0.007124
# NumberOfOpenCreditLinesAndLoans                                  -0.011281
# More3months                                                      -0.001061
# NumberRealEstateLoansOrLines                                      0.006235
# Less3months                                                      -0.001048
# NumberOfDependents                                                0.001557
#
#                                            age  Less2months  DebtRatio  \
# RevolvingUtilizationOfUnsecuredLines -0.005898    -0.001314   0.003961
# age                                   1.000000    -0.062995   0.024188
# Less2months                          -0.062995     1.000000  -0.006542
# DebtRatio                             0.024188    -0.006542   1.000000
# MonthlyIncome                         0.037717    -0.010217  -0.028712
# NumberOfOpenCreditLinesAndLoans       0.147705    -0.055312   0.049565
# More3months                          -0.061005     0.983603  -0.008320
# NumberRealEstateLoansOrLines          0.033150    -0.030565   0.120046
# Less3months                          -0.057159     0.987005  -0.007533
# NumberOfDependents                   -0.213303    -0.002680  -0.040673
#
#                                       MonthlyIncome  \
# RevolvingUtilizationOfUnsecuredLines       0.007124
# age                                        0.037717
# Less2months                               -0.010217
# DebtRatio                                 -0.028712
# MonthlyIncome                              1.000000
# NumberOfOpenCreditLinesAndLoans            0.091455
# More3months                               -0.012743
# NumberRealEstateLoansOrLines               0.124959
# Less3months                               -0.011116
# NumberOfDependents                         0.062647
#
#                                       NumberOfOpenCreditLinesAndLoans  \
# RevolvingUtilizationOfUnsecuredLines                        -0.011281
# age                                                          0.147705
# Less2months                                                 -0.055312
# DebtRatio                                                    0.049565
# MonthlyIncome                                                0.091455
# NumberOfOpenCreditLinesAndLoans                              1.000000
# More3months                                                 -0.079984
# NumberRealEstateLoansOrLines                                 0.433959
# Less3months                                                 -0.071077
# NumberOfDependents                                           0.065322
#
#                                       More3months  \
# RevolvingUtilizationOfUnsecuredLines    -0.001061
# age                                     -0.061005
# Less2months                              0.983603
# DebtRatio                               -0.008320
# MonthlyIncome                           -0.012743
# NumberOfOpenCreditLinesAndLoans         -0.079984
# More3months                              1.000000
# NumberRealEstateLoansOrLines            -0.045205
# Less3months                              0.992796
# NumberOfDependents                      -0.010176
#
#                                       NumberRealEstateLoansOrLines  \
# RevolvingUtilizationOfUnsecuredLines                      0.006235
# age                                                       0.033150
# Less2months                                              -0.030565
# DebtRatio                                                 0.120046
# MonthlyIncome                                             0.124959
# NumberOfOpenCreditLinesAndLoans                           0.433959
# More3months                                              -0.045205
# NumberRealEstateLoansOrLines                              1.000000
# Less3months                                              -0.039722
# NumberOfDependents                                        0.124684
#
#                                       Less3months  NumberOfDependents
# RevolvingUtilizationOfUnsecuredLines    -0.001048            0.001557
# age                                     -0.057159           -0.213303
# Less2months                              0.987005           -0.002680
# DebtRatio                               -0.007533           -0.040673
# MonthlyIncome                           -0.011116            0.062647
# NumberOfOpenCreditLinesAndLoans         -0.071077            0.065322
# More3months                              0.992796           -0.010176
# NumberRealEstateLoansOrLines            -0.039722            0.124684
# Less3months                              1.000000           -0.010922
# NumberOfDependents                      -0.010922            1.000000

# %%
df.isnull().sum()
# Out:
# SeriousDlqin2yrs                            0
# RevolvingUtilizationOfUnsecuredLines        0
# age                                         0
# Less2months                                 0
# DebtRatio                                   0
# MonthlyIncome                           29731
# NumberOfOpenCreditLinesAndLoans             0
# More3months                                 0
# NumberRealEstateLoansOrLines                0
# Less3months                                 0
# NumberOfDependents                       3924
# dtype: int64

# %%
sns.pairplot(df.fillna(df.mean()) , hue='SeriousDlqin2yrs')

# %%
import Analysis

# %%
a = Analysis.outlier_iqr(df)
# Out:
# /home/student/CAPP-30254-1-Spring-2018-/hw2/Analysis.py:76: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   col[col < outlier_min] = None
# /home/student/CAPP-30254-1-Spring-2018-/hw2/Analysis.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   col[col > outlier_max] = None

# %%
a=a.fillna(a.mean())
a.corr(
# Out:
#                                       SeriousDlqin2yrs  \
# SeriousDlqin2yrs                              1.000000
# RevolvingUtilizationOfUnsecuredLines          0.153575
# age                                          -0.072939
# Less2months                                        NaN
# DebtRatio                                     0.046779
# MonthlyIncome                                -0.036296
# NumberOfOpenCreditLinesAndLoans              -0.000099
# More3months                                        NaN
# NumberRealEstateLoansOrLines                 -0.006957
# Less3months                                        NaN
# NumberOfDependents                            0.019632
#
#                                       RevolvingUtilizationOfUnsecuredLines  \
# SeriousDlqin2yrs                                                  0.153575
# RevolvingUtilizationOfUnsecuredLines                              1.000000
# age                                                              -0.264215
# Less2months                                                            NaN
# DebtRatio                                                         0.174838
# MonthlyIncome                                                    -0.090673
# NumberOfOpenCreditLinesAndLoans                                  -0.156833
# More3months                                                            NaN
# NumberRealEstateLoansOrLines                                     -0.058576
# Less3months                                                            NaN
# NumberOfDependents                                                0.068714
#
#                                            age  Less2months  DebtRatio  \
# SeriousDlqin2yrs                     -0.072939          NaN   0.046779
# RevolvingUtilizationOfUnsecuredLines -0.264215          NaN   0.174838
# age                                   1.000000          NaN  -0.115058
# Less2months                                NaN          NaN        NaN
# DebtRatio                            -0.115058          NaN   1.000000
# MonthlyIncome                         0.105672          NaN  -0.024389
# NumberOfOpenCreditLinesAndLoans       0.160809          NaN   0.369329
# More3months                                NaN          NaN        NaN
# NumberRealEstateLoansOrLines          0.032761          NaN   0.584420
# Less3months                                NaN          NaN        NaN
# NumberOfDependents                   -0.178485          NaN   0.136296
#
#                                       MonthlyIncome  \
# SeriousDlqin2yrs                          -0.036296
# RevolvingUtilizationOfUnsecuredLines      -0.090673
# age                                        0.105672
# Less2months                                     NaN
# DebtRatio                                 -0.024389
# MonthlyIncome                              1.000000
# NumberOfOpenCreditLinesAndLoans            0.290842
# More3months                                     NaN
# NumberRealEstateLoansOrLines               0.402113
# Less3months                                     NaN
# NumberOfDependents                         0.178882
#
#                                       NumberOfOpenCreditLinesAndLoans  \
# SeriousDlqin2yrs                                            -0.000099
# RevolvingUtilizationOfUnsecuredLines                        -0.156833
# age                                                          0.160809
# Less2months                                                       NaN
# DebtRatio                                                    0.369329
# MonthlyIncome                                                0.290842
# NumberOfOpenCreditLinesAndLoans                              1.000000
# More3months                                                       NaN
# NumberRealEstateLoansOrLines                                 0.400646
# Less3months                                                       NaN
# NumberOfDependents                                           0.071561
#
#                                       More3months  \
# SeriousDlqin2yrs                              NaN
# RevolvingUtilizationOfUnsecuredLines          NaN
# age                                           NaN
# Less2months                                   NaN
# DebtRatio                                     NaN
# MonthlyIncome                                 NaN
# NumberOfOpenCreditLinesAndLoans               NaN
# More3months                                   NaN
# NumberRealEstateLoansOrLines                  NaN
# Less3months                                   NaN
# NumberOfDependents                            NaN
#
#                                       NumberRealEstateLoansOrLines  \
# SeriousDlqin2yrs                                         -0.006957
# RevolvingUtilizationOfUnsecuredLines                     -0.058576
# age                                                       0.032761
# Less2months                                                    NaN
# DebtRatio                                                 0.584420
# MonthlyIncome                                             0.402113
# NumberOfOpenCreditLinesAndLoans                           0.400646
# More3months                                                    NaN
# NumberRealEstateLoansOrLines                              1.000000
# Less3months                                                    NaN
# NumberOfDependents                                        0.153209
#
#                                       Less3months  NumberOfDependents
# SeriousDlqin2yrs                              NaN            0.019632
# RevolvingUtilizationOfUnsecuredLines          NaN            0.068714
# age                                           NaN           -0.178485
# Less2months                                   NaN                 NaN
# DebtRatio                                     NaN            0.136296
# MonthlyIncome                                 NaN            0.178882
# NumberOfOpenCreditLinesAndLoans               NaN            0.071561
# More3months                                   NaN                 NaN
# NumberRealEstateLoansOrLines                  NaN            0.153209
# Less3months                                   NaN                 NaN
# NumberOfDependents                            NaN            1.000000

# %%
sns.pairplot(a , hue='SeriousDlqin2yrs')
